# %% [markdown]
# # a10: Iteration and Strings & Regular Expressions
# - a10 (Lab 10) covers Chapter 7 and Chapter 8 of the textbook: Iteration and Python strings and regular expression (regex).
# - To run a cell, highlight the cell, hold the Shift key and hit Enter; or, just the Run icon.
# - To add a new cell, highlight the cell, and then enter A (new cell above the cell) or B (below).

# %% [markdown]
# ### .ipynb Instructions
#
# #### Activating virtual environment
# 1. Go to your **terminal** (PowerShell for Windows and Terminal.app for macOS) & move (cd) into your project directory (**workspace/python**)
# 2. Activate your virtual environment:
#    1. For macOS, Enter "source .venv/bin/activate"
#    2. For Windows, Enter "./.venv/Scripts/activate"
#    3. You should see the ".venv" prefix at your terminal prompt when the virtual environment is activated unless you run a script to activate your venv.
# 3. Launch Jupyter Notebook by entering "jupyter notebook" at the command line.
# 4. When you are done, deactivate the virtual environment by entering "deactivate".
#
# #### Installing packages
# 1. Ideally, you should install packages using a terminal:
#    1. In a terminal, activate your virtual environment.
#    2. Enter "pip install [PACKAGE-NAME]" to install the module/package/library.
# 2. To install packages in Jupyter Notebook, for example:
#    1. Type **```%pip install jupyturtle```** and hit Enter key to install jupyturtle
#    2. Comment out the installation line after installation is done.

# %% [markdown]
# ### Assignment Instruction:
#
# 1. The noteook:
#     1. Use **Jupyter Notebook** or **VS Code** as instructed. We do not have the resources to support <font color="darkred">**Anaconda**</font>.
#     2. Provide your answers in the designated spaces.
#     3. Do not reassign variables in the notebooks! For example, if you use `max_temperature` in your answer to one question, do not reassign it later on (e.g., as an intermediate variable). Otherwise, you will fail the tests that you thought you were passing previously!
#     4. **Do not run the grader.check() cells**.
# 2. Grading:
#     1. Points will be scaled in Canvas.
#     2. Most "tests", if any, in this assignment test the **format and data types** of your answers, not their **correctness**. Passing **100%** of the **tests** does not mean your **grade** will be 100%.
# 3. Academic honor:
#     1. Academic honor is important: **DO NOT CHEAT!**
#     2. <font color='darkred'>**Use AI to LEARN, not to cheat**. **DO NOT copy-n-paste**</font>: You will be competing with people who are as good as you in AI, and you will have the competitive edge when you are one of the few who know how to do things without AI.
#     3. Collaboration and using resources are encouraged, but DO NOT directly share answers. Upon typing up answers, do it yourself.
# 4. Getting help:
#     1. Come to the TA's help sessions and the instructor's office hours for help and clarification.
#     2. Text a screenshot of your technical issue to the instructor.
#     3. Emailing the instructor and the TA. (Emailing is too slow for technical problem-solving, so do not expect quick responses.)
# 5. <font color="darkred">**Time management**</font>: Start early in the assignment cycle and allot enough time for it.

# %% [markdown]
# ## References
#
# - Turtle graphics: https://docs.python.org/3.12/library/turtle.html (Choose the version)
# - Think Python v3: https://allendowney.github.io/ThinkPython/

# %% [markdown]
# <font color='darkred' size="3pt"><b>The final exam will be paper-and-pencil. Practice your coding knowledge and skills; DO NOT rely on AI. </b></font>

# %% [markdown]
# ## 1. Looping
#
# There different kinds of **for loops** in Python:
# 1. for loop with range()
# 2. for loop through a sequence
#    1. for loop though a list
#    2. for loop through a string

# %% [markdown]
# ### 1.1. for loop with range()
# - the range(START, STOP, STEP) function returns a sequence of numbers
# - START and STEP are optional and STOP is required
# - run the cell below to see what happens:

# %%
### run this cell and observe
k = 5
range(k)

# %% [markdown]
# ##### practice range STOP:
# - create a sequence of numbers from 1 to 5:

# %%
### fix the code by replacing the ellipsis (...) part with proper code

for i in range(1, ...):
    print(i)

# %% [markdown]
# ##### practice range STEP:
# - create a sequence of odd numbers between 1 and 10
# - the outcome should be 1 3 5 7 9

# %%
for i in range(..., ..., ... ):
    print(..., end=" ")

# %% [markdown]
# #### 1.2. for loop with string
#
# practice looping through strings
# - strings are sequences

# %%
### loop through the string "I am a string."
### print the characters one line at a time
str_a = "..."
for char in ...
    print(...)

# %% [markdown]
# #### 1.3. The Python **in** operator
# - The **in** keyword in Python has two uses:
#   1. looping with for
#   2. **membership testing**
#
# The membership testing feature is great for searach. Pay attention to membership testing with **in** in the following questions.

# %%
### continued from the cell above, now print vowels one line at a time
### note that the "in" operator checks if a value exists within a sequence
### and return True if the value is found
### the output should be "a a i" in three lines

for char in ...
    if char ... 'aeiou':
        print(char)

# %%
### continue from the cell above, count the number of characters that is NOT a vowel

num = 0
for char in str_a:
    if char not ... 'aeiou':
        num ... 1

print(num)

# %% [markdown]
# #### 1.4. for loop, conditional, and "in" for search
#
# Write a Python program that contains the following:
# 1. A function (call it "search_word_in_sentence") with two parameters ("word" and "sentence") that will search to see if the sentence contain the word. Return "word found" if it does and "word not found" if it doesn't.
# 2. The search should be case-insensitive.
# 3. Asks the user for a sentence.
# 4. Asks the user to enter a word.
# 5. Call the function and print the result

# %%
### complete the solution following the lines

def ...(sentence, ...):
    if ...
        return "word found"
    ...
        return "word not found"

### ask user for input
sentence = ...
word = ...

### use "This is a sentence." for a sentence and "this" for a word to test.
### the result should be "word found"

### call the function and print the result
result = ...
print(result)

# %% [markdown]
# #### 1.5. while loops
# Write a function, call it "sum_up_to", that takes a parameter ("num") and return the sum of all numbers from 0 the that number using a while loop. Your accumulater should be called "total" and your loop variable "i". At the end of the function, return total.

# %%
### Solution goes here.
### Solution goes here.
### Solution goes here.
### Solution goes here.
### Solution goes here.

# %% [markdown]
# ## 2. File Management

# %% [markdown]
# #### 2.1 Writing files with user input
#
# Design a Python function (without parameters), call it "write_to_file", that keeps taking user input and writes each sentence to a file called test.txt.
# 1. The program stops when the user types "end" (case-sensitive).
# 2. Note that this will require the use of "while true" loop, which is an infinite loop.
# 3. You may terminate the loop using the "break" keyword.

# %%
### Solution goes here.

def 
    file=...
    while True:
        sentence = input...
        if ...
            ...
        file.write(... + "\n")

write_to_file()

# %% [markdown]
# #### 2.2. Reading files and search
#
# Write a Python function that reads from the test.txt written from previous question, searches for a given word, and prints all lines that contain that word:

# %%
### Solution goes here.
### Solution goes here.
### Solution goes here.
### Solution goes here.
### Solution goes here.

# %% [markdown]
# <p>&nbsp;</p>
#
# `Good Job! You are done with this assignment!`
#
# ## Submission
#
# After you have completed the assignment, do the following to submit it:
#
# 1. Run all cells other than the grader.check cells.
# 2. **Save** the notebook file (File ==> Save Notebook) (or just the Save icon)
# 3. Use the Jupyter Notebook dashboard/Homepage to create a **duplicate** (check the checkbox by the filename ==> Duplicate) of this notebook and then **rename** (check the checkbox by the filename ==> Rename) it from *assignment*.ipynb_**copy** (e.g., a01.ipynb_copy) to *assignment_**FIRSTNAME_LASTNAME***.ipynb (e.g., a01_TSANGYAO_CHEN.ipynb) to be graded. That way you will be able to keep your original file.
# 4. **Upload** your <font color="blue">*assignment_**FIRSTNAME_LASTNAME***.ipynb</font> to Canvas.
