# %% [markdown]
# # a02 Relational Databases
# For each question, query against the employees database, give SQL code and answer.

# %% [markdown]
# ## Q1. Show all the departments in the company

# %% [markdown]
# ## Q2. Count the numbers of dept_emp

# %% [markdown]
# ## Q3. Show all dept_manager

# %% [markdown]
# ## Q4. Count employees

# %% [markdown]
# ## Q5. Count the number of salaries records

# %% [markdown]
# ## Q6. Show first 10 records of titles

# %% [markdown]
# ## Q7. What’s the average salary for the company?

# %% [markdown]
# ## Q8. What’s the name of employee who is earning the highest salary?
