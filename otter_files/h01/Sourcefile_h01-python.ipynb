# %% [raw]
# # ASSIGNMENT CONFIG
# init_cell: true
# export_cell:
#   force_save: true
#   pdf: false
#   template_pdf: false
# generate:
#   points_possible: 100.0
#   show_stdout: true
#   pagebreaks: true
#   zip: false

# %% [markdown]
# # h01. Python Lists, Looping, and Function

# %% [markdown]
# ### A Quick Note on How Grading Works
#
# Please read this carefully to understand the tests in this notebook.
#
# * **Public Tests:** The instant checks you can run here are "public tests." They are designed to help you make sure your answer is in the correct format (for example, you've named your variable correctly). Passing them is a great first step!
#
# * **Hidden Tests:** Your final grade is determined by a more complete set of "hidden tests." They are more thorough and check if your code is truly correct.
#
# **Bottom line:** Passing the public tests does **not** guarantee a perfect score. Always be sure to double-check your logic and test your code yourself.

# %%
pip install otter-grader

# %% [raw]
# # BEGIN QUESTION
# name: Q01
# points:
#  - 0
#  - 0

# %% [markdown]
# **Question 1: Creating a List of Fruits**
#
# Create a new Python list named `fruits`. The list must contain the following 5 string elements in this exact order:
#
# 1.  `"apple"`
# 2.  `"banana"`
# 3.  `"orange"`
# 4.  `"grape"`
# 5.  `"strawberry"`

# %% [raw]
# # BEGIN SOLUTION

# %%
fruits = ["apple", "banana", "orange", "grape", "strawberry"] #SOLUTION
fruits

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
assert isinstance(fruits, list), "The variable 'fruits' should be a list."

# %%
assert len(fruits) == 5, "The 'fruits' list should contain exactly 5 items."

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: Q02
# points:
#  - 0
#  - 0
#  - 0

# %% [markdown]
# ### Q02. Access and print the first and last elements of your fruit list.

# %% [raw]
# # BEGIN SOLUTION

# %%
first_fruit = fruits[0] #SOLUTION
last_fruit = fruits[-1] #SOLUTION
first_fruit
last_fruit

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
assert 'fruits' in globals(), "This test requires the 'fruits' list from Q01."

# %%
assert first_fruit == fruits[0], f"Expected first_fruit to be '{fruits[0]}', but got '{first_fruit}'."

# %%
assert last_fruit == fruits[-1], f"Expected last_fruit to be '{fruits[-1]}', but got '{last_fruit}'."

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: Q03
# points:
#  - 0
#  - 0

# %% [markdown]
# ### Q03. Add a new fruit mango to the end of the list
# - using the append() method.

# %% [raw]
# # BEGIN SOLUTION

# %%
fruits.append('mango') #SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
assert len(fruits) == 6, "After appending, the 'fruits' list should have 6 items."

# %%
assert fruits[-1] == 'mango', "The last item in the list should now be 'mango'."

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: Q04
# points:
#  - 0
#  - 0

# %% [markdown]
# ### Q04. Insert a fruit durian at the second position in the list.

# %% [raw]
# # BEGIN SOLUTION

# %%
fruits.insert(1, 'durian') #SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
assert len(fruits) == 7, "After inserting an element, the 'fruits' list should have 7 items."

# %%
assert fruits[1] == 'durian', "The item at index 1 should now be 'durian'."

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: Q05
# points:
#  - 0
#  - 0
#  - 0

# %% [markdown]
# ### Q05. Remove the fruit orange by its name
# - using the remove() method.

# %% [raw]
# # BEGIN SOLUTION

# %%
fruits.remove('orange') #SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
assert len(fruits) == 6, "After removing an element, the 'fruits' list should have 6 items."

# %%
assert 'orange' not in fruits, "The string 'orange' should no longer be in the fruits list."

# %%
assert fruits[3] == 'grape', "The element that came after 'orange' should now be at index 3."

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: Q06
# points:

# %% [markdown]
# ### Q06. Write a loop to iterate over the list and print each fruit in upper case.
# - using the upper() method

# %% [raw]
# # BEGIN SOLUTION

# %%
for fruit in fruits: #SOLUTION
    print(fruit.upper()) #SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: Q07
# points:
#  - 0
#  - 0

# %% [markdown]
# ### Q07. Write a for loop to count the number of the elements in the list.
# - use a "counter" variable
# - create a loop variable
# - use the in keyword before "fruits"
# - increment the counter inside the loop

# %% [raw]
# # BEGIN SOLUTION

# %%
counter = 0 #SOLUTION
for fruit in fruits: #SOLUTION
    counter += 1 #SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
assert counter == 6, f"Expected the counter to be 6, but got {counter} instead."

# %%
assert counter == len(fruits), "The final value of 'counter' should be equal to the number of elements in the 'fruits' list."

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: Q08
# points:

# %% [markdown]
# ### Q08. Check if 'apple' exists in the list and print a message "apple found" if it does.

# %% [raw]
# # BEGIN SOLUTION

# %%
if 'apple' in fruits: #SOLUTION
    print("apple found") #SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: Q09
# points:
#  - 0
#  - 0

# %% [markdown]
# **Question 9: Create Sorted Versions of a List**
#
# Using the original `fruits` list, perform the following two steps:
#
# 1.  Create a **new list** called `sorted_list` that contains all the fruits sorted alphabetically (A-Z).
# 2.  Create a **second new list** called `reverse_sorted_list` that contains all the fruits sorted in reverse-alphabetical order (Z-A).

# %% [raw]
# # BEGIN SOLUTION

# %%
sorted_list = sorted(fruits) #SOLUTION
reverse_sorted_list = sorted(fruits, reverse=True) #SOLUTION
sorted_list
reverse_sorted_list

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
expected_sorted = ['apple', 'banana', 'durian', 'grape', 'mango', 'strawberry']
assert sorted_list == expected_sorted, "The 'sorted_list' is not sorted correctly in alphabetical order (A-Z)."

# %%
expected_reverse_sorted = ['strawberry', 'mango', 'grape', 'durian', 'banana', 'apple']
assert reverse_sorted_list == expected_reverse_sorted, "The 'reverse_sorted_list' is not sorted correctly in reverse-alphabetical order (Z-A)."

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: Q10
# points:
#  - 0
#  - 0
#  - 0

# %% [markdown]
# ### Q10. Design a function:
# - call it count_elements
# - with a parameter call lst (which means list)
# - when called with a list argument (this fruits list), count the number of elements in the list
# - return the number of elements in the list to the caller

# %% [raw]
# # BEGIN SOLUTION

# %%
def count_elements(lst):
    number_of_elements = len(lst)# SOLUTION
    return number_of_elements # SOLUTION

fruit_count= count_elements(fruits) #SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
from types import FunctionType
result_general = count_elements([1, 2, 3, 4, 5, 6, 7, 8])
assert result_general == 8, "The function did not return the correct count for a list of 8 numbers."

# %%
result_empty = count_elements([])
assert result_empty == 0, "The function should return 0 when called with an empty list."

# %%
assert 'fruit_count' in globals(), "The variable 'fruit_count' should be defined."

assert fruit_count == 6, f"Expected fruit_count to be 6, but got {fruit_count} instead."
assert isinstance(fruit_count, int), "The 'fruit_count' variable should be an integer."

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION
