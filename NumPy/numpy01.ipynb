# %%
# %pip install numpy
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
! echo "hello"
# Out:
# hello

# %%
import sys

# %%
# !{sys.executable}
# Out:
# Python 3.12.2 (v3.12.2:6abddd9f6a, Feb  6 2024, 17:02:06) [Clang 13.0.0 (clang-1300.0.29.30)] on darwin
# Type "help", "copyright", "credits" or "license" for more information.
# >>>
# Traceback (most recent call last):
#   File "<stdin>", line 0, in <module>
# KeyboardInterrupt
# >>>

# %%
import numpy as np
matrix_a = np.random.rand(1000, 1000)

# %%
matrix_b = matrix_a

# %%
matrix_a * matrix_b
# Out:
# array([[0.80743012, 0.52511637, 0.07051152, ..., 0.26482955, 0.00942385,
#         0.07992429],
#        [0.04553287, 0.65053071, 0.24676446, ..., 0.11355458, 0.27922015,
#         0.35006183],
#        [0.00753052, 0.54980299, 0.00106559, ..., 0.02738047, 0.00721014,
#         0.0181436 ],
#        ...,
#        [0.11206432, 0.77920981, 0.26988859, ..., 0.05595858, 0.53969272,
#         0.37266649],
#        [0.06461975, 0.1660893 , 0.10721866, ..., 0.21099865, 0.89741256,
#         0.01491332],
#        [0.66474363, 0.15061226, 0.6759238 , ..., 0.08281626, 0.74876823,
#         0.90193242]], shape=(1000, 1000))

# %%
import random
[[ random.randoom() for _ in range(1000)] for _ in range(1000)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 import random
# ----> 2 [[ random.randoom() for _ in range(1000)] for _ in range(1000)]
#
# AttributeError: module 'random' has no attribute 'randoom'
