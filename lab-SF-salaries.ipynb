# %% [markdown]
# # SF Salaries Project Exercise - Questions
#
# We will be using the [SF Salaries Dataset](https://www.kaggle.com/kaggle/sf-salaries) from Kaggle to practice data analysis.
#
# Use the [dataset]('../../data/Salaries.csv') provided by the instructor.
#
# <!-- Please do the following: -->
#
# <!-- - Download the dataset (called "archive") from Kaggle.
# - Extract the archive; we will use the `Salaries.csv` file.
# - Place the `Salaries.csv` dataset in your project `data` directory. -->

# %%
# %pip install pandas
import pandas as pd
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.13/site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Read `Salaries.csv` into a DataFrame variable and call it sal.

# %%
sal = pd.read_csv('Salaries.csv')

### don't worry about the warning below.

# %% [markdown]
# Check the head of the DataFrame.

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN
# 3  2011    NaN  San Francisco     NaN
# 4  2011    NaN  San Francisco     NaN

# %% [markdown]
# Use the `.info()` method to find out how many entries there are.

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# **Q01. What is the average BasePay?**

# %%
print(sal['BasePay'].mean())
# Out:
# 66325.44884048769

# %% [markdown]
# **Q02. What is the highest amount of OvertimePay in the dataset?**

# %%
print(sal['OvertimePay'].max())
# Out:
# 245131.88

# %% [markdown]
# **Q03 What is the job title of  JOSEPH DRISCOLL?**
#
# Note: Use all caps; otherwise, you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll).

# %% [markdown]
# **Q04 How much does JOSEPH DRISCOLL make (including benefits)?**

# %% [markdown]
# **Q05. What is the name of the highest paid person (including benefits)?**

# %%
### or
### sal.loc[sal['TotalPayBenefits'].idxmax()]

# %% [markdown]
# **Q06. What is the name of the lowest-paid person (including benefits)? Do you notice something strange about how much he or she is paid?**

# %%
### or
### sal.loc[sal['TotalPayBenefits'].idxmax()]['EmployeeName']

### IT'S NEGATIVE!! VERY STRANGE

# %% [markdown]
# **Q07. What was the average (mean) BasePay of all employees per year (2011-2014)?**
#
# You may need to drop some string columns here (<span style= "color:white">drop(['EmployeeName', 'JobTitle', 'Agency'], axis=1)</span>).

# %% [markdown]
# **Q08. How many unique job titles are there?**

# %% [markdown]
# **Q09. What are the top 5 most common jobs?**
#
# (Check the [Pandas website](https://pandas.pydata.org/pandas-docs/stable/index.html). Hint: use `value_counts()`)

# %% [markdown]
# **Q10. How many Job Titles were represented by only one person in 2013? (e.g., Job Titles with only one occurrence in 2013)**

# %%
# Out:
# 202

# %% [markdown]
# <!-- **Q10. How many people have the word Chief in their job title? (This is pretty tricky)** -->
