# %% [markdown]
# # Python Overview

# %% [markdown]
# ## Programming Languages

# %% [markdown]
# ## Keywords

# %% [markdown]
# ## Variables

# %% [markdown]
# ## Data Types

# %% [markdown]
# ### Simple/Primitive Types
# numeric: int, float, (complex,) str, bool

# %%
num1 = 1
num2 = num1

# %%
yes_no =

# %%
### Boolean from relational operators
# Out:
# True

# %% [markdown]
# ### Data Structures
# list, tuple, set, dictionary (range) (strings)

# %%
### list: creation, updating, indexing, slicing, multiplying
fruits = ["apple","banana","cherry"]
nums = [1, 2, 3, 4, 5]

### tuple: creation, indexing
# nums_tuple = 
# nums_tuple

### set: creation, intersection & | 
set_a = {1, 2, 3}
set_b = {2, 3, 4}
set_a & set_b

### dictionary: creation, access, update
fruit_price = {"apple": 5,"banana": 3,"cherry": 7}
fruit_price["apple"]
# Out:
# 5

# %% [markdown]
# ## Operators
#
# ![image.png](attachment:1d9a06e2-6cf0-4482-a558-b834f31dea53.png)

# %%
### baby math: // % **


### comparison: ==, !<


### logical: and, or, not


### assignment: +=
num = 1
num += 5

### membership: in, not in
"apple" in fruits
# Out:
# True

# %% [markdown]
# ## Control Structures
# - selection
# - iteration

# %% [markdown]
# ### Conditional Statements
# 1. conditional execution
# 2. alternative execution
# 3. charined conditional

# %% [markdown]
# ### Looping
# 1. for loop: iterable, range
# 2. while loop: counter initiation, control variable+condition, block, increment/decrement

# %%
### for 
for i in [1, 2, 3, 4]

### while

# count = 1
# while count < 5:
#     print(count)
#     count += 1
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Functions
