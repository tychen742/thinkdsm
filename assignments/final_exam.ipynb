# %% [markdown]
# # Final Exam Fall 2025

# %% [markdown]
# ## Q01: Creating a List of Fruits (h0101)
#
# Create a new Python list named `fruits`. The list must contain the following 5 string elements in this exact order:
#
# 1.  `"apple"`
# 2.  `"banana"`
# 3.  `"orange"`
# 4.  `"grape"`
# 5.  `"strawberry"`

# %%
fruits = ...
fruits

# %% [markdown]
# ## Q02. Design a function (h0110)
# - call it count_elements
# - with a parameter called "lst" (which means list)
# - when called with a list argument, count the number of elements in the list
# - return the number of elements in the list to the caller

# %%
def count_elements(lst):
    number_of_elements = ...
    ...

ele_count= ...

# %% [markdown]
# ## Q03. Creating NumPy Arrays: 1D (vector) & 2D (matrix) (h0302)
# Practicing array creation and attributes:
# - **dtype**,
# - **ndim**, and
# - **shape**.

# %%
### Use the numpy arrange function to to build a one-dimensional array containing the integers 0 through 9 in order.
### assign the numpy array to a variable, call it "arr"

arr = ...
arr

# %%
### check the dimension of the array and store it to a variable dimension
### use the ndmin attribute

dimension= ...
dimension

# %% [markdown]
# ## Q04. NumPy Operations (h0303)
#
# Create 1D numpy arrays arr1 (0, 1, 2, 3, 4) and arr2 (5, 6, 7, 8, 9) using np.arange

# %%
import numpy as np
arr1 = ...
arr2 = ...

# %%
### addition: add arr1 and arr2 and store it in a variable sum_arr

sum_arr = ...
sum_arr

# %%
### multiplication: times arr1 by arr2 and store it in a variable multiplied

multiplied= ...
multiplied

# %% [markdown]
# ## Q05. Pandas DataFrames (hw-pandas3.2)
# - create a DataFrame from a dictionary

# %%
### create a dictionary, call it fruit_price, containing 
### apple, banana, cherry as keys with lists of prices (values)
### the price of apple is a list [3, 2, 3]
### the price of banana is a list [4, 5, 4]
### the price of cherry is a list [5, 5, 5]

fruit_price = ...

# %%
### create a Pandas DataFrame using dictionary fruit_price, call it df
import pandas as pd

df = ...
df

# %%
### indexing and selection in DataFrame df
### df01 ### select the column 'banana'
### df02 ### select columns 'banana' and 'cherry'
### df03 ### select the first row using loc
### df04 ### select the first two rows using loc
### df05 ### select the first row using iloc
### df06 ### select the first two rows using iloc

df01 = ...
df02 = ...
df03 = ...
df04 = ...
df05 = ...
df06 = ...

# %% [markdown]
# ## Q06. SF Salaries (h05)
#
# A salary dataset is as follows.

# %%
import pandas as pd
sal = pd.read_csv('./data/Salaries.csv')
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %% [markdown]
# **What is the average (mean) BasePay of all employees per year (2011-2014)?**
#
# You may need to drop some string columns here (<span style= "color:gray">'EmployeeName', 'JobTitle', 'Agency'</span>).

# %%
pd = ...
pd
# Out:
#             Id       BasePay  OvertimePay     OtherPay      Benefits  \
# Year
# 2011   18080.0  63595.956517  4531.065429  3617.081926           NaN
# 2012   54542.5  65436.406857  5023.417824  3653.437583  26439.966967
# 2013   91728.5  69630.030216  5281.641980  3819.969007  23829.076572
# 2014  129593.0  66564.421924  5401.993737  3505.421251  24789.601756
#
#           TotalPay  TotalPayBenefits  Notes  Status
# Year
# 2011  71744.103871      71744.103871    NaN     NaN
# 2012  74113.262265     100553.229232    NaN     NaN
# 2013  77611.443142     101440.519714    NaN     NaN
# 2014  75463.918140     100250.918884    NaN     NaN

# %% [markdown]
# ## Q07. Missing Data
#
# With the following dataframe, find the information about the missing data.

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame({                     ### create the DataFrame
    'A' : [ 1, 2, np.nan ],             ### np.nan means "Not a Number", i.e., missing data
    'B' : [ 5, np.nan, np.nan],         
    'C' : [ 1, 2, 3]
    })

# %%
df_missing_data = ...
df_missing_data
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
df_missing_sum = ...
df_missing_sum
# Out:
# A    1
# B    2
# C    0
# dtype: int64

# %%
df_fill_0 = ...
df_fill_0
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  0.0  2
# 2  0.0  0.0  3

# %% [markdown]
# ## Q08. Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

...

# %%
### the tips dataset
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

...
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Q09. Assessing Model
#
# In Swain vs. Alabama, we test the numpy multinomial function to see the random variation from the 26% of the county’s eligible Black jurors as follows. Here in this question, you are asked to prepare the for loop to run the simulation.

# %%
np.random.multinomial(100, [0.26, .74])
# Out:
# array([23, 77])

# %% [markdown]
# We then use multinomial in the function sample_proportions() to codify this simulation:

# %%
np.random.seed(42)
def sample_proportions(sample_size, probabilities):
    return np.random.multinomial(sample_size, probabilities) / sample_size
    # return np.random.multinomial(sample_size, probabilities)

# %%
eligible_population = [0.26, 0.74]
sample_proportions(100, eligible_population)
# Out:
# array([0.25, 0.75])

# %% [markdown]
# Further, we define the function `one_simulated_count()` to return what we are simulating.

# %%
np.random.seed(42)

sample_size = 100
def one_simulated_count():
    # return sample_size * sample_proportions(sample_size, eligible_population).item(0)
    return sample_size * sample_proportions(sample_size, eligible_population)[0]

# %% [markdown]
# Next, we create an array of 10,000 simulated counts by using a for loop. **Write that for loop here:**

# %%
np.random.seed(42)

counts = ..
repetitions = 10000                 
for i in ...:
    counts = ...

counts
# Out:
# array([25., 33., 29., ..., 33., 25., 23.], shape=(10000,))

# %% [markdown]
# Next, we visualize the results in an empirical histogram of the simulated counts.

# %%
df = pd.DataFrame({
    'Count in a Random Sample': counts
})

fig, ax = plt.subplots(figsize=(8, 4))

ax.hist(df, bins = np.arange(5.5, 46.6, 1), alpha=0.5, density=True, ec='white')     ### density == y-ticks (increment!)

y_vals = ax.get_yticks()
ax.set_yticklabels(['{:g}'.format( x * 100) for x in y_vals ])  ### list comprehension
ax.set_title('Random Sampling')
ax.set_xlabel('Count in Random Sample')
ax.set_ylabel('Percent Count')
plt.ylim(-0.002, 0.095)
# Out:
# /var/folders/g4/v24tl8t172g5d7rzsd63y51w0000gp/T/ipykernel_69597/3851453533.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(['{:g}'.format( x * 100) for x in y_vals ])  ### list comprehension
# (-0.002, 0.095)

# %% [markdown]
# ## Q10. Splitting Dataset
#
# A student dataset containing students from Berkely and Stanford looks like below.

# %%
coordinates = pd.read_csv('./data/coordinates.csv')
coordinates.head()
# Out:
#     latitude   longitude    school
# 0  37.869304 -122.254946  Berkeley
# 1  37.865051 -122.255582  Berkeley
# 2  37.866116 -122.253733  Berkeley
# 3  37.868049 -122.259579  Berkeley
# 4  37.868286 -122.256581  Berkeley

# %%
import seaborn as sns
plt.figure(figsize=(6,6))
sns.scatterplot(data=coordinates, x="longitude", y="latitude", hue="school")
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# Split the dataset into a training set and a test set. Since coordinates has 100 rows, let's create a training set with the first 75 rows and a test set with the remaining 25 rows. Remember that assignment to each group should be random, so we should shuffle the dataframe first.

# %%
shuffled_table = ...
train = ...
test = ...
