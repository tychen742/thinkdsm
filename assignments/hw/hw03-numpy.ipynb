# %%
# Initialize Otter
import otter
grader = otter.Notebook("hw03-numpy.ipynb")

# %% [markdown]
# # h03 NumPy - Questions
# In this homework, you will do:
# - Python review: for loop & data collection operations
# - NumPy array operations
# - NumPy vectorized functions (**ufuncs**)
#
# **Academic honor**:
# 1. Academic honor is important. Do your work, learn, **DON'T CHEAT!**
# 2. <font color='darkred'>**Use AI to LEARN, not to cheat**. **DO NOT do copy-and-paste**</font>.
# 3. Collaboration and using resources are encouraged, but DO NOT directly share answers.

# %% [markdown]
# # Notebook Editing Rules
#
# 1. **Only modify code where you see**
#    `##### change me #####` *or a similar placeholder.*
#    Write your solution on that line.
#
# 2. **Do NOT rename any variables already provided** in the prompts or tests
#    (e.g., `arr1_mean`, `subset`, `row1`).
#    The autograder looks for those exact names.
#
# Run each cell after editing to confirm it executes without errors.

# %%
# %pip install numpy

# %%
# %pip show numpy

# %%
import numpy as np

# %% [markdown]
# ## 1. Programming Review
# ### 1.1. for loop with range

# %%
### use the range( ) function to print numbers from 0 to 9
### use the end= parameter when printing

##### change me #####:
    print(i, end=" ")

# %% [markdown]
# ### 1.2. for loop with list

# %%
### use the range() function to create the sequence from 0 to 9
### use the list function to cast the object list
### save the list to a variable named "lst"
### use a for loop to print the list elements (use the "in" keyword)
### use the end= parameter when printing

lst = ##### change me #####
for ##### change me #####:
    print(i, end=" ")

# %% [markdown]
# ## 1.3 dictionary

# %%
### Observe the hypothetical pocket change dictionary below. Note that a dictionary:
### use curly braces instead of square brackets like lists
### contains key: value pairs as elements

dict_money = {"Garrett": 1900, "Jase": 20000, "Quincy": 23000, "Canaan": 21000, "Rhea": 19000}

# %% [markdown]
# To access the value of a key, use the **bracket notation**.

# %%
dict_money['Garrett']

# %%
total_money= ##### change me #####
total_money

# %%
grader.check("Q01_3")

# %% [markdown]
# ## 2. NumPy Array Operations

# %%
### import numpy here if you haven't
import numpy as np

# %% [markdown]
# ### 2.1 Creating NumPy Arrays: 1D (vector) & 2D (matrix)
# Practicing array creation and attributes:
# - **dtype**,
# - **ndim**, and
# - **shape**.

# %%
### Use the numpy arrange function to to build a one-dimensional array containing the integers 0 through 9 in order.
### assign the numpy array to a variable, call it "arr"

arr = ##### change me #####
arr

# %%
### check the dimension of the array and store it to a variable dimension
### use the ndmin attribute

dimension= arr.##### change me #####
dimension

# %%
grader.check("Q02_1")

# %%
### Create a 3 × 3 NumPy array that looks exactly like this:
[[1, 2, 3],
 [5, 5, 5],
 [7, 8, 9]]

### Store the array in a variable named arr_2d.

arr_2d = np.array([[1, 2, 3],
                ##### change me #####
                ##### change me #####
arr_2d

# %%
### check the shape of the array
### use the shape attribute

##### change me #####

# %%
grader.check("Q02_2")

# %%
##Use `type()` to find out what Python thinks the object **`arr_2d`** is.  
###Store the result in the variable **`arr_type`**.  
### you should see the data type is "numpy.ndarray"

arr_type = ##### change me #####(arr_2d)
arr_type

# %%
###Use the `.dtype` attribute to discover the data type of the *elements* inside `arr_2d`.  
###Store that result in **`scalar_dtype`**.  
### you should see dtype('int64')
scalar_type = arr_2d.##### change me #####
scalar_type

# %%
grader.check("Q02_3")

# %%
### create a 1D array with 24 elements 
### the elements are random float numbers between [0, 1). 
### use one of the random functions in the np.random module

arr = np.##### change me #####
arr

# %%
grader.check("Q02_4")

# %%
### reshape the array into a 6x4 2D array

arr_64 = arr.##### change me #####
arr_64

# %%
grader.check("Q02_5")

# %%
### create a 1D array with 24 elements 
### the elements are random integers between [1, 100] (including 100)
### use one of the random functions in the np.random module


np.random.seed(100)     ### don't change the seed value
                        ### with the same seed value, the "randomly" 
                        ### generated values will be the same every time you run the code

arr_int = np.random.##### change me #####
arr_int

# %%
grader.check("Q02_6")

# %%
### reshape the 1D array into a 6x4 2D array, still call it arr_int

arr_int = arr_int.##### change me #####
arr_int

# %%
grader.check("Q02_7")

# %%
### show the first row of the array arr_int

arr_int[0]

# %%
### Slicing task – the two middle rows

###`arr_int` is a 6 × 4 array from the question Q02_7.  
###Slice **rows 2 and 3** (0-indexed) and store that 2 × 4 result in a variable named **`mid_rows`**.

mid_rows= arr_int[ ##### change me ##### ]  
mid_rows

# %%
grader.check("Q02_8")

# %%
### Slicing task – select a subset

###Slice the following subset from `arr_int` and store it in a variable called subset.  

# array([[99, 54, 67],
#        [15, 35, 25],
#        [61, 59, 17],
#        [94, 87,  3]])


subset = arr_int[ ##### change me ##### ]
subset

# %%
grader.check("Q02_9")

# %%
arr1 = np.arange(5)           ### 0...4
arr2 = np.arange(5, 10, 1)    ### 5...9
print("arr1 = ", arr1)
print("arr2 = ", arr2)

# %%
### addition: add arr1 and arr2 and store it in a variable sum_arr

sum_arr = ##### change me #####
sum_arr

# %%
grader.check("Q03_1")

# %%
### subtraction: subtract arr2 from arr1 and store the result in a variable difference

difference= ##### change me #####
difference

# %%
grader.check("Q03_2")

# %%
### multiplication: times arr1 by arr2 and store it in a variable multiplied

multiplied= ##### change me #####
multiplied

# %%
grader.check("Q03_3")

# %%
### division: divide arr1 by arr2 and store it in a variable divided

divided = ##### change me #####
divided

# %%
grader.check("Q03_4")

# %%
### min: check the minimum value of arr1 and store it in a variable min_value

min_value = ##### change me #####
min_value

# %%
grader.check("Q03_5")

# %%
### max: check the maximum value of arr1 and store it in a variable max_value

max_value = ##### change me #####
max_value

# %%
grader.check("Q03_6")

# %%
### mean: check the average of elements in arr1

arr1_mean = ##### change me #####
arr1_mean

# %%
grader.check("Q03_7")

# %%
### argmax(): check the index number of the largest value in arr1

index = ##### change me #####
index

# %%
grader.check("Q03_8")

# %%
### sqrt(): take square root of arr1

square_root = ##### change me #####
square_root

# %%
grader.check("Q03_9")

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit.

# %%
grader.export(pdf=False, force_save=True, run_tests=True)
