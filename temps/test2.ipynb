# %%
# %pip install pandas
import numpy as np
import pandas as pd

# %%
data = 'healthdb2_social_bias.sql'

# %%
df = pd.read_csv(data)

# %%
df
# Out:
#    INSERT INTO healthdb2.social_bias (id   id_HIT   id_worker   id_article  \
# 0  INSERT INTO healthdb2.social_bias (id   id_HIT   id_worker   id_article
#
#     time_spent   time_session_spent   category_article   id_article_serial  \
# 0   time_spent   time_session_spent   category_article   id_article_serial
#
#     id_assignment   id_question  ...  null.35  null.36  null.37  null.38  \
# 0   id_assignment   id_question  ...     null     null     null     null
#
#    '2021-05-26 14:18:40'                 null.39                 null.40  \
# 0                   null   '2021-05-26 14:18:40'   '2021-05-26 14:18:42'
#
#    null.41  null.42   'landing');
# 0     null     null   'consent');
#
# [1 rows x 97 columns]

# %%
# %pip install psycopg2

# # engine = sqlalchemy.create_engine("sqlite:///my_database.db")
# from sqlalchemy import create_engine

# engine = create_engine("mysql://user:password@localhost:5432/mysql")

# with open("healthdb2_social_bias.sql", "r") as f:
#     sql_query = f.read()

# df = pd.read_sql_query(sql_query, engine)

# # df = pd.read_sql(data)

# %%
data = 'healthdb2_information_quality.csv'

# %%
df = pd.read_csv(data)
# Out:
# /var/folders/g4/v24tl8t172g5d7rzsd63y51w0000gp/T/ipykernel_14756/2297430693.py:1: DtypeWarning: Columns (25,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data)

# %%
# %pip install matplotlib --quiet
import matplotlib.pyplot as plt
# df.loc['id_article']

# %%
# df.describe

# %%
df[ df['time_question_spent'].isnull()]
# Out:
#           id                          id_HIT                   id_assignment  \
# 0       1997  3IZVJEBJ6AKOPXV9X8RRTBO4CYPZ6T  3PS7W85Z8Z2I8OM1FPANGHAGBURT9X
# 1       1998  3IZVJEBJ6AKOPXV9X8RRTBO4CYPZ6T  3PS7W85Z8Z2I8OM1FPANGHAGBURT9X
# 2       1999  3IZVJEBJ6AKOPXV9X8RRTBO4CYPZ6T  3H8DHMCCW9BV8V9VXW1X1M6AJ2FKDZ
# 9       2006  3IZVJEBJ6AKOPXV9X8RRTBO4CYPZ6T  3300DTYQT2HMB4LQ6WWE3Q04IK8EQE
# 10      2007  3IZVJEBJ6AKOPXV9X8RRTBO4CYPZ6T  3300DTYQT2HMB4LQ6WWE3Q04IK8EQE
# ...      ...                             ...                             ...
# 17800  21176  3M67TQBQQHOA68PZJNEJ4HK5C9BA90  3F0BG9B9MPNABRX2AYZHIR6MGFCY7E
# 17803  21179  3M67TQBQQHOA68PZJNEJ4HK5C9BA90  3F0BG9B9MPNABRX2AYZHIR6MGFCY7E
# 17804  21180  3M67TQBQQHOA68PZJNEJ4HK5C9BA90  3F0BG9B9MPNABRX2AYZHIR6MGFCY7E
# 17805  21181  3M67TQBQQHOA68PZJNEJ4HK5C9BA90  3F0BG9B9MPNABRX2AYZHIR6MGFCY7E
# 17806  21182  3M67TQBQQHOA68PZJNEJ4HK5C9BA90  3F0BG9B9MPNABRX2AYZHIR6MGFCY7E
#
# ...

# %%
df[['id_worker', 'id_question', 'time_article_spent', 'answer_yesNo_prior', 'confidence_prior', 'answer_yesNo_after', 'author_position', 'cc1_accuracy', 'time_question_spent']].dropna(thresh=3)
# Out:
#             id_worker  id_question  time_article_spent answer_yesNo_prior  \
# 3       A49A0FF6ZXYDU          7.0                 0.0                 No
# 4       A49A0FF6ZXYDU          7.0                 0.0                 No
# 5       A49A0FF6ZXYDU          1.0                 0.0                 No
# 6       A49A0FF6ZXYDU          1.0                 0.0                 No
# 7       A49A0FF6ZXYDU          5.0                 0.0                Yes
# ...               ...          ...                 ...                ...
# 17797  A3J75MRRI321F4          5.0                 5.0                Yes
# 17798  A3J75MRRI321F4          7.0                 4.0                Yes
# 17799  A3J75MRRI321F4          3.0                 6.0                Yes
# 17801  A1D54YKFSLF52H          8.0               -18.0                 No
# 17802  A1D54YKFSLF52H          2.0                 NaN                 No
#
#        confidence_prior answer_yesNo_after author_position  cc1_accuracy  \
# ...

# %%
time_article_spent.describe
# Out:
# <bound method NDFrame.describe of 0        NaN
# 1        NaN
# 2        NaN
# 3         No
# 4         No
#         ...
# 17802     No
# 17803    NaN
# 17804    NaN
# 17805    NaN
# 17806    NaN
# Name: answer_yesNo_prior, Length: 17807, dtype: object>

# %%
time_article_spent.describe()
# Out:
# count     8383
# unique       2
# top        Yes
# freq      5932
# Name: answer_yesNo_prior, dtype: object

# %%
time_article_spent.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 17807 entries, 0 to 17806
# Series name: answer_yesNo_prior
# Non-Null Count  Dtype
# --------------  -----
# 8383 non-null   object
# dtypes: object(1)
# memory usage: 139.2+ KB

# %%
time_article_spent.dropna(inplace=True)

# %%
time_article_spent.describe()
# Out:
# count     8383
# unique       2
# top        Yes
# freq      5932
# Name: answer_yesNo_prior, dtype: object

# %%
time_article_spent.plot(kind='line')
# Out:
# <Axes: >

# %%
time_article_spent.plot(kind='hist')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 time_article_spent.plot(kind='hist')
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/pandas/plotting/_matplotlib/core.py:499, in MPLPlot.generate(self)
# ...
