# %% [markdown]
# # Homework
#
# - Use these questions after class to check your understanding of the chapter concepts and coding skills.
# - Sign in from the account menu before you start working on the homework.
# - Complete all true/false and coding questions before you submit the homework.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
# - Multiple submissions are allowed. The highest score is kept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **Question 1: Multiple Predictors**
#
# A multiple regression model can use both store size and local income to predict sales.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 1 answer">
#   <label><input type="radio" name="ch13-hw-q1" value="true"> True</label>
#   <label><input type="radio" name="ch13-hw-q1" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Multiple regression uses more than one predictor.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **Question 2: Holding Constant**
#
# A coefficient can be interpreted as the predicted change associated with one predictor while other predictors are held fixed.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 2 answer">
#   <label><input type="radio" name="ch13-hw-q2" value="true"> True</label>
#   <label><input type="radio" name="ch13-hw-q2" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# This is the usual conditional interpretation.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **Question 3: Train/Test Split**
#
# A test set helps evaluate prediction quality on data not used to fit the model.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 3 answer">
#   <label><input type="radio" name="ch13-hw-q3" value="true"> True</label>
#   <label><input type="radio" name="ch13-hw-q3" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Test data checks out-of-sample performance.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **Question 4: Feature Scaling**
#
# Feature scaling changes the business meaning of the target variable into a classification label.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 4 answer">
#   <label><input type="radio" name="ch13-hw-q4" value="true"> True</label>
#   <label><input type="radio" name="ch13-hw-q4" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# Scaling changes predictor units, not the task type.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **Question 5: Validation Error**
#
# A model with a larger validation error is always preferred because it made bigger mistakes.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 5 answer">
#   <label><input type="radio" name="ch13-hw-q5" value="true"> True</label>
#   <label><input type="radio" name="ch13-hw-q5" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# Smaller validation error is usually better.

# %%
### 6. Three-Term Prediction
# Predict revenue from two features and an intercept.
# Print exactly:
# Predicted revenue: 510
intercept = 100
traffic_coef = 4
staff_coef = 30
traffic = 80
staff = 3

### Your code starts here.



### Your code ends here.

# %%
### Solution
intercept = 100
traffic_coef = 4
staff_coef = 30
traffic = 80
staff = 3
predicted_revenue = intercept + traffic_coef * traffic + staff_coef * staff
print("Predicted revenue:", predicted_revenue)
# Out:
# Predicted revenue: 510

# %%
### 7. Coefficient Comparison
# Identify which coefficient has the larger absolute effect.
# Print exactly:
# Larger coefficient: service_score
price_coef = -8
service_score_coef = 15

### Your code starts here.



### Your code ends here.

# %%
### Solution
price_coef = -8
service_score_coef = 15
price_abs = price_coef
if price_abs < 0:
    price_abs = -price_abs
if service_score_coef > price_abs:
    larger_coefficient = "service_score"
else:
    larger_coefficient = "price"
print("Larger coefficient:", larger_coefficient)
# Out:
# Larger coefficient: service_score

# %%
### 8. Validation Scores
# Choose the model with lower validation RMSE.
# Print exactly:
# Selected model: model_b
scores = {"model_a": 18, "model_b": 14}

### Your code starts here.



### Your code ends here.

# %%
### Solution
scores = {"model_a": 18, "model_b": 14}
if scores["model_b"] < scores["model_a"]:
    selected_model = "model_b"
else:
    selected_model = "model_a"
print("Selected model:", selected_model)
# Out:
# Selected model: model_b

# %%
### 9. Feature Count
# Count the number of predictor features.
# Print exactly:
# Feature count: 3
features = ["traffic", "staff", "income"]

### Your code starts here.



### Your code ends here.

# %%
### Solution
features = ["traffic", "staff", "income"]
print("Feature count:", len(features))
# Out:
# Feature count: 3

# %%
### 10. Test Error
# Calculate average absolute prediction error on a test set.
# Print exactly:
# Average absolute error: 5.0
actual = [100, 110, 120]
predicted = [95, 112, 128]

### Your code starts here.



### Your code ends here.

# %%
### Solution
actual = [100, 110, 120]
predicted = [95, 112, 128]
errors = []
index = 0
for value in actual:
    error = value - predicted[index]
    if error < 0:
        error = -error
    errors.append(error)
    index = index + 1
average_absolute_error = sum(errors) / len(errors)
print("Average absolute error:", average_absolute_error)
# Out:
# Average absolute error: 5.0

# %% [markdown]
# <style>
# .ch13-hw-grader { max-width: 900px; margin-top: 1rem; }
# .ch13-hw-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch13-hw-feedback-list[hidden] { display: none; }
# .ch13-hw-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch13-hw-feedback-row strong { margin-right: 0.35rem; }
# .ch13-hw-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch13-hw-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch13-hw-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch13-hw-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch13-hw-actions button.secondary { background: white; color: #176de8; }
# .ch13-hw-actions.is-locked { opacity: 0.55; }
# .ch13-hw-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch13-hw-result { font-weight: 700; }
# </style>
#
# <div class='ch13-hw-grader' id='ch13-hw-grader'>
#   <div class='ch13-hw-feedback-list' aria-live='polite' hidden>
#     <div class='ch13-hw-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch13-hw-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch13-hw-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch13-hw-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch13-hw-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#     <div class='ch13-hw-feedback-row' data-question='q6'><strong>Question 6</strong><span></span></div>
#     <div class='ch13-hw-feedback-row' data-question='q7'><strong>Question 7</strong><span></span></div>
#     <div class='ch13-hw-feedback-row' data-question='q8'><strong>Question 8</strong><span></span></div>
#     <div class='ch13-hw-feedback-row' data-question='q9'><strong>Question 9</strong><span></span></div>
#     <div class='ch13-hw-feedback-row' data-question='q10'><strong>Question 10</strong><span></span></div>
#   </div>
#   <div class='ch13-hw-actions'>
#     <button type='button' id='ch13-hw-submit' disabled>Submit</button>
#     <button type='button' class='secondary' id='ch13-hw-reset'>Clear Results</button>
#     <span class='ch13-hw-result' id='ch13-hw-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var homeworkId = 'ch13-homework';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var cm = cell.querySelector('.CodeMirror');
#     if (cm && cm.CodeMirror && typeof cm.CodeMirror.getValue === 'function') return cm.CodeMirror.getValue();
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent && cmContent.cmView && cmContent.cmView.view) return cmContent.cmView.view.state.doc.toString();
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.prototype.slice.call(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 6)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function collectAnswers() {
#     var answers = {};
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var checked = document.querySelector('input[name="ch13-hw-' + question + '"]:checked');
#       answers[question] = checked ? checked.value : '';
#     });
#     return answers;
#   }
#
#   function applyFeedback(grader, feedback) {
#     var list = grader.querySelector('.ch13-hw-feedback-list');
#     list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9', 'q10'].forEach(function (question) {
#       var row = grader.querySelector('[data-question=' + question + ']');
#       var message = row.querySelector('span');
#       var item = feedback[question];
#       row.className = 'ch13-hw-feedback-row';
#       if (!item) return;
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(grader) {
#     var list = grader.querySelector('.ch13-hw-feedback-list');
#     list.hidden = true;
#     grader.querySelectorAll('.ch13-hw-feedback-row').forEach(function (row) {
#       row.className = 'ch13-hw-feedback-row';
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/homework-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var payload = text ? JSON.parse(text) : null;
#         if (!payload || !response.ok || !payload.ok) {
#           throw new Error((payload && (payload.message || payload.error)) || 'Submission API is unavailable.');
#         }
#         return payload;
#       });
#     });
#   }
#
#   function initHomeworkGrader() {
#     var grader = document.getElementById('ch13-hw-grader');
#     if (!grader || grader.dataset.ready === 'true') return;
#     grader.dataset.ready = 'true';
#
#     var identity = getParams();
#     var actions = grader.querySelector('.ch13-hw-actions');
#     var result = document.getElementById('ch13-hw-result');
#     var submit = document.getElementById('ch13-hw-submit');
#     var reset = document.getElementById('ch13-hw-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(grader);
#       submit.disabled = true;
#       result.textContent = 'Submitting homework.';
#
#       saveAttempt({
#         homework_id: homeworkId,
#         answers: collectAnswers(),
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           applyFeedback(grader, payload.feedback || {});
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(grader);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initHomeworkGrader);
#   } else {
#     initHomeworkGrader();
#   }
# })();
# </script>
