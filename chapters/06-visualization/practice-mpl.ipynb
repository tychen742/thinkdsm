# %% [markdown]
# # Matplotlib
#
# Matplotlib's strength is its customizability. You can change everything from font sizes and colors to axis limits and tick marks. Use the official documentation to find the specific parameters you need.
#
# **Learning Objectives**
# **Learning Objectives**
# - Understand Matplotlib's architecture and the pyplot interface.
# - Learn how to create and customize line plots, bar charts, scatter plots, and histograms.
# - Explore plot customization: [styles](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html), labels, legends, and grids.
#
#
# - line plot
# - bar chart

# %%
import numpy as np
import pandas as pd

# %%
# %pip install matplotlib   ### install upon need; comment out after done
import matplotlib.pyplot as plt

### set the style. You have many options; ref.:
### https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

plt.style.use('ggplot')
# plt.style.use('seaborn-v0_8-darkgrid')
# plt.style.use('tableau-colorblind10')   ### good for colorblind folks
# plt.style.use('grayscale')              ### gray

# %%
### What is plt?
### plt is the alias for Matplotlib's pyplot module
### It provides a MATLAB-like interface for creating plots

print("plt module name:", plt.__name__)
print("plt location:", plt.__file__)
# Out:
# plt module name: matplotlib.pyplot
# plt location: /Users/tcn85/workspace/dsm/.venv/lib/python3.13/site-packages/matplotlib/pyplot.py

# %% [markdown]
# ## The Data

# %%
### sample data

x = np.linspace(0, 10, 100)      ### note that np.linspace has endpoint=True by default)
y = np.sin(x)

x_len = len(x)
x_size = x.size    
x_max = max(x)            ### function
x_min = x.min()           ### method
x_std = x.std()
x_sum = x.sum()
# x_count = x.count(0)    ### list: count the value passed in the object

x_info = [                ### make a list of tuples
    ('x_len', x_len),
    ('x_size', x_size),
    ('x_max', x_max),
    ('x_min', x_min),
    ('x_std', x_std),
    ('x_sum', x_sum)
]

### loop through a list of tuples
for name, val in x_info:     ### this is called tuple unpacking
    # print(name, val)
    print(f"{name:10} ==> {val}")
# Out:
# x_len      ==> 100
# x_size     ==> 100
# x_max      ==> 10.0
# x_min      ==> 0.0
# x_std      ==> 2.9157646512850626
# x_sum      ==> 500.0

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
y
# Out:
# array([ 0.        ,  0.10083842,  0.20064886,  0.2984138 ,  0.39313661,
#         0.48385164,  0.56963411,  0.64960951,  0.72296256,  0.78894546,
#         0.84688556,  0.8961922 ,  0.93636273,  0.96698762,  0.98775469,
#         0.99845223,  0.99897117,  0.98930624,  0.96955595,  0.93992165,
#         0.90070545,  0.85230712,  0.79522006,  0.73002623,  0.65739025,
#         0.57805259,  0.49282204,  0.40256749,  0.30820902,  0.21070855,
#         0.11106004,  0.01027934, -0.09060615, -0.19056796, -0.28858706,
#        -0.38366419, -0.47483011, -0.56115544, -0.64176014, -0.7158225 ,
#        -0.7825875 , -0.84137452, -0.89158426, -0.93270486, -0.96431712,
#        -0.98609877, -0.99782778, -0.99938456, -0.99075324, -0.97202182,
#        -0.94338126, -0.90512352, -0.85763861, -0.80141062, -0.73701276,
#        -0.66510151, -0.58640998, -0.50174037, -0.41195583, -0.31797166,
#        -0.22074597, -0.12126992, -0.0205576 ,  0.0803643 ,  0.18046693,
# ...

# %% [markdown]
# ## Shift+Tab
#
# **Q01.**
#
# Learn how to use Shift-Tab. This is critical for your learning in data science. For example, when you use Shift+Tab on plt.plot(, you see the popup as below, which is full of information you can use.
#
# <code>
# plt.plot(        ### SHIT+TAB
# </code>
#
# <pre style=" background: 'lightgrey'">
# Signature:
# plt.plot(
#     *args: 'float | ArrayLike | str',
#     scalex: 'bool' = True,
#     scaley: 'bool' = True,
#     data=None,
#     **kwargs,
# ) -> 'list[Line2D]'
# Docstring:
# Plot y versus x as lines and/or markers.
#
# Call signatures::
#
#     plot([x], y, [fmt], *, data=None, **kwargs)
#     plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
# The coordinates of the points or line nodes are given by *x*, *y*.
#     ...
#     ...
#     ...
#     </pre>

# %%
plt.plot        ### Shift+Tab
# Out:
# <function matplotlib.pyplot.plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'>

# %%
### Q01. Shift+Tab
### run plt.plot + Shift+Tab in the cell above

### Q01. Name one thing that you learned from doing Shift+Tab on plt.plot.

# %% [markdown]
# ## Line Plot
# **Q02.**

# %% [markdown]
# ### Plotting the line plot
#
# - Parameters:
#     - color
#     - linestyle

# %%
### Q02.1.
### Uncomment and run the following one by one. 

# plt.plot(x, y)                                ### plt.1
# plt.plot(x, y, color='grey')                  ### plt.2
# plt.plot(x, y, color='grey', linestyle='--')  ### plt.3

### Q02.1. Write down one thing that you learn from these three plots?

# %% [markdown]
# ### Customizing Plot
# - label
#     - The label argument is what you assign to a plotted line or object.
#     - It doesn’t display automatically; instead, it’s used by the legend.
#     - The plt.legend() call tells Matplotlib to draw a legend using all labeled artists (lines, patches, etc.).
#     - If you don’t call plt.legend(), the labels won’t be shown.
# - title
# - xlabel
# - ylabel
# - legend
#     - plt.legend(loc='upper right', title='Functions', fontsize=10)
# - grid
# - show

# %%
### plot it 
plt.plot(x, y, label='sin(x)', color='grey', linestyle='--')

# add labels and title
plt.title('Basic Sine Wave')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend()
# plt.legend(title="Legend Title")
plt.grid(True)
# plt.show()      ### == Jupyter %matplotlib inline

# %% [markdown]
# ## Bar Chart
#
# **Q03.**

# %%
### sample data
categories = [ 'A' , 'B' , 'C' , 'D' ]       ### x
values = [25, 40, 55, 30]                    ### y

### create a bar plot 
plt.figure(figsize=(5, 3))                   ### figsize; default 640*480 pixel
plt.bar(categories, values, color='teal')    ### categories, values, color (color is in the Other Parameter section)
plt.title('Categorical Data Comparison') 
plt.xlabel('Category')                       ### string literal
plt.ylabel('Value')                          ### string literal
plt.show()                                   ### %mpl inline so we don't need this in Jupyter

# %% [markdown]
# **SHIFT+TAB**:
# <pre>
# Signature:
# plt.bar(
#     x: 'float | ArrayLike',                           ### "categories" in this case
#     height: 'float | ArrayLike',                      ### "values" in this case
#     width: 'float | ArrayLike' = 0.8,
#     bottom: 'float | ArrayLike | None' = None,
#     *,
#     align: "Literal['center', 'edge']" = 'center',
#     data=None,
#     **kwargs,
# ) -> 'BarContainer'
# Docstring:
# Make a bar plot.
# </pre>

# %%
### plt was used by bar chart
### plt.plot still holds the same information, except custom parameters are changed
### x is np.linspace(0, 10, 100)
### y is np.sin(x)

# plt.plot(x, y)

# %% [markdown]
# At times, you will produce not very useful plots.

# %%
plt.bar(x, y)     ### not useful

### plt.bar(x, y)  ### This would create 100 thin bars - not useful for categorical data
### Use categories and values instead for proper bar charts
# Out:
# <BarContainer object of 100 artists>

# %%
# plt.figure(figsize=(5, 3))                        ### works: gives Fig but no axes
# plt.bar(categories, values)                       ### ABCDE; 
# plt.bar(categories, values, figsize=(5, 3))       ### figsize does not work this way

# plt.figure(figsize=(5, 3))                        ### also, figsize does not work after plt.bar()

# %% [markdown]
# ## Scatter Plots
#
# **Q04.**
#
# Scatter plots are used to visualize the relationship between two continuous variables. Each point represents a single observation.

# %%
### sample data 
np.random.seed(42)                  ### for reproducibility
x = np.random.rand(50) * 10         ### rand: random float 0-1 exclusive
y = np.random.rand(50) * 10 
colors = np.random.rand(50)         ### colors for each point
sizes = 100 * np.random.rand(50)    ### randomizing sizes of each point

### creating a scatter plot 
plt.figure(figsize=(5, 3))          ### (5, 3) tutple; personal favorite
                                    ### MPL DEFUALT is plt.figure(figsize=(6.4, 4.8) inches)
                                    ### Units are in inches
                                    ### Default DPI (dots per inch) is usually 100
                                    ### typical Matplotlib window looks like a 640×480 image — 
                                    ### the same size as an old VGA screen
plt.scatter(x, y, c=colors, s=sizes, alpha=0.7, cmap='viridis') 
plt.title('Random Scatter Plot') 
plt.xlabel('X-axis') 
plt.ylabel('Y-axis') 
plt.colorbar(label='Color intensity') 
plt.show()

# %%
### the default size: 640*480
plt.scatter(x, y)

### see below gives you the reason to learn visualization

# %% [markdown]
# ## Histograms
#
# Histograms are used to visualize the distribution of a single numerical variable. They show how many data points fall into different ranges (bins).

# %%
### sample data 

np.random.seed(42)
data = np.random.randn(1000)      ### rand, randn, randint
# Create a histogram 
# plt.figure(figsize=(8, 6)) 
plt.figure(figsize=(5, 3)) 
plt.hist(data, bins=30, color='purple', alpha=0.75, edgecolor='white' )

plt.title('Distribution of Random Data') 
plt.xlabel('Value') 
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# The end.
