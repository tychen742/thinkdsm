# %% [markdown]
# # Matplotlib Exercises - Solutions
#
# As Pandas visualization and Seaborn are both based on matplotlib, a good understanding of Matplotlib is important to have. Matplotlib can be slightly involved and tricky to understand at first. These are relatively simple plots, but they can be hard when you first start with matplotlib. Luckily, we have some experience with Pandas `plot()` already, so you will not feel totally lost.
#
# In this exercise, we'll also learn about:
# 1. How to place the code in different cells, and
# 2. the `set_xlim()` and `set_ylim` method.
#
# Resource: I encourage you to use [matplotlib.org](https://matplotlib.org/) for this exercise.
#
# - Note that you should place **all the code in one cell** when constructing the same figure. Otherwise, you may need to call the figure (`fig`) at the end in order to show the figure and plots.

# %% [markdown]
# ## Data
#
# Create the following data:

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %%
import matplotlib.pyplot as plt

# %matplotlib inline       ### for older jupyter version
# plt.show()               ### for non-notebook environment

# %% [markdown]
# ## Q01. Simple PLot with `plt.figure()`
#
# Steps to create the plot:
#
# 1. Create a new figure object and assign it to a variable named `fig` using plt.figure().
# 2. Add an axes to the figure with `fig.add_axes([0, 0, 1, 1])` and store it in a variable called `axes`.
# 3. Plot your data (x, y) on this axes.
# 4. Set the x-label, y-label, and title to match the example shown below.

# %%
### note the 3 steps: 1) plt.figure; 2) add_axes (with location & proportion); 3) plot (& set labels...)

fig = plt.figure()
axes = fig.add_axes([0, 0, 1, 1])
axes.plot(x, y)
axes.set_xlabel('x Axis')
axes.set_ylabel('y Axis')
axes.set_title('Plot Title')
# Out:
# Text(0.5, 1.0, 'Plot Title')

# %% [markdown]
# ## Q02. Plot in Plot 1: Multiple Axes
#
# 1. Figure: Create a figure object (`fig`) and put two axes, ax1 and ax2, on it.
# 2. The `figsize` of the figure should be 5 x 3.
# 4. The axes should be located at [0, 0, 1, 1] and [0.2, 0.5, .2, .2], respectively.
# 5. Plot `(x, y)` on both axes.

# %%
fig = plt.figure(figsize=(5, 3))

ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.2, 0.5, .2, .2])

ax1.plot(x,y)
ax1.set_xlabel('x')
ax1.set_ylabel('y')

ax2.plot(x,y)
ax2.set_xlabel('x')
ax2.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Q03. Plot in Plot 2
#
# Create the plot below by adding two axes to a figure object at [0, 0, 1, 1] and [0.2, 0.5, .4, .4]

# %%
fig = plt.figure()

ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.2, 0.5, .4, .4])

# %% [markdown]
# Now,
#
# - use the data (x, y, and z) arrays to create the plots. Also,
# - set the **x limits** and **y limits** on the inserted plot using the `set_xlim` and `set_ylim` methods; and
# - place `fig` at the end of the code to show the plot.

# %%
ax1.plot(x, z)
ax1.set_xlabel('X')
ax1.set_ylabel('Z')

ax2.plot(x,y)
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('zoom')
ax2.set_xlim(20, 22)
ax2.set_ylim(30, 50)

fig

# %% [markdown]
# ## Q04. Side by Side with `subplots()`
#
# 1. Use plt.subplots(nrows=1, ncols=2) to create the plot below.
# 2. Don't forget to create `fig, axes` at once.
# 3. When using subplots(), your axes variable is an ndarray and you use indexing (e.g., `axes[0]`) to access the created axes.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %% [markdown]
# - Plot (x, y) and (x, z) on the axes.
# - Adjust linewidth and linestyle.
# - Don't forget to call `fig` to evaluate and output.

# %%
axes[0].plot(x,y,color="blue", lw=3, ls='--')
axes[1].plot(x,z,color="red", lw=3, ls='-')
fig

# %% [markdown]
# - Resize the plot by adding the figsize() argument in plt.subplots().

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,2))

axes[0].plot(x, y, color="blue", lw=5)
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')

axes[1].plot(x, z, color="red", lw=3, ls='--')
axes[1].set_xlabel('x')
axes[1].set_ylabel('z')
# Out:
# Text(0, 0.5, 'z')
