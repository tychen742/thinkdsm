# %% [markdown]
# # Pandas Data Visualization Exercise: Solutions
#
# This is just a quick exercise for you to review the various plots we showed earlier. Use **df3** to replicate the following plots.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

### Set Matplotlib style options
# plt.style.use('ggplot')  # other styles: https://matplotlib.org/3.1.1/gallery/style_sheets/style_sheets_reference.html 
# plt.style.use('fivethirtyeight')
plt.style.use('seaborn-v0_8')
plt.rcParams['axes.facecolor'] = '#f7f7f7'
# plt.rcParams['grid.color'] = 'lightgray'
plt.rcParams['grid.linewidth'] = 0.5
# plt.rcParams['grid.linestyle'] = '--'
# plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['figure.edgecolor'] = 'white'
# plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['figure.figsize'] = (5, 3)
# plt.rcParams['font.size'] = 12
# plt.rcParams['axes.titlesize'] = 14
# plt.rcParams['axes.titlesize'] = 10
# plt.rcParams['axes.labelsize'] = 12
# plt.rcParams['xtick.labelsize'] = 10
# plt.rcParams['ytick.labelsize'] = 10
# plt.rcParams['legend.fontsize'] = 10
# plt.rcParams['legend.loc'] = 'best'
# plt.rcParams['lines.linewidth'] = 2
# plt.rcParams['lines.markersize'] = 6
# plt.rcParams['savefig.dpi'] = 100
# plt.rcParams['figure.dpi'] = 100

# %%
### data 

df3 = pd.read_csv('../../data/df3')
df3
# Out:
#             a         b         c         d
# 0    0.336272  0.325011  0.001020  0.401402
# 1    0.980265  0.831835  0.772288  0.076485
# 2    0.480387  0.686839  0.000575  0.746758
# 3    0.502106  0.305142  0.768608  0.654685
# 4    0.856602  0.171448  0.157971  0.321231
# ..        ...       ...       ...       ...
# 495  0.528705  0.226122  0.055835  0.131962
# 496  0.324730  0.215201  0.935302  0.794115
# 497  0.118036  0.264574  0.629206  0.824062
# 498  0.227021  0.660209  0.851353  0.478676
# 499  0.466157  0.753000  0.115391  0.279712
#
# [500 rows x 4 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# Recreate this scatter plot of b vs a. Note the color and size of the points. Also note the figure size. See if you can figure out how to stretch it in a similar fashion.

# %%
df3.plot.scatter(x='a',y='b',c='red',s=10,figsize=(12,3))
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# Create a histogram of the 'a' column.

# %%
# df3['a'].plot.hist()      ### this is a series method, not a dataframe method

df3['a'].plot.hist(edgecolor='white', linewidth=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# These plots are okay, but they don't look very polished. Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add more bins to it.

# %%
# plt.style.use('ggplot')

# %%
# df3['a'].plot.hist(alpha=0.5,bins=25)
df3['a'].plot.hist(alpha=0.5,bins=25, edgecolor='white', linewidth=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Create a boxplot comparing the a and b columns.

# %%
### create a boxplot for the dataframe first.

df3.plot.box()
# Out:
# <Axes: >

# %%
### create a boxplot comparing the columns a and b.
### note that you can pass a list of columns to index/select.

df3[['a', 'b']].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# Create a KDE plot of the 'd' column

# %%
### KDE plot requires seaborn or scipy to be installed
# %pip install scipy      ### in case scipy is not installed; uncomment this line to install it first

df3['d'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# Figure out how to increase the linewidth and make the linestyle dashed. (Note: You would usually not dash a kde plot line).

# %%
df3['d'].plot.density(lw=2,ls='--')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# Create an area plot of all the columns for just the rows up to 30. (hint: use .iloc).

# %%
df3.iloc[0:31].plot.area(alpha=0.4)  ### area plot for the first 30 rows
# df3.iloc[0:30].plot.area(alpha=0.4, figsize=(10, 4))  ### area plot for the first 30 rows
# df3.iloc[0:30].plot.area(alpha=0.4)  ### area plot for the first 30 rows
# Out:
# <Axes: >

# %% [markdown]
# <!-- ### Bonus Challenge!
# Note, you may find this really hard, reference the solutions if you can't figure it out!
# ** Notice how the legend in our previous figure overlapped some of actual diagram. Can you figure out how to display the legend outside of the plot as shown below?**
#
# ** Try searching Google for a good stackoverflow link on this topic. If you can't find it on your own - [use this one for a hint.](http://stackoverflow.com/questions/23556153/how-to-put-legend-outside-the-plot-with-pandas)** -->

# %%
# f = plt.figure()
# df3.iloc[0:30].plot.area(alpha=0.4,ax=f.gca())
# plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
# plt.show()
