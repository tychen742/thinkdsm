# %% [markdown]
# # Homework
#
# - Use these questions after class to check your understanding of the chapter concepts and coding skills.
# - Sign in from the account menu before you start working on the homework.
# - Complete all true/false and coding questions before you submit the homework.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
# - Multiple submissions are allowed. The highest score is kept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **1. Figures and Axes**
#
# **True or False:** In Matplotlib, an axes object is the plotting area where data, labels, and ticks are drawn.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 1 answer">
#   <label><input type="radio" name="ch06-hw-q1" value="true"> True</label>
#   <label><input type="radio" name="ch06-hw-q1" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Axes hold the actual plotted data and chart controls.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **2. Stateful Plotting**
#
# **True or False:** The pyplot interface can be convenient for quick charts because it keeps track of the current figure and axes.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 2 answer">
#   <label><input type="radio" name="ch06-hw-q2" value="true"> True</label>
#   <label><input type="radio" name="ch06-hw-q2" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Pyplot provides a stateful plotting style.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **3. Subplots**
#
# **True or False:** A 2 by 2 subplot layout creates exactly two plotting areas.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 3 answer">
#   <label><input type="radio" name="ch06-hw-q3" value="true"> True</label>
#   <label><input type="radio" name="ch06-hw-q3" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# A 2 by 2 layout creates four axes.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **4. Saving Figures**
#
# **True or False:** Saving a figure is useful when a chart needs to be included in a report or slide deck.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 4 answer">
#   <label><input type="radio" name="ch06-hw-q4" value="true"> True</label>
#   <label><input type="radio" name="ch06-hw-q4" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Figures can be exported for communication.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **5. Titles**
#
# **True or False:** A Matplotlib title changes the underlying data values used in the plot.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 5 answer">
#   <label><input type="radio" name="ch06-hw-q5" value="true"> True</label>
#   <label><input type="radio" name="ch06-hw-q5" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# Titles label the display; they do not modify data.

# %%
### 6. Figure Size Area
# Calculate the area of a figure size in inches.
# Print exactly:
# Figure area: 24
width = 6
height = 4

### Your code starts here.



### Your code ends here.

# %%
### Solution
width = 6
height = 4
figure_area = width * height
print("Figure area:", figure_area)
# Out:
# Figure area: 24

# %%
### 7. Legend Labels
# Collect labels that should appear in a legend.
# Print exactly:
# Legend labels: ['North', 'South']
regions = ["North", "South"]

### Your code starts here.



### Your code ends here.

# %%
### Solution
regions = ["North", "South"]
legend_labels = []
for region in regions:
    legend_labels.append(region)
print("Legend labels:", legend_labels)
# Out:
# Legend labels: ['North', 'South']

# %%
### 8. DPI Pixels
# Calculate pixel width from inches and DPI.
# Print exactly:
# Pixel width: 600
width_inches = 6
dpi = 100

### Your code starts here.



### Your code ends here.

# %%
### Solution
width_inches = 6
dpi = 100
pixel_width = width_inches * dpi
print("Pixel width:", pixel_width)
# Out:
# Pixel width: 600

# %%
### 9. Line Style Choice
# Choose a dashed line for forecast values and solid for actual values.
# Print exactly:
# Forecast style: dashed
series_type = "forecast"

### Your code starts here.



### Your code ends here.

# %%
### Solution
series_type = "forecast"
if series_type == "forecast":
    style = "dashed"
else:
    style = "solid"
print("Forecast style:", style)
# Out:
# Forecast style: dashed

# %%
### 10. Axes Titles
# Build titles for two subplot axes.
# Print exactly:
# Axis titles: ['Revenue', 'Margin']
metrics = ["Revenue", "Margin"]

### Your code starts here.



### Your code ends here.

# %%
### Solution
metrics = ["Revenue", "Margin"]
axis_titles = []
for metric in metrics:
    axis_titles.append(metric)
print("Axis titles:", axis_titles)
# Out:
# Axis titles: ['Revenue', 'Margin']

# %% [markdown]
# <style>
# .ch06-hw-grader { max-width: 900px; margin-top: 1rem; }
# .ch06-hw-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch06-hw-feedback-list[hidden] { display: none; }
# .ch06-hw-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch06-hw-feedback-row strong { margin-right: 0.35rem; }
# .ch06-hw-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch06-hw-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch06-hw-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch06-hw-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch06-hw-actions button.secondary { background: white; color: #176de8; }
# .ch06-hw-actions.is-locked { opacity: 0.55; }
# .ch06-hw-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch06-hw-result { font-weight: 700; }
# </style>
#
# <div class='ch06-hw-grader' id='ch06-hw-grader'>
#   <div class='ch06-hw-feedback-list' aria-live='polite' hidden>
#     <div class='ch06-hw-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch06-hw-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch06-hw-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch06-hw-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch06-hw-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#     <div class='ch06-hw-feedback-row' data-question='q6'><strong>Question 6</strong><span></span></div>
#     <div class='ch06-hw-feedback-row' data-question='q7'><strong>Question 7</strong><span></span></div>
#     <div class='ch06-hw-feedback-row' data-question='q8'><strong>Question 8</strong><span></span></div>
#     <div class='ch06-hw-feedback-row' data-question='q9'><strong>Question 9</strong><span></span></div>
#     <div class='ch06-hw-feedback-row' data-question='q10'><strong>Question 10</strong><span></span></div>
#   </div>
#   <div class='ch06-hw-actions'>
#     <button type='button' id='ch06-hw-submit' disabled>Submit</button>
#     <button type='button' class='secondary' id='ch06-hw-reset'>Clear Results</button>
#     <span class='ch06-hw-result' id='ch06-hw-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var homeworkId = 'ch06-homework';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var cm = cell.querySelector('.CodeMirror');
#     if (cm && cm.CodeMirror && typeof cm.CodeMirror.getValue === 'function') return cm.CodeMirror.getValue();
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent && cmContent.cmView && cmContent.cmView.view) return cmContent.cmView.view.state.doc.toString();
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.prototype.slice.call(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 6)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function collectAnswers() {
#     var answers = {};
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var checked = document.querySelector('input[name="ch06-hw-' + question + '"]:checked');
#       answers[question] = checked ? checked.value : '';
#     });
#     return answers;
#   }
#
#   function applyFeedback(grader, feedback) {
#     var list = grader.querySelector('.ch06-hw-feedback-list');
#     list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9', 'q10'].forEach(function (question) {
#       var row = grader.querySelector('[data-question=' + question + ']');
#       var message = row.querySelector('span');
#       var item = feedback[question];
#       row.className = 'ch06-hw-feedback-row';
#       if (!item) return;
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(grader) {
#     var list = grader.querySelector('.ch06-hw-feedback-list');
#     list.hidden = true;
#     grader.querySelectorAll('.ch06-hw-feedback-row').forEach(function (row) {
#       row.className = 'ch06-hw-feedback-row';
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/homework-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var payload = text ? JSON.parse(text) : null;
#         if (!payload || !response.ok || !payload.ok) {
#           throw new Error((payload && (payload.message || payload.error)) || 'Submission API is unavailable.');
#         }
#         return payload;
#       });
#     });
#   }
#
#   function initHomeworkGrader() {
#     var grader = document.getElementById('ch06-hw-grader');
#     if (!grader || grader.dataset.ready === 'true') return;
#     grader.dataset.ready = 'true';
#
#     var identity = getParams();
#     var actions = grader.querySelector('.ch06-hw-actions');
#     var result = document.getElementById('ch06-hw-result');
#     var submit = document.getElementById('ch06-hw-submit');
#     var reset = document.getElementById('ch06-hw-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(grader);
#       submit.disabled = true;
#       result.textContent = 'Submitting homework.';
#
#       saveAttempt({
#         homework_id: homeworkId,
#         answers: collectAnswers(),
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           applyFeedback(grader, payload.feedback || {});
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(grader);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initHomeworkGrader);
#   } else {
#     initHomeworkGrader();
#   }
# })();
# </script>
