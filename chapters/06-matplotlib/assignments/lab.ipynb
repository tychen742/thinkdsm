# %% [markdown]
# # Lab
#
# - Use this lab to practice the chapter's coding skills in runnable Python code.
# - Sign in from the account menu before you start working on the lab.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
# - Multiple submissions are allowed. The highest score is kept.
#
# <div data-lab-answers-release-at="2026-10-13T23:59-05:00"></div>

# %%
### Question 1: Line Plot Coordinates
# Prepare x and y coordinate lists for a line chart.
# Print exactly:
# X values: [1, 2, 3, 4]
# Y values: [20, 24, 23, 29]
quarters = [1, 2, 3, 4]
revenue = [20, 24, 23, 29]
### Your code starts here.



### Your code ends here.

# %%
### Solution
quarters = [1, 2, 3, 4]
revenue = [20, 24, 23, 29]

x_values = quarters
y_values = revenue

print("X values:", x_values)
print("Y values:", y_values)
# Out:
# X values: [1, 2, 3, 4]
# Y values: [20, 24, 23, 29]

# %%
### Question 2: Figure Labels
# Store the labels that should be applied to a management chart.
# Print exactly:
# Title: Quarterly Revenue
# X label: Quarter
# Y label: Revenue
metric = "Revenue"
time_unit = "Quarter"
### Your code starts here.



### Your code ends here.

# %%
### Solution
metric = "Revenue"
time_unit = "Quarter"

title = "Quarterly " + metric
x_label = time_unit
y_label = metric

print("Title:", title)
print("X label:", x_label)
print("Y label:", y_label)
# Out:
# Title: Quarterly Revenue
# X label: Quarter
# Y label: Revenue

# %%
### Question 3: Subplot Layout
# Calculate how many axes are needed for a 2 by 2 subplot layout.
# Print exactly:
# Rows: 2
# Columns: 2
# Axes: 4
rows = 2
columns = 2
### Your code starts here.



### Your code ends here.

# %%
### Solution
rows = 2
columns = 2

axes = rows * columns

print("Rows:", rows)
print("Columns:", columns)
print("Axes:", axes)
# Out:
# Rows: 2
# Columns: 2
# Axes: 4

# %%
### Question 4: Plot Type Plan
# Match each management need to a Matplotlib plot type.
# Use line, bar, scatter, and hist.
# Print exactly:
# Trend: line
# Groups: bar
# Relationship: scatter
# Distribution: hist
needs = ["trend", "groups", "relationship", "distribution"]
### Your code starts here.



### Your code ends here.

# %%
### Solution
needs = ["trend", "groups", "relationship", "distribution"]

plot_types = {"trend": "line", "groups": "bar", "relationship": "scatter", "distribution": "hist"}

print("Trend:", plot_types["trend"])
print("Groups:", plot_types["groups"])
print("Relationship:", plot_types["relationship"])
print("Distribution:", plot_types["distribution"])
# Out:
# Trend: line
# Groups: bar
# Relationship: scatter
# Distribution: hist

# %%
### Question 5: Save Figure Filename
# Build a clear filename for a saved chart.
# Use lowercase text and underscores.
# Print exactly:
# Filename: regional_margin_q2.png
topic = "Regional Margin"
quarter = "Q2"
### Your code starts here.



### Your code ends here.

# %%
### Solution
topic = "Regional Margin"
quarter = "Q2"

filename = topic.lower().split()[0] + "_" + topic.lower().split()[1] + "_" + quarter.lower() + ".png"
print("Filename:", filename)
# Out:
# Filename: regional_margin_q2.png

# %% [markdown]
# <style>
# .ch06-lab-grader { max-width: 900px; margin-top: 1rem; }
# .ch06-lab-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch06-lab-feedback-list[hidden] { display: none; }
# .ch06-lab-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch06-lab-feedback-row strong { margin-right: 0.35rem; }
# .ch06-lab-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch06-lab-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch06-lab-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch06-lab-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch06-lab-actions button.secondary { background: white; color: #176de8; }
# .ch06-lab-actions.is-locked { opacity: 0.55; }
# .ch06-lab-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch06-lab-result { font-weight: 700; }
# </style>
#
# <div class='ch06-lab-grader' id='ch06-lab-grader'>
#   <div class='ch06-lab-feedback-list' aria-live='polite' hidden>
#     <div class='ch06-lab-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch06-lab-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch06-lab-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch06-lab-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch06-lab-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#   </div>
#   <div class='ch06-lab-actions'>
#     <button type='button' id='ch06-lab-submit' disabled>Submit</button>
#     <button type='button' class='secondary' id='ch06-lab-reset'>Clear Results</button>
#     <span class='ch06-lab-result' id='ch06-lab-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var labId = 'ch06-lab';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var cm = cell.querySelector('.CodeMirror');
#     if (cm && cm.CodeMirror && typeof cm.CodeMirror.getValue === 'function') return cm.CodeMirror.getValue();
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent && cmContent.cmView && cmContent.cmView.view) return cmContent.cmView.view.state.doc.toString();
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.prototype.slice.call(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 1)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function applyFeedback(grader, feedback) {
#     var list = grader.querySelector('.ch06-lab-feedback-list');
#     list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var row = grader.querySelector('[data-question=' + question + ']');
#       var message = row.querySelector('span');
#       var item = feedback[question];
#       row.className = 'ch06-lab-feedback-row';
#       if (!item) return;
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(grader) {
#     var list = grader.querySelector('.ch06-lab-feedback-list');
#     list.hidden = true;
#     grader.querySelectorAll('.ch06-lab-feedback-row').forEach(function (row) {
#       row.className = 'ch06-lab-feedback-row';
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/lab-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var payload = text ? JSON.parse(text) : null;
#         if (!payload || !response.ok || !payload.ok) {
#           throw new Error((payload && (payload.message || payload.error)) || 'Submission API is unavailable.');
#         }
#         return payload;
#       });
#     });
#   }
#
#   function initLabGrader() {
#     var grader = document.getElementById('ch06-lab-grader');
#     if (!grader || grader.dataset.ready === 'true') return;
#     grader.dataset.ready = 'true';
#
#     var identity = getParams();
#     var actions = grader.querySelector('.ch06-lab-actions');
#     var result = document.getElementById('ch06-lab-result');
#     var submit = document.getElementById('ch06-lab-submit');
#     var reset = document.getElementById('ch06-lab-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(grader);
#       submit.disabled = true;
#       result.textContent = 'Submitting code.';
#
#       saveAttempt({
#         lab_id: labId,
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           applyFeedback(grader, payload.feedback || {});
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(grader);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initLabGrader);
#   } else {
#     initLabGrader();
#   }
# })();
# </script>
