# %% [markdown]
# # Cheat Sheets

# %% [markdown]
# ## Math Definitions in Data Science
#
# ```{figure} ../../images/math_definitions_data_science.jpeg
# :label: math_definitions_data_science
# :width: 450px
# :align: left
#
#
# [Mathematical Definitions in Data Science](https://x.com/PythonDvz/status/1828441337353646156)

# %% [markdown]
# ## Matrices
#
#
# ```{figure} ../../images/matrices.jpeg
# :label: matrices
# :width: 500px
# :align: left
#
#
# [Matrices](https://x.com/SolvingForZ/status/2052253844466462833/photo/1)
