# %% [markdown]
# # a08: Functions with Turtle
# - a08 (Lab 08) walks you through the creation of Python functions and some of the major ideas in functions.
# - To run a cell, highlight the cell, hold the Shift key and hit Enter; or, just the Run icon.
# - To add a new cell, highlight the cell, and then enter A (new cell above the cell) or B (below).

# %% [markdown]
# ## .ipynb Instructions
#
# ### Activating virtual environment
# 1. Go to your **terminal** (PowerShell for Windows and Terminal.app for macOS) & move (cd) into your project directory (**workspace/python**)
# 2. Activate your virtual environment:
#    1. For macOS, Enter "source .venv/bin/activate"
#    2. For Windows, Enter "./.venv/Scripts/activate"
#    3. You should see the ".venv" prefix at your terminal prompt when the virtual environment is activated unless you run a script to activate your venv.
# 3. Launch Jupyter Notebook by entering "jupyter notebook" at the command line.
# 4. When you are done, deactivate the virtual environment by entering "deactivate".
#
# ### Installing packages
# 1. Ideally, you should install packages using a terminal:
#    1. In a terminal, activate your virtual environment.
#    2. Enter "pip install [PACKAGE-NAME]" to install the module/package/library.
# 2. To install packages in Jupyter Notebook, for example:
#    1. type **```%pip install jupyturtle```** and hit Enter key (this will take a while, like minutes)
#    2. Comment out the installation line after installation is done.

# %% [markdown]
# ### Assignment Instruction:
#
# 1. The noteook:
#     1. Use **Jupyter Notebook** or **VS Code** as instructed. We do not have the resources to support <font color="darkred">**Anaconda**</font>.
#     2. Provide your answers in the designated spaces.
#     3. Do not reassign variables in the notebooks! For example, if you use `max_temperature` in your answer to one question, do not reassign it later on (e.g., as an intermediate variable). Otherwise, you will fail the tests that you thought you were passing previously!
#     4. **Do not run the grader.check() cells**.
# 2. Grading:
#     1. Points will be scaled in Canvas.
#     2. Most "tests", if any, in this assignment test the **format and data types** of your answers, not their **correctness**. Passing **100%** of the **tests** does not mean your **grade** will be 100%.
# 3. Academic honor:
#     1. Academic honor is important: **DO NOT CHEAT!**
#     2. <font color='darkred'>**Use AI to LEARN, not to cheat**. **DO NOT copy-n-paste**</font>: You will be competing with people who are as good as you in AI, and you will have the competitive edge when you are one of the few who know how to do things without AI.
#     3. Collaboration and using resources are encouraged, but DO NOT directly share answers. Upon typing up answers, do it yourself.
# 4. Getting help:
#     1. Come to the TA's help sessions and the instructor's office hours for help and clarification.
#     2. Text a screenshot of your technical issue to the instructor.
#     3. Emailing the instructor and the TA. (Emailing is too slow for technical problem-solving, so do not expect quick responses.)
# 5. <font color="darkred">**Time management**</font>: Start early in the assignment cycle and allot enough time for it.

# %% [markdown]
# ## References
#
# - Turtle graphics: https://docs.python.org/3.12/library/turtle.html (Choose the version)
# - Think Python v3: https://allendowney.github.io/ThinkPython/

# %% [markdown]
# ## 1. Launching your IDE
# - Make sure that you are in your project folder (~/workspace/python for macOS and C:\Users\[USERNAME]\workspace\python for Windows).
# - To use this file in Jupyter Notebook, enter "jupyter notebook" at terminal.
# - To use this file in VS Code, enter "code ." at terminal.
# - Use Jupyter Notebook if you are not proficient with VS Code.

# %%
### Make sure you are in your Python virtual environments directory
### 1. import the built-in "sys" module
### 2. run "sys.prefix" to show your current path; you should be in the project (python) directory
### "sys.prefix" is a string that gives the current directory of the Python installation.
### This is useful for finding the location of the Python installation (the ".venv").
### You should see your virtual environment path like: /Users/tcn85/workspace/python

...
...

# %% [markdown]
# ## 2. Import turtle
# - In Jupyter Notebook, install, if you haven't, and run "import jupyturtle".
# - Ideally, you should install jupyturtle module in terminal: activate venv and run "pip install jupyturtle"
# - If you are in a Python file (*.py) using VS Code, do "import turtle" instead of jupyturtle.
# - Run the code below to check that turtle is working.

# %%
### 1. import jupyturtle/turtle using the "import turtle as t" give alias "t" to the module
### Note this is one of the several ways we discussed to import modules
### 2. call the "make_turtle()" function from the "t" module; this will create the turtle cavas
### 3. call the "forward()" function from the "t" module to forward the turtle for 100 unit
### You should pass the argument 100 to the "forward()" function
### This will move the turtle forward 100 units
### You should see a turtle move forward 100 units

...        ### 1. import "jupyturtle" with alias "t"
...        ### 2. call the "make_turtle()" function from the "t" module to create a canvas.
...        ### 3. call the "forward()" function from the "t" module to forward the turtle for 100 unit

# %% [markdown]
# ## 3. Make a square
# - Use function forward() and left() to make a squre

# %%
### 3.1. Run the code below and observe the behavior of turtle
t.make_turtle()

t.forward(50)          ### this will move the turtle to the right for 50 units

t.left(90)             ### this will turn turtle 90 degree to the left
t.forward(50)          ### this will move the turtle to the right for 50 units

# %%
### 3.2. create a square 
### 1. create the canvas using make_turtle()
### 2. using the forward() 50 and left() 90 function to create a square

...

...
...

...
...

...
...

...
...

# %% [markdown]
# ## 4. Make a square using the for statement
# - Instead of repetitively typing left() and forward(), using a for statement to create a square.

# %%
### 1. call make_turlt() to create canvas
### 2. use a for statement and the range function to for the count of repetition.
### 3. forward() 50 units
### 4. left() 90 degrees

...            ### 1. canvas
...            ### 2. for statement header; use the range function
    ...        ### 3. forward 50 units
    ...        ### 4. turn left 90 degrees

# %% [markdown]
# ## 5. Encapsulation: Make a function to create the square
# - enclose the square-drawing code from the previous section in a function called square

# %%
### 1. define the function header and call it square.
### 2. In the body of the function, include the for loop from the previous question
### 3. call the function (you should make_turtle first)


...                ### define function header for function square
    ...            ### enclose your for statement header here
        ...        ### forward 50
        ...        ### turn 90

...                ### the canvas
...                ### call the function

# %% [markdown]
# ## 6. Code Generalization: Function Parameters/Arguments
# - In the current version, the size of the square is always 50. If we want to draw squares with different sizes, we can take the **length** of the sides as a parameter.

# %%
### 1. type again and add the parameter "length" to the function square
### 2. call the function three times to draw square of different sizes

### modify the square function to include with length parameter
...            ### 1. define function with parameter "length"
    ...        ### 2. the for statement with range
        ...    ### 3. forward at length
        ...    ### 4. turn left by 90 degrees

### call the function 3 times with length 20, 25, 50 units
...            ### create canvas first
...            ### length 20
...            ### length 25
...            ### length 50

# %% [markdown]
# ## 7. More generalization: Add sides to create polygon()
# - add another parameter, we can make it even more general. The following function draws regular polygons with a given number of sides.

# %%
### 1. change the name of the function to polygon 
### 2. add parameter "sides" and length to the function
### 3. before the for statement, calculate the angle to turn left

...        ### header with 2 parameters
    """
    parameters:
    1. sides: the number of sides of the polygon
    2. length: the length of the side by unit
    """
    ...            ### the angle variable, this should be 360/sides
    ...            ### this should be the for loop
        ...        ### this is forward by the length 
        ...        ### this is turn left by the angle

# %%
### call the function with length 50 units and sides 4
...        ### canvas
...

# %%
### call the function with length 30 units and sides 6
...        ### canvas
...

# %%
### call the function with length 30 units and sides 8
...        ### canvas
...

# %%
### call the function with length 20 units and sides 12
...        ### canvas
...

# %%
### 1. call the function polygon with length 2 units and sides 100
### You can stop the cell execution by Kernel ==> Interrupt Kernel or I,I

...        ### canvas; add argument/option "delay=0.01" to speed up the turtle
...        ### call polygon 100, 2

# %% [markdown]
# _<font color='blue'>Explain what the code above does, line by line, including the function you call. Type your answer here; replacing this text.</font>_

# %% [markdown]
# ## 8. Using the jupyturtle Built-in Functions

# %%
### find the jupyturtle functions
### 1. use the dot notation to see the turtle functions and attributes
### 2. use the dir() to find a list of turtle functions and attributes: dir(t)
### 3. Try out the functions

...        ### 1. "t." followed by the Tab key
...        ### 2. dir(t)

# %% [markdown]
# - with the functions available in jupyturtle, create a figure as below
# - you should reuse the square(length) function
#
#   <img src="./three_squares.jpg" width=250>

# %%
### Your code here.

# %% [markdown]
# ## 9. Calling Functions
# - It looks like your polygon can be pretty close to circle. Use a for loop to call it and draw a figure like below.
# - The turtle should not be seen when you are done.
#     <img src="./three_circles.jpg" width=250>

# %%
### Your code here

# %% [markdown]
# <p>&nbsp;</p>
#
# `Good Job! You are done with this assignment!`
#
# ## Submission
#
# After you have completed the assignment, do the following to submit it:
#
# 1. Run all cells other than the grader.check cells.
# 2. **Save** the notebook file (File ==> Save Notebook) (or just the Save icon)
# 3. Use the Jupyter Notebook dashboard/Homepage to create a **duplicate** (check the checkbox by the filename ==> Duplicate) of this notebook and then **rename** (check the checkbox by the filename ==> Rename) it from *assignment*.ipynb_**copy** (e.g., a01.ipynb_copy) to *assignment_**FIRSTNAME_LASTNAME***.ipynb (e.g., a01_TSANGYAO_CHEN.ipynb) to be graded. That way you will be able to keep your original file.
# 4. **Upload** your <font color="blue">*assignment_**FIRSTNAME_LASTNAME***.ipynb</font> to Canvas.
