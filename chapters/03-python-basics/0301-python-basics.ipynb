# %% [markdown]
# # Python Basics

# %% [markdown]
# Python is a core tool in data science because it is easy to learn, reflecting its origins as a scripting language with a flexible, dynamically typed approach. Its rich ecosystem of libraries for data wrangling, visualization, and machine learning lets you move quickly from raw data to analysis and models. Packages such as Pandas, NumPy, and scikit-learn are common starting points.
#
# This chapter introduces three fundamental areas of Python you'll use immediately:
# 1. Basic syntax
# 2. Variables
# 3. Operators
# 4. Data types
# 5. Keywords and built-in functions
# 6. Input and output
# 7. Exceptions

# %% [markdown]
# ### Basic Syntax
#
# Python is designed to be readable and minimal, with syntax rules that emphasize clarity. There are basic rules that you have to follow when you write Python code:
#
# - Case sensitive: Python is case sensitive with names; e.g., "Name" is different from "name".
# - Indentation: Python uses indentation (4 spaces) to define **blocks**, not {} braces.
# - Comments:
#   - \# The hash character or pound sign works as a single-line comment.
#   - Multi-line comment: Python does not have multi-line comments, but you can use a multi-line string for the purpose.
#
#     ```code
#     """
#     Multi-line comment or docstring
#     Used for documentation
#     """
#     ```
# - Statement vs. Expression:
#   - Statements are instructions that perform an action but do not produce a result value; e.g., x = 5 is an **assignment** statement, and to iterate through a sequence, we use a **for** statement or a **while** statement.
#   - Expressions are combinations of values, variables, and operators that the Python **interpreter** evaluates to produce a single value; e.g., len('hello') or "world".
#
# A quick reference for some additional basic Python syntax concepts:
#
# | Concept    | Example            |
# | ---------- | ------------------ |
# | Print      | `print("Hello")`   |
# | Variable   | `x = 10`           |
# | Comment    | `# note`           |
# | If/Else    | `if...elif...else` |
# | Loop       | `for i in nums:`   |
# | List Index | `items[0]`         |
# | Function   | `def add(x,y):`    |
# | Import     | `import random`    |

# %% [markdown]
# #### Autocomplete
#
# In Jupyter Notebook (and in Python shell and VS Code), autocomplete (also known as IntelliSense or tab completion) helps you discover and write code more efficiently. When you use dot notation (the dot operator), autocomplete shows
# you available methods, attributes, and function signatures as you type.
#
# | Action                         | Shortcut                                  |
# | ------------------------------ | ----------------------------------------- |
# | Show autocomplete suggestions (any function, variable, or keyword in scope)  | **Tab**   |
# | Show properties and methods of the object  | `.`**Tab**   |
# | Display basic tooltip Function signature / docstring (documentation) | **Shift + Tab**                           |
# | Expanded help                  | **Shift + Tab** (twice)                   |

# %% [markdown]
# ## Variables
#
# **Variables** are names that reference **objects** in memory. A couple of things to know about Python variables include:
#
# - You create variables with the assignment operator (the equal sign, e.g., x = 2) and
# - Can **reassign** them to different objects.
# - Use descriptive, **lowercase** names with **underscores** for readability, and
# - Avoid starting names with digits or symbols.
#
# For naming conventions, see [PEP8](https://peps.python.org/pep-0008/) or [Google Python Style Guide](https://google.github.io/styleguide/pyguide.html).

# %% [markdown]
# ### Creating Variables
#
# Variables are created by assigning values through the use of the equal sign.

# %%
### creating variables
num1 = 100                  ### creating a variable with an integer value assigned
user_age = 30               ### lower-case with underscore for name
total_volume = 15.5         ### creating a floating-point number variable
is_active = True            ### creating a Boolean value variable
university = "S&T"          ### creating a string object variable

### reassignment
num2 = 200
num3 = num1 + num2          ### reassign with expression
num3 = num3 + num3          ### reassign, again

### creating constants
MAX_CONNECTIONS = 100000    ### UPPER case for constant (variable)
PI = 3.14159


print(num1, user_age, total_volume, is_active, university, sep="\n")
# Out:
# 100
# 30
# 15.5
# True
# S&T

# %%
### illegal names

# my-var = 10
# my var = 10
# 2myvar = 10

# 12var = 12
# $var = 5

# %% [markdown]
# ### Python Object Defined
#
# You would often here the saying that:
# - Everything in Python is an **object**.
#
# Two things we want to learn here: The definition of object in Python and how objects help us.

# %% [markdown]
# **Definition**: Some other ideas to be considered about objects, however:
# - A variable doesn't "contain" a value; it **points** to an object in memory.
# - Objects come from **classes**, which act like blueprints.
# - Each object has:
#   - **Identity** (where it lives in memory)
#   - **Type** (what kind of thing it is)
#   - **Value** (the data it holds)
#
# To check the identy and type of an object, we can use the `id()` and `type()` method:

# %%
num = 100                                                            ### assign a value to a variable name/label
print("The unique identifier of this num object is: ", id(num))      ### identity of object
print("The type/class of this num object is: ", type(num))           ### data type of object
print("The value of this num object is: ", num)                      ### value of object
# Out:
# The unique identifier of this num object is:  4340427872
# The type/class of this num object is:  <class 'int'>
# The value of this num object is:  100

# %% [markdown]
# ### Python Object Usage
#
# Further, we know that Python objects have attributes and methods. Python objects encapsulate variables (attributes) and methods (functions) that operate on those variables:
#   - **Attributes**: Variables associated with an object or a class.
#   - **Methods**: Functions defined within a class that describe the object's behavior.
#
# Having access to the attributes and methods will be extremely helpful when, for example, learning new packages in data science.
#
# For now, let's take a look at the built-in attributes/methods for `int` objects:

# %%
print("The num object is an integer: ", num.is_integer())            ### num's has an function "is_integer"
# Out:
# The num object is an integer:  True

# %% [markdown]
# The reason we are able to check whether `num` is an integer is because it is an object and it has built-in attributes and functions that we can use. In this case of an object with `int` type, there is a `is_integer()` function/method that returns True/False.
#
# We can use the `dir` function to see all the associated functions and attributes of an object:

# %%
print(dir(num))
# Out:
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'as_integer_ratio', 'bit_count', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'is_integer', 'numerator', 'real', 'to_bytes']

# %% [markdown]
# #### Dot Notation
#
# To access the attributes and methods of a Python object, instead of `dir()`, we can use the **dot operator**. <span style="color: darkred;">In Jupyter Notebook, you place the **dot** operator after the object, move your **cursor** to after the dot, followed by the **Tab** key to show a dropdown menu of the attributes (instances) and methods (functions)</span>.

# %% [markdown]
# ```{figure} ../../images/dot-operator-tab.png
# ---
# height: 200px
# name: dot-operator-tab
# ---
# **dot** operator, then **Tab**, to see attributes and methods with the object
# ```

# %% [markdown]
# In Python shell, you can do the same. For example, to access the attributes and methods of `string` objects using dot operator with Tab key:
#
# ```python
# PS C:\Users\tychen> py -3.13
# >>> string_example = "abc"
# >>> string_example.
# string.capitalize()    string.index(          string.isspace()       string.removesuffix(
# string.startswith(     string.casefold()      string.isalnum()       string.istitle()
# string.replace(        string.strip(          string.center(         string.isalpha()
# string.isupper()       string.rfind(          string.swapcase()      string.count(
# string.isascii()       string.join(           string.rindex(         string.title()
# string.encode(         string.isdecimal()
# ...
# ```

# %% [markdown]
# Now, let us create a string object `university` and assign to it the value of `'MS&T'`. This is a string, so we can check the attributes and methods of the string object here:

# %%
university = 'MS&T'

print("String object 'university' is a decimal: \t", university.isdecimal())
print("Turn 'university' to lower case: \t\t", university.lower())
# Out:
# String object 'university' is a decimal: 	 False
# Turn 'university' to lower case: 		 ms&t

# %% [markdown]
# Note that we use the `dir()` function to show all the attributes and methods for the object `university`:

# %%
print(dir(university))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %% [markdown]
# ## Operators
#
# **Operators** enable you to perform common operations on variables. There are seven main operator types:
#
# | No. | Operator type | Purpose | Examples |
# | --- | --- | --- | --- |
# | 1 | Assignment | Perform assignments and augmented assignments | `=`, `+=`, `:=`  |
# | 2 | Arithmetic | Perform calculations (note `/` yields a floating-point number; avoid division by 0) | `+`, `-`, `*`, `/`, `%`, `//`, `**` |
# | 3 | Comparison | Evaluate relationships | `==`, `!=`, `<`, `>`, `<=`, `>=` |
# | 4 | Logical | Combine boolean expressions | `and`, `or`, `not` (e.g., `x == x and y > z`) |
# | 5 | Identity | Compare object identity; equality compares values | `is`, `is not` (e.g., `a is b`) |
# | 6 | Membership | Test membership in a collection | `in`, `not in` (e.g., `x in my_list`) |
# | 7 | Bitwise | Bit-level operations | `&`, `\|`, `^`, `<<`, `>>` (e.g., `x & y`) |

# %% [markdown]
# ### Operator Precedence
#
# Python follows standard mathematical order of operations (PEMDAS: Parentheses, Exponents, Multiplication and Division from left to right, then Addition and Subtraction from left to right). For example:

# %%
print(2 + 3 * 5 + 5)
print(2 + 3 * (5 + 5))
# Out:
# 22
# 32

# %% [markdown]
# ## Built-in Types
#
# **Data types** define the kind of values you work with. Python has [standard built-in types](https://docs.python.org/3/library/stdtypes.html) built into the interpreter:
#
# | No. | Category             | Types                         | Description                                                 |
# |-----|----------------------|-------------------------------|-------------------------------------------------------------|
# | 1   | Numeric Types     | `int`, `float`, `complex`     | Integer, floating-point, and complex numbers                |
# | 2   | Boolean Type      | `bool`                        | True/False logic                                            |
# | 3   | Sequence Types    | `list`, `tuple`, `range`      | Ordered, mutable/immutable collections; nesting supported   |
# | 4   | Text Sequence     | `str`                         | Text that supports indexing and slicing                     |
# | 5   | Binary Sequence   | `bytes`, `bytearray`,         | Binary data                                                 |
# |     |                      | `memoryview`                  |                                                             |
# | 6   | Set Types         | `set`, `frozenset`            | Unordered collections of unique elements                    |
# | 7   | Mapping Type      | `dict`                        | Key-value pairs                                             |
# | 8   | None Type         | `NoneType`                    | Represents absence of value                                 |
#
#
# ```{figure} ../../images/python-data-types-2.png
# ---
# width: 500px
# name: python-data-types
# ---
# [Python built-in data types](https://www.codecademy.com/article/what-are-python-data-types-and-how-to-check-them)
# ```
#
# <!-- [Python built-in data types](https://www.scaler.com/topics/type-casting-in-python/) -->

# %% [markdown]
# Some examples of Python built-in types and their common operations are as follows.

# %% [markdown]
# ### Numbers
#
# Python has three basic number types: integers (e.g., 1), floating-point numbers (e.g., 1.0), and complex numbers. The standard order of operations for basic arithmetic is followed. Note that dividing two integers results in a floating-point number, and dividing by zero will generate an error.

# %%
print(1 + 1)
print(1 * 3)         
print(1 / 2)
print(2 / 2)             ### output 1.0, not 1
print(2 ** 4)
# Out:
# 2
# 3
# 0.5
# 1.0
# 16

# %% [markdown]
# The **modulus** operation (also known as the mod function) is represented by the percent sign. It returns what remains after the division. **Floor division**, on the other hand, rounds the result down to the nearest whole number.

# %%
print(4 % 2)
print(5 % 2)
print(9 // 2)
# Out:
# 0
# 1
# 4

# %%
### Practice Cell

# %% [markdown]
# ### Strings
#
# Strings can be created using single or double quotes. You can wrap double quotes around single quotes if you need to include a quote inside the string. You can also **escape** (\) a quotation mark to show it as a regular character.

# %%
print('hello')
print("hello")
print("I can't go")
print('I can\'t go')     ### escape sequence: \
# Out:
# hello
# hello
# I can't go
# I can't go

# %% [markdown]
# #### Indexing and Slicing Strings
#
# Strings are **sequences** of characters. You can access specific elements using **square bracket notation**. Python indexing starts at zero. Negative indexing in slicing starts with -1 from the end element.

# %%
s = 'hello'
print(s[0])
print(s[4])
print(s[-1])
# Out:
# h
# o
# o

# %% [markdown]
# **Slice notation** allows you to grab parts of a string. Use a **colon** to specify the **start**, **stop**, and **step** indices in slicing. Note that the slicing operation is stop-**exclusive**.

# %%
s = 'abcdef'
print(s[0:])
print(s[:3])
print(s[3:6])
print(s[3:999])
print(s[0::2])
print(s[1:-1])
# Out:
# abcdef
# abc
# def
# def
# ace
# bcde

# %% [markdown]
# ```{code-cell} ipython3
# :tags: [thebe-init]
#
# %matplotlib inline
# import numpy as np
# import matplotlib.pyplot as plt
# x = np.linspace(0,10)
# plt.plot(x, np.sin(x))
# plt.plot(x, np.cos(x))
#
# ```

# %%
num = 1 / 1
print("The data type of num is:", type(num))
# Out:
# The data type of num is: <class 'float'>

# %% [markdown]
# ### Lists
#
# Lists are sequences of elements (similar to the array in many other languages) in **square brackets**, separated by _commas_. Lists can contain any data type, including other lists.

# %%
my_list = ['a', 'b', 'c']

print(my_list)

my_list[0] = 'NEW'          ### update element (lists are mutable)
my_list.append('d')         ### using the append method
print(my_list)
# Out:
# ['a', 'b', 'c']
# ['NEW', 'b', 'c', 'd']

# %% [markdown]
# - Lists can be nested inside each other.
# - Indexing and slicing work the same as in strings.
# - You can access elements in nested lists by chaining square brackets.

# %%
lst = [1, 2, [3, 4]]

print(lst[0])
print(lst[1:3])             ### output a subset list
print(lst[2][1])            ### 4
# Out:
# 1
# [2, [3, 4]]
# 4

# %% [markdown]
# For deeper nesting, continue stacking brackets to access the desired element.

# %%
nest = [1, 2, 3, [4, 5, ['Target', 'Walmart']]]

print(nest[3][2][0])                  ### 'target'
# Out:
# Target

# %% [markdown]
# ## Python Keywords
#
# In programming, keywords are predefined, reserved words with special meanings that define the **structure** and **syntax** of a programming language. Keywords have predefined meanings and cannot be used as **identifiers** (such as variable names, function names, or class names). For example, trying to create a value with a keyword as the variable name ("True" in this example) will cause a syntax error:

# %% [markdown]
# ```python
# >>> True = "this is true"
#   File "<python-input-0>", line 1
#     True = "this is true"
#     ^^^^
# SyntaxError: cannot assign to True
# >>>
# ```

# %% [markdown]
# There are currently 35 [keywords](https://docs.python.org/3/reference/lexical_analysis.html#keywords) and four soft keywords in the [Python Language Reference](https://docs.python.org/3/reference/lexical_analysis.html#keywords).
#
# ::::{grid}
# :gutter: 5
#
# :::{grid-item}
# False
# await
# else
# import
# pass
# :::
# :::{grid-item}
# None
# break
# except
# in
# raise
# :::
# :::{grid-item}
# True
# class
# finally
# is
# return
# :::
# :::{grid-item}
# and
# continue
# for
# lambda
# try
# :::
# :::{grid-item}
# as
# def
# from
# nonlocal
# while
# :::
# :::{grid-item}
# assert
# del
# global
# not
# with
# :::
# :::{grid-item}
# async
# elif
# if
# or
# yield
# :::
# ::::

# %% [markdown]
# Python has 4 _soft keywords_ that are only reserved under specific contexts and can still be used as identifier names: `match`, `case`, `_`, and `type`.

# %% [markdown]
# ## Built-in Functions
# The Python interpreter includes a number of built-in functions and types that are always available, so you don’t need to `import` modules to access them. For example, `print()` is available to use when you have the interpreter available through the Python shell or Jupyter Notebook.
#
# Along with **keywords**, the **built-in functions** provide the essential capabilities of the programming language, such as:
#
# - working with data types
# - performing calculations
# - handling input/output
#
# Some examples of built-in functions are:
# - `print()`) for displaying output)
# - `len()` for finding the length of a sequence
# - `type()` for checking the data type of a value
# - `range()` for generating sequences of numbers
# - `input()` for reading user input

# %% [markdown]
# The Python Standard Library lists the built-in functions.
#
# ```{figure} ../../images/python-builtin-functions.png
# ---
# width: 400px
# name: python-builtin-functions
# ---
# [Python Built-In Functions](https://docs.python.org/3/library/functions.html#built-in-functions)
# ```
#
# These Python built-in functions can be grouped as:
#
# | Group                           | Functions                                                                                                                          | Notes                                                            |
# | ------------------------------- | ---------------------------------------------------------------------------------------------------------------------------------- | ---------------------------------------------------------------- |
# | Numbers & math                  | **`abs`**, `divmod`, **`max`**, **`min`**, **`pow`**, **`round`**, **`sum`**                                                                               | `pow(a, b, mod=None)` supports modular exponentiation.           |
# | Type constructors/conversions | **`bool`**, **`int`**, **`float`**, **`complex`**, **`str`**, `bytes`, `bytearray`, `memoryview`, **`list`**, **`tuple`**, `set`, `frozenset`, `dict`, `range` | Convert or construct core types.                                 |
# | Object/attribute introspection  | **`type`**, `isinstance`, `issubclass`, **`id`**, `hash`, `dir`, `vars`, `repr`, `ascii`                                                   | `vars(obj)` → `obj.__dict__` when available.                     |
# | Attribute access                | `getattr`, `setattr`, `delattr`, `hasattr`                                                                                         | Dynamic attribute management.                                    |
# | Iteration & functional tools    | `iter`, `next`, `enumerate`, `zip`, `map`, `filter`, `sorted`, `reversed`                                                          | Prefer comprehensions when clearer.                              |
# | Sequence/char helpers           | **`len`**, `ord`, `chr`, `slice`                                                                                                       | `len()` works on many containers.                                |
# | I/O                             | **`print`**, **`input`**, `open`                                                                                                           | `open` returns a context manager; prefer `with open(...) as f:`. |
# | Formatting / representation     | `format`, `bin`, `oct`, `hex`                                                                                                      | Also see f-strings for formatting.                               |
# | Object model (OOP helpers)      | `object`, `property`, `classmethod`, `staticmethod`, `super`                                                                       | Define descriptors and class behaviors.                          |
# | Execution / metaprogramming     | `compile`, `eval`, `exec`                                                                                                          | Use with care; security concerns for untrusted input.            |
# | Environment / namespaces        | `globals`, `locals`                                                                                                                | Introspection of current namespaces.                             |
# | Help/debugging                  | `help`, `breakpoint`                                                                                                               | `breakpoint()` respects `PYTHONBREAKPOINT`.                      |
# | Import                          | `__import__`                                                                                                                       | Low-level import; usually use `import` statement instead.        |

# %% [markdown]
# ### Type casting
#
# A number of the built-in types are constructor functions that can perform corresponding type casting. For example, `int` turns the argument literal into `int` type:

# %%
### literals: 1, 2.8, "3"
print(type(1), type(2.8), type("3"))

x = int(1)   # x will be 1
y = int(2.8) # y will be 2
z = int("3") # z will be 3

print(x, y, z)
print(type(x), type(y), type(z))
# Out:
# <class 'int'> <class 'float'> <class 'str'>
# 1 2 3
# <class 'int'> <class 'int'> <class 'int'>

# %% [markdown]
# ## Input and Output
#
# In Python, basic input and output operations are handled primarily by the input() and print() functions.

# %% [markdown]
# ### `input()`
#
# The `input()` function is used to obtain user input from the command line:
#
# - It displays the **prompt** (the string argument of the input function) for the user to enter text and then press Enter to complete the input.
# - The function then returns the entered text as a string, and we usually save the entered string to a variable, and you may need to be **cast** to other types when needed.
# - The input prompt **interface** will show differently in different interfaces (Python shell in PowerShell/Terminal, Jupyter Notebook, VSCode...). For example, if you use the Python shell in PowerShell or Terminal, the interface will look like the following:
#
# ```powershell
# >>> num = input("Enter an integer between 1 and 10: ")
# Enter an integer between 1 and 10: 7
# >>> num
# '7'
# >>> type(num)
# <class 'str'>
# >>> int(num)
# 7
# >>> type(num)
# <class 'int'>
# ```

# %%
name = input("Enter your name: ")
print(f"Hello, {name}!")
# Out:
# Enter your name:  TY
# Hello, TY!

# %% [markdown]
# ### `print()`
#
# The print function is a built-in Python function that serves as the primary tool for displaying output. It converts objects into their string representation before sending them to the console or another standard output device. In the Python shell, typing an expression (e.g., a variable name) and pressing Enter will cause the expression to be evaluated and display its value. In Jupyter Notebook, you need to run the cell for this to happen. However, to officially display output in Python, we use the `print` statement.
#
# The basic syntax for `print()` is:
#
# `print(*objects, sep=' ', end='\n', file=None, flush=False)`
#
# You can pass a string **literal** directly to print() as an argument:
#
# ```powershell
# >>> print("Please wait while the professor is thinking...")
# Please wait while the professor is thinking...

# %% [markdown]
# Mostly, you will pass **variables** to print() instead of literal values:

# %%
greeting = 'hello world'
print(greeting)
# Out:
# hello world

# %% [markdown]
# You can also pass **expressions** to print():

# %%
x = 10
y = 2
print( x**y )
# Out:
# 100

# %% [markdown]
# print() also accepts **multiple arguments** separated by **comma**:

# %%
name = "Dr. Chen"
age = 35
print(name, "was", age, ".")
# Out:
# Dr. Chen was 35 .

# %% [markdown]
# You can also mix **expressions** with literals when printing using commas (a **space** between each item will be added):

# %%
name = "Bob"
age = 25
print("Hello,", name, "! You are", age + 3, "years old.")
# Out:
# Hello, Bob ! You are 28 years old.

# %% [markdown]
# If you use **concatenation** (`+`) to join the arguments, you have to cast the arguments to **string** (note that concatenation does not add commas between arguments):

# %%
print(name, age)            ### multiple arguments with comman
# Out:
# Bob 25

# %%
print(name + age)           ### multiple arguments with concatenation
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print(name + age)           ### multiple arguments with concatenation
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(name + str(age))       ### type casting, then concatenate
# Out:
# Bob25

# %% [markdown]
# ### F-strings
#
# Also called **formatted string** literals, f-strings are string literals that have an `f` before the opening quotation mark. They can include Python expressions enclosed in **curly braces**. Python will replace those expressions with their resulting values. F-strings are more flexible and readable and therefore are in general preferred for string formatting:
#
# ```python
# >>> name = "Bob"
# >>> age = 25
# >>> print(f"Hello, {name}, you are {age} years old!")
# Hello, Bob, you are 25 years old!
# >>>
# ```

# %% [markdown]
# ### `end` and `sep`
# The `end` (end of line) and `sep` (separator between items) parameters in the print function are used to control the output format. `end` (default to `\n`, the newline character) controls what character(s) are printed at the end of the printed text; `sep` (default to " ") specifies the separator between the values that are passed to the print() function.

# %% [markdown]
# In the example below, we want to print the full path to your project folder by setting the `sep` parameter:
#
# ````{tab-set}
# ```{tab-item} Windows
# ```python
# >>> import os
# >>> print("C:\\", "User", os.getlogin(), "workspace", "dsm", sep="\\")
# C:\\User\tychen\workspace\dsm
# ```
#
# ```{tab-item} macOS
# ```python
# >>> import os
# >>> print("/Users", os.getlogin(), "workspace", "dsm", sep='/')
# /Users/tychen/workspace/dsm
# >>>
# ```
# ````

# %% [markdown]
# In this example below, we want to print all the output in one line (because each print output by default has a new line character at the end of the line) by setting the `end` parameter from a new line (`\n`) to a space.

# %%
for num in range(5):
    print(num)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for num in range(5):
    print(num, end=" ")
# Out:
# 0 1 2 3 4

# %%
for num in range(5):
    print(num, end=", ")
# Out:
# 0, 1, 2, 3, 4,

# %%
for num in range(5):
    print(num, end=", " if num < len(range(5)) - 1 else "\n")
# Out:
# 0, 1, 2, 3, 4

# %% [markdown]
# ## Exceptions
#
# According to [Python Documentation](https://docs.python.org/3/tutorial/errors.html), errors fall under two groups:
#
# 1. **Syntax errors**: Also known as **parsing errors**; Python detects the error when parsing/reading, namely, **before** executing your code.
# 2. **Exceptions**: Your statement or expression is syntactically correct but it causes an error when attempting to **execute**. Errors detected **during** execution are called exceptions.
#
# Another way of looking at errors and exceptions is: An error is the problem and an exception is the mechanism Python uses to report that problem. When Python encounters a problem, it raises an exception and that exception produces an error message. In this sense, **all errors are exceptions**. In Python, there are many [built-in exceptions](https://docs.python.org/3/library/exceptions.html#BaseException) and they are instances of a class that derives from `BaseException`. Uses can define their own exceptions as well.

# %% [markdown]
# For a list of all built-in exceptions, see the [Python exception hierarchy](https://docs.python.org/3/library/exceptions.html#exception-hierarchy). The Python Standard Library has a list of 38 [concret exceptions](https://docs.python.org/3/library/exceptions.html#concrete-exceptions), but you will see some of those exceptions below more often than others:
#
# | No. | Error Type            | Meaning                       |
# |-----| --------------------- | ----------------------------- |
# |  1  | `SyntaxError`         | Code is written incorrectly   |
# |  2  | `NameError`           | Variable/function not defined |
# |  3  | `TypeError`           | Wrong data type used          |
# |  4  | `ValueError`          | Type is right, value is wrong |
# |  5  | `IndexError`          | List index doesn’t exist      |
# |  6  | `KeyError`            | Dictionary key doesn’t exist  |
# |  7  | `ZeroDivisionError`   | Dividing by zero              |
# |  8  | `FileNotFoundError`   | Missing file path             |
# |  9  | `AttributeError`      | Wrong attribute for object    |
# |  10 | `ModuleNotFoundError` | Import not installed/found    |

# %% [markdown]
# ### SyntaxError
#
# You will see syntax errors when you make mistakes in the "grammar" when writing code. For example, when you miss a colon ":" or write a "0" instead of "o".

# %% [markdown]
# **SyntaxError: expectede ':'**

# %%
if x > 0                                          ### missing required colon ":"
    print("Hi")
# Out:
#   Cell In[11], line 1
#     if x > 0                                          ### missing required colon ":"
#                                                       ^
# SyntaxError: expected ':'

# %% [markdown]
# **SyntaxError: invalid decimal literal**

# %%
import os
print(f"Hello, {0s.getlogin()}! How are you?")     ### this "0" is a typo
# Out:
#   Cell In[33], line 2
#     print(f"Hello, {0s.getlogin()}! How are you?")     ### this "0" is a typo
#                     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# Fix the type (from **0** to **o**):

# %%
import os
print(f"Hello, {os.getlogin()}! How are you?")     ### change to "os" works
# Out:
# Hello, tychen! How are you?

# %% [markdown]
# Note that the `os.getlogin()` method retrieves the username that's currently logged in in the terminal.

# %% [markdown]
# ### NameError
#
# This happens a lot when a variable of a function you mention is not defined; e.g., you make a typo in the name and Python sees that as an undefined name.

# %%
print(score)       ### "score" is not defined before referenced
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(score)       ### "score" is not defined before referenced
#
# NameError: name 'score' is not defined

# %% [markdown]
# ### TypeError

# %%
age = "25"
print(age + 5)       ### concatenation is for strings only
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 age = "25"
# ----> 2 print(age + 5)       ### concatenation is for strings only
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ### ValueError

# %%
int("hello")       ### type is correct but literal value is incorrect
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 int("hello")       ### type is correct but literal value is incorrect
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
int("100")         ### literal is correct
# Out:
# 100

# %% [markdown]
# ### FileNotFoundError
#
# This usually happens when you have an incorrect path or filename.

# %%
open("notes.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 open("notes.txt")
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'notes.txt'

# %% [markdown]
# ### ZeroDivisionError
#
# Dividing by zero is not allowed and it raises an exception called ZeroDivisionError.

# %%
10 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 10 / 0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### IndexError
#
# Raised when a sequence subscript is out of range.

# %%
nums = [1, 2, 3]       ### indexes are 0, 1, and 2
print(nums[5])         ### index 5 does not exist
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 nums = [1, 2, 3]       ### indexes are 0, 1, and 2
# ----> 2 print(nums[5])         ### index 5 does not exist
#
# IndexError: list index out of range

# %% [markdown]
# ### KeyError

# %%
person = {"name": "Alice"}       ### a dictionary has key-value pairs
print(person["age"])             ### referencing a non-existent key
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 2
#       1 person = {"name": "Alice"}       ### a dictionary has key-value pairs
# ----> 2 print(person["age"])             ### referencing a non-existent key
#
# KeyError: 'age'

# %% [markdown]
# ### AttributeError

# %%
x = 3
x.append(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 2
#       1 x = 3
# ----> 2 x.append(5)
#
# AttributeError: 'int' object has no attribute 'append'

# %% [markdown]
# ### ImportError / ModuleNotFoundError
#
# When importing a module, this could happen because of a typo or because the module is not installed.

# %%
import numpyyyy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 import numpyyyy
#
# ModuleNotFoundError: No module named 'numpyyyy'
