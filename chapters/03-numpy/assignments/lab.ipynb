# %% [markdown]
# # Lab
#
# **Due:** Thursday, September 10, 2026, 11:59 PM CT.
# **Answers unlock:** after the lab due date.
#
# This lab will extend the section exercises from Chapter 3.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
#
# > Lab questions will be added here.
#
# <div data-lab-answers-release-at="2026-09-10T23:59-05:00"></div>
