# %% [markdown]
# # Pandas Plotting

# %%
import pandas as pd
import os.path as path
# %pip install matplotlib
import matplotlib.pyplot as plt
data_path = "/Users/tychen/workspace/dsm/data"
data = path.join(data_path, "data.csv")
df = pd.read_csv(data)

# %% [markdown]
# ## Simple Plot

# %%
df.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.plot()
#       2 plt.show()
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/pandas/plotting/_matplotlib/core.py:499, in MPLPlot.generate(self)
#     497 @final
#     498 def generate(self) -> None:
# --> 499     self._compute_plot_data()
#     500     fig = self.fig
#     501     self._make_plot(fig)
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/pandas/plotting/_matplotlib/core.py:698, in MPLPlot._compute_plot_data(self)
#     696 # no non-numeric frames or series allowed
#     697 if is_empty:
# --> 698     raise TypeError("no numeric data to plot")
#     700 self.data = numeric_data.apply(type(self)._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %% [markdown]
# ### Scatter Plot

# %%
df.plot(kind = 'scatter', x = 'Duration', y = 'Calories')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.plot(kind = 'scatter', x = 'Duration', y = 'Calories')
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/pandas/plotting/_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     973 if kind in self._dataframe_kinds:
#     974     if isinstance(data, ABCDataFrame):
# --> 975         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     976     else:
#     977         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/pandas/plotting/_matplotlib/core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/pandas/plotting/_matplotlib/core.py:1351, in ScatterPlot._make_plot(self, fig)
#    1349 else:
#    1350     label = None
# -> 1351 scatter = ax.scatter(
#    1352     data[x].values,
#    1353     data[y].values,
#    1354     c=c_values,
#    1355     label=label,
#    1356     cmap=cmap,
#    1357     norm=norm,
#    1358     s=self.s,
#    1359     **self.kwds,
#    1360 )
#    1361 if cb:
#    1362     cbar_label = c if c_is_column else ""
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/matplotlib/axes/_axes.py:4930, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4928 edgecolors = kwargs.pop('edgecolor', None)
#    4929 # Process **kwargs to handle aliases, conflicts with explicit kwargs:
# -> 4930 x, y = self._process_unit_info([("x", x), ("y", y)], kwargs)
#    4931 # np.ma.ravel yields an ndarray, not a masked array,
#    4932 # unless its argument is a masked array.
#    4933 x = np.ma.ravel(x)
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/matplotlib/axes/_base.py:2663, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2661     # Update from data if axis is already set but no unit is set yet.
#    2662     if axis is not None and data is not None and not axis.have_units():
# -> 2663         axis.update_units(data)
#    2664 for axis_name, axis in axis_map.items():
#    2665     # Return if no axis is set.
#    2666     if axis is None:
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/matplotlib/axis.py:1754, in Axis.update_units(self, data)
#    1752 neednew = self._converter != converter
#    1753 self._set_converter(converter)
# -> 1754 default = self._converter.default_units(data, self)
#    1755 if default is not None and self.units is None:
#    1756     self.set_units(default)
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/matplotlib/category.py:106, in StrCategoryConverter.default_units(data, axis)
#     104 # the conversion call stack is default_units -> axis_info -> convert
#     105 if axis.units is None:
# --> 106     axis.set_units(UnitData(data))
#     107 else:
#     108     axis.units.update(data)
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/matplotlib/category.py:182, in UnitData.__init__(self, data)
#     180 self._counter = itertools.count()
#     181 if data is not None:
# --> 182     self.update(data)
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/matplotlib/category.py:217, in UnitData.update(self, data)
#     214 convertible = True
#     215 for val in OrderedDict.fromkeys(data):
#     216     # OrderedDict just iterates over unique values in data.
# --> 217     _api.check_isinstance((str, bytes), value=val)
#     218     if convertible:
#     219         # this will only be called so long as convertible is True.
#     220         convertible = self._str_is_convertible(val)
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/matplotlib/_api/__init__.py:92, in check_isinstance(types, **kwargs)
#      90     names.remove("None")
#      91     names.append("None")
# ---> 92 raise TypeError(
#      93     "{!r} must be an instance of {}, not a {}".format(
#      94         k,
#      95         ", ".join(names[:-1]) + " or " + names[-1]
#      96         if len(names) > 1 else names[0],
#      97         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float

# %%
df.plot(kind = 'scatter', x = 'Duration', y = 'Maxpulse')
# Out:
# <Axes: xlabel='Duration', ylabel='Maxpulse'>

# %% [markdown]
# ### Historgram

# %%
df["Duration"].plot(kind = 'hist')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df["Duration"].plot(kind = 'hist')
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/pandas/plotting/_matplotlib/core.py:499, in MPLPlot.generate(self)
#     497 @final
#     498 def generate(self) -> None:
# --> 499     self._compute_plot_data()
#     500     fig = self.fig
#     501     self._make_plot(fig)
#
# File ~/workspace/dsm/.venv/lib/python3.13/site-packages/pandas/plotting/_matplotlib/core.py:698, in MPLPlot._compute_plot_data(self)
#     696 # no non-numeric frames or series allowed
#     697 if is_empty:
# --> 698     raise TypeError("no numeric data to plot")
#     700 self.data = numeric_data.apply(type(self)._convert_to_ndarray)
#
# TypeError: no numeric data to plot
