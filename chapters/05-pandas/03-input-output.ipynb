# %% [markdown]
# # Worksheet: Data Input and Output
#
# This section serves as the reference code for obtaining input and output with Pandas. Pandas can read a variety of file types using its **pd.read_** methods. Here we cover the most common data types:
#
# - CSV
# - Excel
# - HTML
# - SQL

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## CSV
#
# ### CSV Input

# %%
df = pd.read_csv('../../data/example')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %% [markdown]
# ### CSV Output

# %%
df.to_csv('example',index=False)
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %% [markdown]
# ## Excel
# Pandas can read and write excel files, keep in mind, this only imports data. Not formulas or images, having images or macros may cause this read_excel method to crash.

# %% [markdown]
# ### Excel Input
#
# - If you see the error message:
#
#   <code>ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.</code>
#
#   Install the dependency by issuing `%pip install openpyxl`

# %%
### install dependencies if needed
# %pip install openpyxl

# %%
### read Excel file
df = pd.read_excel('../../data/Excel_Sample.xlsx', sheet_name='Sheet1')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Excel Output

# %%
### note this output will be in the same folder as your notebook

df.to_excel('Excel_Sample.xlsx', sheet_name='Sheet1')

# %% [markdown]
# ## HTML
#
# You may need to install htmllib5,lxml, and BeautifulSoup4. In your terminal/command prompt run:
#
#     conda install lxml
#     conda install html5lib
#     conda install BeautifulSoup4
#
# Then restart Jupyter Notebook.
# (or use pip install if you aren't using the Anaconda Distribution)
#
# Pandas can read table tabs off of html. For example:

# %% [markdown]
# ### HTML Input
#
# - If you see the error message:
#
#     `ImportError: Missing optional dependency 'lxml'.  Use pip or conda to install lxml.`
#
#     Install the dependency: `%pip install lxml`
#
# - **macOS users** do this to get rid of a certificate error ([4 steps](https://stackoverflow.com/questions/68275857/urllib-error-urlerror-urlopen-error-ssl-certificate-verify-failed-certifica) in the (.venv) lines:
#     ```bash
#     (.venv) [user]@[host]ː~/workspace/dsm$ cd /Applications/Python 3.12/
# (.venv) [user]@[host]ː/Applications/Python 3.12$ ls
#         Icon?        Install Certificates.command Python Documentation.html        ReadMe.rtf
#         IDLE.app     License.rtf      Python Launcher.app Update Shell Profile.command
#     (.venv) [user]@[host]ː/Applications/Python 3.12$ ./Install\ Certificates.command
#     -- pip install --upgrade certifi
#     Collecting certifi
#       Using cached certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
#     Using cached certifi-2025.8.3-py3-none-any.whl (161 kB)
#     Installing collected packages: certifi
#     Successfully installed certifi-2025.8.3
# (.venv) [user]@[host]ː/Applications/Python 3.12$ cd ~/workspace/dsm
#     ```
#
# Pandas `read_html` function will read tables off of a webpage and return a list of DataFrame objects:

# %%
##### install dependencies if needed
# %pip install lxml
# %pip install pandas

# %%
import pandas as pd
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
df[0]
# Out:
#                                             Bank Name                City  \
# 0                        The Santa Anna National Bank          Santa Anna
# 1                                Pulaski Savings Bank             Chicago
# 2                  The First National Bank of Lindsay             Lindsay
# 3               Republic First Bank dba Republic Bank        Philadelphia
# 4                                       Citizens Bank            Sac City
# 5                            Heartland Tri-State Bank             Elkhart
# 6                                 First Republic Bank       San Francisco
# 7                                      Signature Bank            New York
# 8                                 Silicon Valley Bank         Santa Clara
# 9                                   Almena State Bank              Almena
# 10                         First City Bank of Florida   Fort Walton Beach
# 11                               The First State Bank       Barboursville
# 12                                 Ericson State Bank             Ericson
# 13                   City National Bank of New Jersey              Newark
# 14                                      Resolute Bank              Maumee
# 15                              Louisa Community Bank              Louisa
# 16                               The Enloe State Bank              Cooper
# 17                Washington Federal Bank for Savings             Chicago
# 18    The Farmers and Merchants State Bank of Argonia             Argonia
# 19                                Fayette County Bank          Saint Elmo
# 20  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 21                                     First NBC Bank         New Orleans
# 22                                      Proficio Bank  Cottonwood Heights
# 23                      Seaway Bank and Trust Company             Chicago
# 24                             Harvest Community Bank          Pennsville
#
#             State   Cert                Acquiring Institution  \
# 0           Texas   5520            Coleman County State Bank
# 1        Illinois  28611                      Millennium Bank
# 2        Oklahoma   4134               First Bank & Trust Co.
# 3    Pennsylvania  27332    Fulton Bank, National Association
# 4            Iowa   8758            Iowa Trust & Savings Bank
# 5          Kansas  25851               Dream First Bank, N.A.
# 6      California  59017            JPMorgan Chase Bank, N.A.
# 7        New York  57053                  Flagstar Bank, N.A.
# 8      California  24735  First Citizens Bank & Trust Company
# 9          Kansas  15426                          Equity Bank
# 10        Florida  16748            United Fidelity Bank, fsb
# 11  West Virginia  14361                       MVB Bank, Inc.
# 12       Nebraska  18265           Farmers and Merchants Bank
# 13     New Jersey  21111                      Industrial Bank
# 14           Ohio  58317                   Buckeye State Bank
# 15       Kentucky  58112    Kentucky Farmers Bank Corporation
# 16          Texas  10716                   Legend Bank, N. A.
# 17       Illinois  30570                   Royal Savings Bank
# 18         Kansas  17719                          Conway Bank
# 19       Illinois   1802            United Fidelity Bank, fsb
# 20      Wisconsin  30003  First-Citizens Bank & Trust Company
# 21      Louisiana  58302                         Whitney Bank
# 22           Utah  35495                    Cache Valley Bank
# 23       Illinois  19328                  State Bank of Texas
# 24     New Jersey  34951  First-Citizens Bank & Trust Company
#
#          Closing Date  Fund  Sort ascending
# 0       June 27, 2025                 10549
# 1    January 17, 2025                 10548
# 2    October 18, 2024                 10547
# 3      April 26, 2024                 10546
# 4    November 3, 2023                 10545
# 5       July 28, 2023                 10544
# 6         May 1, 2023                 10543
# 7      March 12, 2023                 10540
# 8      March 10, 2023                 10539
# 9    October 23, 2020                 10538
# 10   October 16, 2020                 10537
# 11      April 3, 2020                 10536
# 12  February 14, 2020                 10535
# 13   November 1, 2019                 10534
# 14   October 25, 2019                 10533
# 15   October 25, 2019                 10532
# 16       May 31, 2019                 10531
# 17  December 15, 2017                 10530
# 18   October 13, 2017                 10529
# 19       May 26, 2017                 10528
# 20        May 5, 2017                 10527
# 21     April 28, 2017                 10526
# 22      March 3, 2017                 10525
# 23   January 27, 2017                 10524
# 24   January 13, 2017                 10523

# %% [markdown]
# ## SQL

# %% [markdown]
# ([source](https://www.reddit.com/r/learnpython/comments/hgrekl/need_help_use_sql_on_a_dataframe_created_through/)) The pandas.io.sql module provides a collection of query wrappers to both facilitate data retrieval and to reduce dependency on DB-specific API. Database abstraction is provided by SQLAlchemy if installed. In addition you will need a driver library for your database. Examples of such drivers are psycopg2 for PostgreSQL or pymysql for MySQL. For SQLite this is included in Python’s standard library by default. You can find an overview of supported drivers for each SQL dialect in the SQLAlchemy docs.
#
#
# If SQLAlchemy is not installed, a fallback is only provided for sqlite (and for mysql for backwards compatibility, but this is deprecated and will be removed in a future version). This mode requires a Python database adapter which respect the Python DB-API.
#
# See also some cookbook examples for some advanced strategies.
#
# The key functions are:
#
# * read_sql_table(table_name, con[, schema, ...])
#     * Read SQL database table into a DataFrame.
# * read_sql_query(sql, con[, index_col, ...])
#     * Read SQL query into a DataFrame.
# * read_sql(sql, con[, index_col, ...])
#     * Read SQL query or database table into a DataFrame.
# * DataFrame.to_sql(name, con[, flavor, ...])
#     * Write records stored in a DataFrame to a SQL database.

# %%
# %pip install SQLAlchemy
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
print(type(df))
df = pd.DataFrame(df[0])
# Out:
# <class 'list'>

# %%
df.to_sql('data', engine)
# Out:
# 25

# %%
sql_df = pd.read_sql('data',con=engine)

# %%
sql_df
# Out:
#     index                                          Bank Name  \
# 0       0                       The Santa Anna National Bank
# 1       1                               Pulaski Savings Bank
# 2       2                 The First National Bank of Lindsay
# 3       3              Republic First Bank dba Republic Bank
# 4       4                                      Citizens Bank
# 5       5                           Heartland Tri-State Bank
# 6       6                                First Republic Bank
# 7       7                                     Signature Bank
# 8       8                                Silicon Valley Bank
# 9       9                                  Almena State Bank
# 10     10                         First City Bank of Florida
# 11     11                               The First State Bank
# 12     12                                 Ericson State Bank
# 13     13                   City National Bank of New Jersey
# 14     14                                      Resolute Bank
# 15     15                              Louisa Community Bank
# 16     16                               The Enloe State Bank
# 17     17                Washington Federal Bank for Savings
# 18     18    The Farmers and Merchants State Bank of Argonia
# 19     19                                Fayette County Bank
# 20     20  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...
# 21     21                                     First NBC Bank
# 22     22                                      Proficio Bank
# 23     23                      Seaway Bank and Trust Company
# 24     24                             Harvest Community Bank
#
#                   City          State   Cert  \
# 0           Santa Anna          Texas   5520
# 1              Chicago       Illinois  28611
# 2              Lindsay       Oklahoma   4134
# 3         Philadelphia   Pennsylvania  27332
# 4             Sac City           Iowa   8758
# 5              Elkhart         Kansas  25851
# 6        San Francisco     California  59017
# 7             New York       New York  57053
# 8          Santa Clara     California  24735
# 9               Almena         Kansas  15426
# 10   Fort Walton Beach        Florida  16748
# 11       Barboursville  West Virginia  14361
# 12             Ericson       Nebraska  18265
# 13              Newark     New Jersey  21111
# 14              Maumee           Ohio  58317
# 15              Louisa       Kentucky  58112
# 16              Cooper          Texas  10716
# 17             Chicago       Illinois  30570
# 18             Argonia         Kansas  17719
# 19          Saint Elmo       Illinois   1802
# 20           Milwaukee      Wisconsin  30003
# 21         New Orleans      Louisiana  58302
# 22  Cottonwood Heights           Utah  35495
# 23             Chicago       Illinois  19328
# 24          Pennsville     New Jersey  34951
#
#                   Acquiring Institution       Closing Date  \
# 0             Coleman County State Bank      June 27, 2025
# 1                       Millennium Bank   January 17, 2025
# 2                First Bank & Trust Co.   October 18, 2024
# 3     Fulton Bank, National Association     April 26, 2024
# 4             Iowa Trust & Savings Bank   November 3, 2023
# 5                Dream First Bank, N.A.      July 28, 2023
# 6             JPMorgan Chase Bank, N.A.        May 1, 2023
# 7                   Flagstar Bank, N.A.     March 12, 2023
# 8   First Citizens Bank & Trust Company     March 10, 2023
# 9                           Equity Bank   October 23, 2020
# 10            United Fidelity Bank, fsb   October 16, 2020
# 11                       MVB Bank, Inc.      April 3, 2020
# 12           Farmers and Merchants Bank  February 14, 2020
# 13                      Industrial Bank   November 1, 2019
# 14                   Buckeye State Bank   October 25, 2019
# 15    Kentucky Farmers Bank Corporation   October 25, 2019
# 16                   Legend Bank, N. A.       May 31, 2019
# 17                   Royal Savings Bank  December 15, 2017
# 18                          Conway Bank   October 13, 2017
# 19            United Fidelity Bank, fsb       May 26, 2017
# 20  First-Citizens Bank & Trust Company        May 5, 2017
# 21                         Whitney Bank     April 28, 2017
# 22                    Cache Valley Bank      March 3, 2017
# 23                  State Bank of Texas   January 27, 2017
# 24  First-Citizens Bank & Trust Company   January 13, 2017
#
#     Fund  Sort ascending
# 0                  10549
# 1                  10548
# 2                  10547
# 3                  10546
# 4                  10545
# 5                  10544
# 6                  10543
# 7                  10540
# 8                  10539
# 9                  10538
# 10                 10537
# 11                 10536
# 12                 10535
# 13                 10534
# 14                 10533
# 15                 10532
# 16                 10531
# 17                 10530
# 18                 10529
# 19                 10528
# 20                 10527
# 21                 10526
# 22                 10525
# 23                 10524
# 24                 10523
