# %%
import os.path as path
print($HOME)
# Out:
#   Cell In[12], line 2
#     print($HOME)
#           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import os.path as path
data_path = "$HOME/workspace/dsm/data/"
data = path.join(data_path, "data.csv")
with open(data) as f:
    df = pd.read_csv(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 5
#       3 data_path = "$HOME/workspace/dsm/data/"
#       4 data = path.join(data_path, "data.csv")
# ----> 5 with open(data) as f:
#       6     df = pd.read_csv(f)
#
# File ~/workspace/thinkdsm/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '$HOME/workspace/dsm/data/data.csv'
