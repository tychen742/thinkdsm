# %% [markdown]
# # Homework
#
# - Use these questions after class to check your understanding of the chapter concepts and coding skills.
# - Sign in from the account menu before you start working on the homework.
# - Complete all true/false and coding questions before you submit the homework.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
# - Multiple submissions are allowed. The highest score is kept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **1. Null Hypothesis**
#
# **True or False:** A null hypothesis can state that a hiring process follows the stated selection model.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 1 answer">
#   <label><input type="radio" name="ch09-hw-q1" value="true"> True</label>
#   <label><input type="radio" name="ch09-hw-q1" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# The null is the model or claim tested against data.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **2. Test Statistic**
#
# **True or False:** A test statistic should summarize the kind of difference that would count as evidence against the null model.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 2 answer">
#   <label><input type="radio" name="ch09-hw-q2" value="true"> True</label>
#   <label><input type="radio" name="ch09-hw-q2" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# The statistic should match the question.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **3. P-value**
#
# **True or False:** A p-value is the probability that the null hypothesis is true.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 3 answer">
#   <label><input type="radio" name="ch09-hw-q3" value="true"> True</label>
#   <label><input type="radio" name="ch09-hw-q3" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# A p-value measures how extreme the observed statistic is under the null model.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **4. Simulation**
#
# **True or False:** Simulating many outcomes under the null model can create a reference distribution for comparison.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 4 answer">
#   <label><input type="radio" name="ch09-hw-q4" value="true"> True</label>
#   <label><input type="radio" name="ch09-hw-q4" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Null simulations show what the model tends to produce.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **5. Cutoff**
#
# **True or False:** A cutoff such as 0.05 removes all need for judgment about data quality and context.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 5 answer">
#   <label><input type="radio" name="ch09-hw-q5" value="true"> True</label>
#   <label><input type="radio" name="ch09-hw-q5" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# Statistical cutoffs do not replace context or data-quality checks.

# %%
### 6. Absolute Test Statistic
# Calculate an absolute difference as a test statistic.
# Print exactly:
# Test statistic: 6
observed = 44
expected = 50

### Your code starts here.



### Your code ends here.

# %%
### Solution
observed = 44
expected = 50
difference = observed - expected
if difference < 0:
    difference = -difference
print("Test statistic:", difference)
# Out:
# Test statistic: 6

# %%
### 7. Null Simulation Count
# Count simulated values greater than or equal to the observed value.
# Print exactly:
# Tail count: 3
observed = 5
simulated = [1, 5, 7, 3, 8]

### Your code starts here.



### Your code ends here.

# %%
### Solution
observed = 5
simulated = [1, 5, 7, 3, 8]
tail_count = 0
for value in simulated:
    if value >= observed:
        tail_count = tail_count + 1
print("Tail count:", tail_count)
# Out:
# Tail count: 3

# %%
### 8. P-value Interpretation
# Convert a p-value into a short evidence label.
# Print exactly:
# Evidence: weak
p_value = 0.12

### Your code starts here.



### Your code ends here.

# %%
### Solution
p_value = 0.12
if p_value < 0.05:
    evidence = "strong"
else:
    evidence = "weak"
print("Evidence:", evidence)
# Out:
# Evidence: weak

# %%
### 9. Category Distance
# Calculate total absolute difference between two category distributions.
# Print exactly:
# Distance: 0.1
observed = [0.50, 0.30, 0.20]
expected = [0.45, 0.35, 0.20]

### Your code starts here.



### Your code ends here.

# %%
### Solution
observed = [0.50, 0.30, 0.20]
expected = [0.45, 0.35, 0.20]
distance = 0
index = 0
for value in observed:
    difference = value - expected[index]
    if difference < 0:
        difference = -difference
    distance = distance + difference
    index = index + 1
print("Distance:", round(distance, 1))
# Out:
# Distance: 0.1

# %%
### 10. Decision Summary
# Build a decision summary from the p-value cutoff.
# Print exactly:
# Reject null: True
p_value = 0.02
cutoff = 0.05

### Your code starts here.



### Your code ends here.

# %%
### Solution
p_value = 0.02
cutoff = 0.05
reject_null = p_value < cutoff
print("Reject null:", reject_null)
# Out:
# Reject null: True

# %% [markdown]
# <style>
# .ch09-hw-grader { max-width: 900px; margin-top: 1rem; }
# .ch09-hw-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch09-hw-feedback-list[hidden] { display: none; }
# .ch09-hw-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch09-hw-feedback-row strong { margin-right: 0.35rem; }
# .ch09-hw-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch09-hw-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch09-hw-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch09-hw-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch09-hw-actions button.secondary { background: white; color: #176de8; }
# .ch09-hw-actions.is-locked { opacity: 0.55; }
# .ch09-hw-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch09-hw-result { font-weight: 700; }
# </style>
#
# <div class='ch09-hw-grader' id='ch09-hw-grader'>
#   <div class='ch09-hw-feedback-list' aria-live='polite' hidden>
#     <div class='ch09-hw-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch09-hw-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch09-hw-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch09-hw-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch09-hw-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#     <div class='ch09-hw-feedback-row' data-question='q6'><strong>Question 6</strong><span></span></div>
#     <div class='ch09-hw-feedback-row' data-question='q7'><strong>Question 7</strong><span></span></div>
#     <div class='ch09-hw-feedback-row' data-question='q8'><strong>Question 8</strong><span></span></div>
#     <div class='ch09-hw-feedback-row' data-question='q9'><strong>Question 9</strong><span></span></div>
#     <div class='ch09-hw-feedback-row' data-question='q10'><strong>Question 10</strong><span></span></div>
#   </div>
#   <div class='ch09-hw-actions'>
#     <button type='button' id='ch09-hw-submit' disabled>Submit</button>
#     <button type='button' class='secondary' id='ch09-hw-reset'>Clear Results</button>
#     <span class='ch09-hw-result' id='ch09-hw-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var homeworkId = 'ch09-homework';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var cm = cell.querySelector('.CodeMirror');
#     if (cm && cm.CodeMirror && typeof cm.CodeMirror.getValue === 'function') return cm.CodeMirror.getValue();
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent && cmContent.cmView && cmContent.cmView.view) return cmContent.cmView.view.state.doc.toString();
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.prototype.slice.call(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 6)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function collectAnswers() {
#     var answers = {};
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var checked = document.querySelector('input[name="ch09-hw-' + question + '"]:checked');
#       answers[question] = checked ? checked.value : '';
#     });
#     return answers;
#   }
#
#   function applyFeedback(grader, feedback) {
#     var list = grader.querySelector('.ch09-hw-feedback-list');
#     list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9', 'q10'].forEach(function (question) {
#       var row = grader.querySelector('[data-question=' + question + ']');
#       var message = row.querySelector('span');
#       var item = feedback[question];
#       row.className = 'ch09-hw-feedback-row';
#       if (!item) return;
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(grader) {
#     var list = grader.querySelector('.ch09-hw-feedback-list');
#     list.hidden = true;
#     grader.querySelectorAll('.ch09-hw-feedback-row').forEach(function (row) {
#       row.className = 'ch09-hw-feedback-row';
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/homework-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var payload = text ? JSON.parse(text) : null;
#         if (!payload || !response.ok || !payload.ok) {
#           throw new Error((payload && (payload.message || payload.error)) || 'Submission API is unavailable.');
#         }
#         return payload;
#       });
#     });
#   }
#
#   function initHomeworkGrader() {
#     var grader = document.getElementById('ch09-hw-grader');
#     if (!grader || grader.dataset.ready === 'true') return;
#     grader.dataset.ready = 'true';
#
#     var identity = getParams();
#     var actions = grader.querySelector('.ch09-hw-actions');
#     var result = document.getElementById('ch09-hw-result');
#     var submit = document.getElementById('ch09-hw-submit');
#     var reset = document.getElementById('ch09-hw-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(grader);
#       submit.disabled = true;
#       result.textContent = 'Submitting homework.';
#
#       saveAttempt({
#         homework_id: homeworkId,
#         answers: collectAnswers(),
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           applyFeedback(grader, payload.feedback || {});
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(grader);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initHomeworkGrader);
#   } else {
#     initHomeworkGrader();
#   }
# })();
# </script>
