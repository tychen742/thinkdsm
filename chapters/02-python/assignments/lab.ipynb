# %% [markdown]
# # Lab
#
# - Use this lab to practice the chapter's coding skills in runnable Python code.
# - Sign in from the account menu before you start working on the lab.
# - Multiple submissions are allowed. The highest score is kept.
#
# <div data-lab-answers-release-at="2026-09-03T23:59-05:00"></div>

# %%
### Question 1: Order Totals
# A manager is reviewing one customer order.
# Calculate subtotal, discount, and final_total from the variables below.
# Print exactly:
# Subtotal: 180
# Discount: 18.0
# Final total: 162.0
unit_price = 45
quantity = 4
discount_rate = 0.10
### Your code starts here.



### Your code ends here.

# %%
### Solution
unit_price = 45
quantity = 4
discount_rate = 0.10

subtotal = unit_price * quantity
discount = subtotal * discount_rate
final_total = subtotal - discount

print("Subtotal:", subtotal)
print("Discount:", discount)
print("Final total:", final_total)

# %%
### Question 2: Reorder Decision
# Use an if/else statement to decide whether the store should reorder.
# If inventory is less than reorder_point, set decision to "Reorder".
# Otherwise, set decision to "Wait".
# Print exactly:
# Decision: Reorder
inventory = 8
reorder_point = 10
### Your code starts here.



### Your code ends here.

# %%
### Solution
inventory = 8
reorder_point = 10

if inventory < reorder_point:
    decision = "Reorder"
else:
    decision = "Wait"

print("Decision:", decision)

# %%
### Question 3: High Sales List
# Use a loop and append() to build a list of sales above the target.
# Store the result in high_sales.
# Print exactly:
# High sales: [340, 410]
# First high sale: 340
sales = [340, 280, 410]
target = 300
### Your code starts here.



### Your code ends here.

# %%
### Solution
sales = [340, 280, 410]
target = 300

high_sales = []
for sale in sales:
    if sale > target:
        high_sales.append(sale)

print("High sales:", high_sales)
print("First high sale:", high_sales[0])

# %%
### Question 4: Department Counts
# Count how many employees appear in each department.
# Store the counts in a dictionary named department_counts.
# Print exactly:
# Sales count: 3
# HR count: 1
departments = ["Sales", "HR", "Sales", "Ops", "Sales"]
### Your code starts here.



### Your code ends here.

# %%
### Solution
departments = ["Sales", "HR", "Sales", "Ops", "Sales"]

department_counts = {}
for department in departments:
    department_counts[department] = department_counts.get(department, 0) + 1

print("Sales count:", department_counts["Sales"])
print("HR count:", department_counts["HR"])

# %%
### Question 5: Reusable Margin Function
# Define a function named calculate_margin that takes revenue and cost.
# The function should return revenue minus cost.
# Call it with revenue 1250 and cost 875.
# Print exactly:
# Margin: 375
def calculate_margin(revenue, cost):
    ### Your code starts here.
    pass
    ### Your code ends here.

margin = calculate_margin(1250, 875)
print("Margin:", margin)

# %%
### Solution
def calculate_margin(revenue, cost):
    return revenue - cost

margin = calculate_margin(1250, 875)
print("Margin:", margin)

# %% [markdown]
# <style>
# .ch02-lab-grader { max-width: 900px; margin-top: 1rem; }
# .ch02-lab-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch02-lab-feedback-list[hidden] { display: none; }
# .ch02-lab-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch02-lab-feedback-row strong { margin-right: 0.35rem; }
# .ch02-lab-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch02-lab-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch02-lab-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch02-lab-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch02-lab-actions button.secondary { background: white; color: #176de8; }
# .ch02-lab-actions.is-locked { opacity: 0.55; }
# .ch02-lab-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch02-lab-result { font-weight: 700; }
# </style>
#
# <div class='ch02-lab-grader' id='ch02-lab-grader'>
#   <div class='ch02-lab-feedback-list' aria-live='polite' hidden>
#     <div class='ch02-lab-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch02-lab-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch02-lab-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch02-lab-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch02-lab-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#   </div>
#   <div class='ch02-lab-actions'>
#     <button type='button' id='ch02-lab-submit'>Submit Code</button>
#     <button type='button' class='secondary' id='ch02-lab-reset'>Clear Results</button>
#     <span class='ch02-lab-result' id='ch02-lab-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var labId = 'ch02-lab';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var cm = cell.querySelector('.CodeMirror');
#     if (cm && cm.CodeMirror && typeof cm.CodeMirror.getValue === 'function') return cm.CodeMirror.getValue();
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent && cmContent.cmView && cmContent.cmView.view) return cmContent.cmView.view.state.doc.toString();
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.prototype.slice.call(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 1)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function applyFeedback(grader, feedback) {
#     var list = grader.querySelector('.ch02-lab-feedback-list');
#     list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var row = grader.querySelector('[data-question=' + question + ']');
#       var message = row.querySelector('span');
#       var item = feedback[question];
#       row.className = 'ch02-lab-feedback-row';
#       if (!item) return;
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(grader) {
#     var list = grader.querySelector('.ch02-lab-feedback-list');
#     list.hidden = true;
#     grader.querySelectorAll('.ch02-lab-feedback-row').forEach(function (row) {
#       row.className = 'ch02-lab-feedback-row';
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/lab-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var payload = text ? JSON.parse(text) : null;
#         if (!payload || !response.ok || !payload.ok) {
#           throw new Error((payload && (payload.message || payload.error)) || 'Submission API is unavailable.');
#         }
#         return payload;
#       });
#     });
#   }
#
#   function initLabGrader() {
#     var grader = document.getElementById('ch02-lab-grader');
#     if (!grader || grader.dataset.ready === 'true') return;
#     grader.dataset.ready = 'true';
#
#     var identity = getParams();
#     var actions = grader.querySelector('.ch02-lab-actions');
#     var result = document.getElementById('ch02-lab-result');
#     var submit = document.getElementById('ch02-lab-submit');
#     var reset = document.getElementById('ch02-lab-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(grader);
#       submit.disabled = true;
#       result.textContent = 'Submitting code.';
#
#       saveAttempt({
#         lab_id: labId,
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           applyFeedback(grader, payload.feedback || {});
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(grader);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initLabGrader);
#   } else {
#     initLabGrader();
#   }
# })();
# </script>
