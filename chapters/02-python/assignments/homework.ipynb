# %% [markdown]
# # Homework
#
# - Use these questions after class to check your understanding of the chapter concepts and coding skills.
# - Sign in from the account menu before you start working on the homework.
# - Complete all true/false and coding questions before you submit the homework.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
# - Multiple submissions are allowed. The highest score is kept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **1. List Indexing**
#
# If `departments = ["Sales", "HR", "Ops"]`, then `departments[0]` refers to `"Sales"`.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 1 answer">
#   <label><input type="radio" name="ch02-hw-q1" value="true"> True</label>
#   <label><input type="radio" name="ch02-hw-q1" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Python lists use zero-based indexing, so index 0 refers to the first item.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **2. String and Number Operations**
#
# A dashboard import reads quantity as the string `"12"`. Python will always treat `"12" + 3` as the number 15 without conversion.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 2 answer">
#   <label><input type="radio" name="ch02-hw-q2" value="true"> True</label>
#   <label><input type="radio" name="ch02-hw-q2" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# The string must be converted with a function such as `int()` before numeric addition.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **3. Conditional Business Rules**
#
# An inventory script uses an `if` statement to reorder only when inventory is below the reorder point. This is a reasonable use of conditional logic.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 3 answer">
#   <label><input type="radio" name="ch02-hw-q3" value="true"> True</label>
#   <label><input type="radio" name="ch02-hw-q3" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# The program chooses a branch based on whether the business condition is true.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **4. Looping Through Sales**
#
# A `for` loop over a list of daily sales is useful when the same calculation should run once for each day.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 4 answer">
#   <label><input type="radio" name="ch02-hw-q4" value="true"> True</label>
#   <label><input type="radio" name="ch02-hw-q4" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# A `for` loop repeats work for each item in a collection.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **5. Dictionary Keys**
#
# A dictionary that stores product prices must use only integer keys; text keys such as product names are invalid.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 5 answer">
#   <label><input type="radio" name="ch02-hw-q5" value="true"> True</label>
#   <label><input type="radio" name="ch02-hw-q5" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# Python dictionaries can use strings as keys, which is common for labels such as product names.

# %%
### 6. Format a Revenue Message
# Use the variables below to calculate profit and print exactly:
# East profit: 375
region = "East"
revenue = 1250
cost = 875

### Your code starts here.



### Your code ends here.

# %%
### Solution
region = "East"
revenue = 1250
cost = 875

profit = revenue - cost
print(f"{region} profit: {profit}")
# Out:
# East profit: 375

# %%
### 7. Classify Customer Volume
# Use if/elif/else to classify the customer count.
# Set segment to "high" when customers is at least 100,
# "medium" when customers is at least 50, and "low" otherwise.
# Print exactly:
# Segment: medium
customers = 72

### Your code starts here.



### Your code ends here.

# %%
### Solution
customers = 72

if customers >= 100:
    segment = "high"
elif customers >= 50:
    segment = "medium"
else:
    segment = "low"

print("Segment:", segment)
# Out:
# Segment: medium

# %%
### 8. Count Until Closing
# Use a while loop to add customer counts until the sentinel value 0 appears.
# Print exactly:
# Days counted: 2
# Customers before closing: 80
daily_customers = [42, 38, 0, 51]

### Your code starts here.



### Your code ends here.

# %%
### Solution
daily_customers = [42, 38, 0, 51]

index = 0
days_counted = 0
customers_before_closing = 0
while daily_customers[index] != 0:
    customers_before_closing += daily_customers[index]
    days_counted += 1
    index += 1

print("Days counted:", days_counted)
print("Customers before closing:", customers_before_closing)
# Out:
# Days counted: 2
# Customers before closing: 80

# %%
### 9. Count Product Categories
# Count each category in the purchases list using a dictionary.
# Print exactly:
# Software purchases: 3
# Service purchases: 2
purchases = ["Software", "Service", "Software", "Hardware", "Service", "Software"]

### Your code starts here.



### Your code ends here.

# %%
### Solution
purchases = ["Software", "Service", "Software", "Hardware", "Service", "Software"]

category_counts = {}
for category in purchases:
    category_counts[category] = category_counts.get(category, 0) + 1

print("Software purchases:", category_counts["Software"])
print("Service purchases:", category_counts["Service"])
# Out:
# Software purchases: 3
# Service purchases: 2

# %%
### 10. Reusable Revenue Per Employee
# Define revenue_per_employee(revenue, employees).
# Return revenue divided by employees.
# Print exactly:
# Revenue per employee: 250.0
def revenue_per_employee(revenue, employees):
    ### Your code starts here.
    pass
    ### Your code ends here.

metric = revenue_per_employee(5000, 20)
print("Revenue per employee:", metric)

# %%
### Solution
def revenue_per_employee(revenue, employees):
    return revenue / employees

metric = revenue_per_employee(5000, 20)
print("Revenue per employee:", metric)
# Out:
# Revenue per employee: 250.0

# %% [markdown]
# <style>
# .ch02-hw-grader { max-width: 900px; margin-top: 1rem; }
# .ch02-hw-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch02-hw-feedback-list[hidden] { display: none; }
# .ch02-hw-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch02-hw-feedback-row strong { margin-right: 0.35rem; }
# .ch02-hw-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch02-hw-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch02-hw-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch02-hw-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch02-hw-actions button.secondary { background: white; color: #176de8; }
# .ch02-hw-actions.is-locked { opacity: 0.55; }
# .ch02-hw-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch02-hw-result { font-weight: 700; }
# </style>
#
# <div class='ch02-hw-grader' id='ch02-hw-grader'>
#   <div class='ch02-hw-feedback-list' aria-live='polite' hidden>
#     <div class='ch02-hw-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch02-hw-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch02-hw-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch02-hw-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch02-hw-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#     <div class='ch02-hw-feedback-row' data-question='q6'><strong>Question 6</strong><span></span></div>
#     <div class='ch02-hw-feedback-row' data-question='q7'><strong>Question 7</strong><span></span></div>
#     <div class='ch02-hw-feedback-row' data-question='q8'><strong>Question 8</strong><span></span></div>
#     <div class='ch02-hw-feedback-row' data-question='q9'><strong>Question 9</strong><span></span></div>
#     <div class='ch02-hw-feedback-row' data-question='q10'><strong>Question 10</strong><span></span></div>
#   </div>
#   <div class='ch02-hw-actions'>
#     <button type='button' id='ch02-hw-submit' disabled>Submit</button>
#     <button type='button' class='secondary' id='ch02-hw-reset'>Clear Results</button>
#     <span class='ch02-hw-result' id='ch02-hw-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var homeworkId = 'ch02-homework';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var cm = cell.querySelector('.CodeMirror');
#     if (cm && cm.CodeMirror && typeof cm.CodeMirror.getValue === 'function') return cm.CodeMirror.getValue();
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent && cmContent.cmView && cmContent.cmView.view) return cmContent.cmView.view.state.doc.toString();
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.prototype.slice.call(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 6)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function collectAnswers() {
#     var answers = {};
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var checked = document.querySelector('input[name="ch02-hw-' + question + '"]:checked');
#       answers[question] = checked ? checked.value : '';
#     });
#     return answers;
#   }
#
#   function applyFeedback(grader, feedback) {
#     var list = grader.querySelector('.ch02-hw-feedback-list');
#     list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9', 'q10'].forEach(function (question) {
#       var row = grader.querySelector('[data-question=' + question + ']');
#       var message = row.querySelector('span');
#       var item = feedback[question];
#       row.className = 'ch02-hw-feedback-row';
#       if (!item) return;
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(grader) {
#     var list = grader.querySelector('.ch02-hw-feedback-list');
#     list.hidden = true;
#     grader.querySelectorAll('.ch02-hw-feedback-row').forEach(function (row) {
#       row.className = 'ch02-hw-feedback-row';
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/homework-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var payload = text ? JSON.parse(text) : null;
#         if (!payload || !response.ok || !payload.ok) {
#           throw new Error((payload && (payload.message || payload.error)) || 'Submission API is unavailable.');
#         }
#         return payload;
#       });
#     });
#   }
#
#   function initHomeworkGrader() {
#     var grader = document.getElementById('ch02-hw-grader');
#     if (!grader || grader.dataset.ready === 'true') return;
#     grader.dataset.ready = 'true';
#
#     var identity = getParams();
#     var actions = grader.querySelector('.ch02-hw-actions');
#     var result = document.getElementById('ch02-hw-result');
#     var submit = document.getElementById('ch02-hw-submit');
#     var reset = document.getElementById('ch02-hw-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(grader);
#       submit.disabled = true;
#       result.textContent = 'Submitting homework.';
#
#       saveAttempt({
#         homework_id: homeworkId,
#         answers: collectAnswers(),
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           applyFeedback(grader, payload.feedback || {});
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(grader);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initHomeworkGrader);
#   } else {
#     initHomeworkGrader();
#   }
# })();
# </script>
