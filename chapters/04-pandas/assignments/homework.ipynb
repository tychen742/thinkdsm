# %% [markdown]
# # Homework
#
# - Use these questions after class to check your understanding of the chapter concepts and coding skills.
# - Sign in from the account menu before you start working on the homework.
# - Complete all true/false and coding questions before you submit the homework.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
# - Multiple submissions are allowed. The highest score is kept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **1. Series Labels**
#
# **True or False:** A regional sales Series can use store names as index labels instead of only integer positions.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 1 answer">
#   <label><input type="radio" name="ch04-hw-q1" value="true"> True</label>
#   <label><input type="radio" name="ch04-hw-q1" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Series objects support labeled indexes, which make business values easier to identify.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **2. DataFrame Column Types**
#
# **True or False:** Every column in a pandas DataFrame must use the same data type as every other column.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 2 answer">
#   <label><input type="radio" name="ch04-hw-q2" value="true"> True</label>
#   <label><input type="radio" name="ch04-hw-q2" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# A DataFrame can hold different dtypes in different columns.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **3. Previewing Data**
#
# **True or False:** Calling `head()` is mainly used to preview rows; it does not clean or transform the DataFrame by itself.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 3 answer">
#   <label><input type="radio" name="ch04-hw-q3" value="true"> True</label>
#   <label><input type="radio" name="ch04-hw-q3" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# `head()` displays rows so you can inspect a table before analysis.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **4. Missing Data Checks**
#
# **True or False:** A manager can use `isna()` to count incomplete values before deciding whether to drop or fill them.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 4 answer">
#   <label><input type="radio" name="ch04-hw-q4" value="true"> True</label>
#   <label><input type="radio" name="ch04-hw-q4" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# `isna()` returns a missing-value mask that can be counted or inspected.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **5. Grouped Summaries**
#
# **True or False:** A GroupBy operation can summarize revenue by region only after the data has been converted to a Python list.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 5 answer">
#   <label><input type="radio" name="ch04-hw-q5" value="true"> True</label>
#   <label><input type="radio" name="ch04-hw-q5" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# GroupBy works directly on pandas Series and DataFrame objects.

# %%
### 6. Create a Customer Table
# Create a DataFrame named customers with columns name and purchases.
# Print exactly:
# Customer rows: 3
# Purchase total: 12
import pandas as pd
names = ["Ana", "Bo", "Cy"]
purchases = [5, 3, 4]
### Your code starts here.



### Your code ends here.

# %%
### Solution
import pandas as pd
names = ["Ana", "Bo", "Cy"]
purchases = [5, 3, 4]

customers = pd.DataFrame({"name": names, "purchases": purchases})
print("Customer rows:", customers.shape[0])
print("Purchase total:", customers["purchases"].sum())
# Out:
# Customer rows: 3
# Purchase total: 12

# %%
### 7. Select a Column Summary
# Use the DataFrame below to calculate the average order value.
# Print exactly:
# Average order: 35.0
import pandas as pd
orders = pd.DataFrame({"order_id": [101, 102, 103], "value": [30, 45, 30]})
### Your code starts here.



### Your code ends here.

# %%
### Solution
import pandas as pd
orders = pd.DataFrame({"order_id": [101, 102, 103], "value": [30, 45, 30]})

average_order = orders["value"].mean()
print("Average order:", average_order)
# Out:
# Average order: 35.0

# %%
### 8. Use Label and Position Selection
# Use .loc[] to get West revenue and .iloc[] to get the first region.
# Print exactly:
# West revenue: 900
# First region: East
import pandas as pd
revenue = pd.DataFrame({"region": ["East", "West", "North"], "revenue": [1200, 900, 1400]}).set_index("region")
### Your code starts here.



### Your code ends here.

# %%
### Solution
import pandas as pd
revenue = pd.DataFrame({"region": ["East", "West", "North"], "revenue": [1200, 900, 1400]}).set_index("region")

print("West revenue:", revenue.loc["West", "revenue"])
print("First region:", revenue.index[0])
# Out:
# West revenue: 900
# First region: East

# %%
### 9. Fill Missing Ratings
# Fill missing ratings with 0, then calculate the total.
# Print exactly:
# Missing ratings: 1
# Rating total: 8
import pandas as pd
survey = pd.DataFrame({"rating": [5, None, 3]})
### Your code starts here.



### Your code ends here.

# %%
### Solution
import pandas as pd
survey = pd.DataFrame({"rating": [5, None, 3]})

missing_ratings = survey["rating"].isna().sum()
filled = survey["rating"].fillna(0)
print("Missing ratings:", missing_ratings)
print("Rating total:", int(filled.sum()))
# Out:
# Missing ratings: 1
# Rating total: 8

# %%
### 10. Merge Product Tables
# Merge products and prices on sku.
# Print exactly:
# Matched rows: 2
# Pen price: 2.5
import pandas as pd
products = pd.DataFrame({"sku": ["A1", "B2"], "product": ["Pen", "Notebook"]})
prices = pd.DataFrame({"sku": ["A1", "B2"], "price": [2.5, 5.0]})
### Your code starts here.



### Your code ends here.

# %%
### Solution
import pandas as pd
products = pd.DataFrame({"sku": ["A1", "B2"], "product": ["Pen", "Notebook"]})
prices = pd.DataFrame({"sku": ["A1", "B2"], "price": [2.5, 5.0]})

merged = products.merge(prices, on="sku")
print("Matched rows:", merged.shape[0])
print("Pen price:", merged.loc[merged["product"] == "Pen", "price"].iloc[0])
# Out:
# Matched rows: 2
# Pen price: 2.5

# %% [markdown]
# <style>
# .ch04-hw-grader { max-width: 900px; margin-top: 1rem; }
# .ch04-hw-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch04-hw-feedback-list[hidden] { display: none; }
# .ch04-hw-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch04-hw-feedback-row strong { margin-right: 0.35rem; }
# .ch04-hw-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch04-hw-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch04-hw-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch04-hw-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch04-hw-actions button.secondary { background: white; color: #176de8; }
# .ch04-hw-actions.is-locked { opacity: 0.55; }
# .ch04-hw-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch04-hw-result { font-weight: 700; }
# </style>
#
# <div class='ch04-hw-grader' id='ch04-hw-grader'>
#   <div class='ch04-hw-feedback-list' aria-live='polite' hidden>
#     <div class='ch04-hw-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch04-hw-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch04-hw-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch04-hw-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch04-hw-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#     <div class='ch04-hw-feedback-row' data-question='q6'><strong>Question 6</strong><span></span></div>
#     <div class='ch04-hw-feedback-row' data-question='q7'><strong>Question 7</strong><span></span></div>
#     <div class='ch04-hw-feedback-row' data-question='q8'><strong>Question 8</strong><span></span></div>
#     <div class='ch04-hw-feedback-row' data-question='q9'><strong>Question 9</strong><span></span></div>
#     <div class='ch04-hw-feedback-row' data-question='q10'><strong>Question 10</strong><span></span></div>
#   </div>
#   <div class='ch04-hw-actions'>
#     <button type='button' id='ch04-hw-submit' disabled>Submit</button>
#     <button type='button' class='secondary' id='ch04-hw-reset'>Clear Results</button>
#     <span class='ch04-hw-result' id='ch04-hw-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var homeworkId = 'ch04-homework';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var cm = cell.querySelector('.CodeMirror');
#     if (cm && cm.CodeMirror && typeof cm.CodeMirror.getValue === 'function') return cm.CodeMirror.getValue();
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent && cmContent.cmView && cmContent.cmView.view) return cmContent.cmView.view.state.doc.toString();
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.prototype.slice.call(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 6)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function collectAnswers() {
#     var answers = {};
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var checked = document.querySelector('input[name="ch04-hw-' + question + '"]:checked');
#       answers[question] = checked ? checked.value : '';
#     });
#     return answers;
#   }
#
#   function applyFeedback(grader, feedback) {
#     var list = grader.querySelector('.ch04-hw-feedback-list');
#     list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9', 'q10'].forEach(function (question) {
#       var row = grader.querySelector('[data-question=' + question + ']');
#       var message = row.querySelector('span');
#       var item = feedback[question];
#       row.className = 'ch04-hw-feedback-row';
#       if (!item) return;
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(grader) {
#     var list = grader.querySelector('.ch04-hw-feedback-list');
#     list.hidden = true;
#     grader.querySelectorAll('.ch04-hw-feedback-row').forEach(function (row) {
#       row.className = 'ch04-hw-feedback-row';
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/homework-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var payload = text ? JSON.parse(text) : null;
#         if (!payload || !response.ok || !payload.ok) {
#           throw new Error((payload && (payload.message || payload.error)) || 'Submission API is unavailable.');
#         }
#         return payload;
#       });
#     });
#   }
#
#   function initHomeworkGrader() {
#     var grader = document.getElementById('ch04-hw-grader');
#     if (!grader || grader.dataset.ready === 'true') return;
#     grader.dataset.ready = 'true';
#
#     var identity = getParams();
#     var actions = grader.querySelector('.ch04-hw-actions');
#     var result = document.getElementById('ch04-hw-result');
#     var submit = document.getElementById('ch04-hw-submit');
#     var reset = document.getElementById('ch04-hw-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(grader);
#       submit.disabled = true;
#       result.textContent = 'Submitting homework.';
#
#       saveAttempt({
#         homework_id: homeworkId,
#         answers: collectAnswers(),
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           applyFeedback(grader, payload.feedback || {});
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(grader);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initHomeworkGrader);
#   } else {
#     initHomeworkGrader();
#   }
# })();
# </script>
