# %% [markdown]
# # Homework
#
# **Due:** Saturday, September 19, 2026, 11:59 PM CT.
#
# Use this homework after class to reinforce and extend the ideas from Chapter 4.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
#
# > Homework questions will be added here.
