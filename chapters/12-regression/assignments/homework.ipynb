# %% [markdown]
# # Homework
#
# - Use these questions after class to check your understanding of the chapter concepts and coding skills.
# - Sign in from the account menu before you start working on the homework.
# - Complete all true/false and coding questions before you submit the homework.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
# - Multiple submissions are allowed. The highest score is kept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **Question 1: Correlation**
#
# A positive correlation means larger values of one variable tend to be associated with larger values of the other variable.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 1 answer">
#   <label><input type="radio" name="ch12-hw-q1" value="true"> True</label>
#   <label><input type="radio" name="ch12-hw-q1" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Positive correlation describes an upward linear association.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **Question 2: Regression Line**
#
# A regression line can be used to produce fitted values for prediction.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 2 answer">
#   <label><input type="radio" name="ch12-hw-q2" value="true"> True</label>
#   <label><input type="radio" name="ch12-hw-q2" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Regression lines map predictor values to predicted responses.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **Question 3: Residual**
#
# A residual is the actual value minus the fitted or predicted value.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 3 answer">
#   <label><input type="radio" name="ch12-hw-q3" value="true"> True</label>
#   <label><input type="radio" name="ch12-hw-q3" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Residuals measure prediction errors.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **Question 4: Least Squares**
#
# Least squares chooses the line with the largest possible sum of squared residuals.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 4 answer">
#   <label><input type="radio" name="ch12-hw-q4" value="true"> True</label>
#   <label><input type="radio" name="ch12-hw-q4" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# Least squares minimizes the sum of squared residuals.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **Question 5: Causation**
#
# A strong correlation by itself proves that changing one variable caused the other to change.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 5 answer">
#   <label><input type="radio" name="ch12-hw-q5" value="true"> True</label>
#   <label><input type="radio" name="ch12-hw-q5" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# Association alone does not prove causation.

# %%
### 6. Slope Prediction
# Predict demand using intercept + slope * price.
# Print exactly:
# Predicted demand: 70
intercept = 100
slope = -3
price = 10

### Your code starts here.



### Your code ends here.

# %%
### Solution
intercept = 100
slope = -3
price = 10
predicted_demand = intercept + slope * price
print("Predicted demand:", predicted_demand)
# Out:
# Predicted demand: 70

# %%
### 7. Residual List
# Calculate residuals from actual and predicted values.
# Print exactly:
# Residuals: [2, -1, 3]
actual = [102, 99, 108]
predicted = [100, 100, 105]

### Your code starts here.



### Your code ends here.

# %%
### Solution
actual = [102, 99, 108]
predicted = [100, 100, 105]
residuals = []
index = 0
for value in actual:
    residuals.append(value - predicted[index])
    index = index + 1
print("Residuals:", residuals)
# Out:
# Residuals: [2, -1, 3]

# %%
### 8. RMSE Pieces
# Calculate mean squared error from squared residuals.
# Print exactly:
# MSE: 4.0
squared_residuals = [1, 4, 7]

### Your code starts here.



### Your code ends here.

# %%
### Solution
squared_residuals = [1, 4, 7]
mse = sum(squared_residuals) / len(squared_residuals)
print("MSE:", mse)
# Out:
# MSE: 4.0

# %%
### 9. Outlier Flag
# Flag a point as an outlier if its residual is above 10 in absolute value.
# Print exactly:
# Outlier flag: True
residual = -12

### Your code starts here.



### Your code ends here.

# %%
### Solution
residual = -12
absolute_residual = residual
if absolute_residual < 0:
    absolute_residual = -absolute_residual
outlier_flag = absolute_residual > 10
print("Outlier flag:", outlier_flag)
# Out:
# Outlier flag: True

# %%
### 10. Correlation Strength
# Classify the strength of a correlation.
# Print exactly:
# Strength: strong
correlation = 0.82

### Your code starts here.



### Your code ends here.

# %%
### Solution
correlation = 0.82
if correlation >= 0.7:
    strength = "strong"
else:
    strength = "moderate"
print("Strength:", strength)
# Out:
# Strength: strong

# %% [markdown]
# <style>
# .ch12-hw-grader { max-width: 900px; margin-top: 1rem; }
# .ch12-hw-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch12-hw-feedback-list[hidden] { display: none; }
# .ch12-hw-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch12-hw-feedback-row strong { margin-right: 0.35rem; }
# .ch12-hw-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch12-hw-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch12-hw-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch12-hw-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch12-hw-actions button.secondary { background: white; color: #176de8; }
# .ch12-hw-actions.is-locked { opacity: 0.55; }
# .ch12-hw-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch12-hw-result { font-weight: 700; }
# </style>
#
# <div class='ch12-hw-grader' id='ch12-hw-grader'>
#   <div class='ch12-hw-feedback-list' aria-live='polite' hidden>
#     <div class='ch12-hw-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch12-hw-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch12-hw-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch12-hw-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch12-hw-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#     <div class='ch12-hw-feedback-row' data-question='q6'><strong>Question 6</strong><span></span></div>
#     <div class='ch12-hw-feedback-row' data-question='q7'><strong>Question 7</strong><span></span></div>
#     <div class='ch12-hw-feedback-row' data-question='q8'><strong>Question 8</strong><span></span></div>
#     <div class='ch12-hw-feedback-row' data-question='q9'><strong>Question 9</strong><span></span></div>
#     <div class='ch12-hw-feedback-row' data-question='q10'><strong>Question 10</strong><span></span></div>
#   </div>
#   <div class='ch12-hw-actions'>
#     <button type='button' id='ch12-hw-submit' disabled>Submit</button>
#     <button type='button' class='secondary' id='ch12-hw-reset'>Clear Results</button>
#     <span class='ch12-hw-result' id='ch12-hw-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var homeworkId = 'ch12-homework';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var cm = cell.querySelector('.CodeMirror');
#     if (cm && cm.CodeMirror && typeof cm.CodeMirror.getValue === 'function') return cm.CodeMirror.getValue();
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent && cmContent.cmView && cmContent.cmView.view) return cmContent.cmView.view.state.doc.toString();
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.prototype.slice.call(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 6)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function collectAnswers() {
#     var answers = {};
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var checked = document.querySelector('input[name="ch12-hw-' + question + '"]:checked');
#       answers[question] = checked ? checked.value : '';
#     });
#     return answers;
#   }
#
#   function applyFeedback(grader, feedback) {
#     var list = grader.querySelector('.ch12-hw-feedback-list');
#     list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9', 'q10'].forEach(function (question) {
#       var row = grader.querySelector('[data-question=' + question + ']');
#       var message = row.querySelector('span');
#       var item = feedback[question];
#       row.className = 'ch12-hw-feedback-row';
#       if (!item) return;
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(grader) {
#     var list = grader.querySelector('.ch12-hw-feedback-list');
#     list.hidden = true;
#     grader.querySelectorAll('.ch12-hw-feedback-row').forEach(function (row) {
#       row.className = 'ch12-hw-feedback-row';
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/homework-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var payload = text ? JSON.parse(text) : null;
#         if (!payload || !response.ok || !payload.ok) {
#           throw new Error((payload && (payload.message || payload.error)) || 'Submission API is unavailable.');
#         }
#         return payload;
#       });
#     });
#   }
#
#   function initHomeworkGrader() {
#     var grader = document.getElementById('ch12-hw-grader');
#     if (!grader || grader.dataset.ready === 'true') return;
#     grader.dataset.ready = 'true';
#
#     var identity = getParams();
#     var actions = grader.querySelector('.ch12-hw-actions');
#     var result = document.getElementById('ch12-hw-result');
#     var submit = document.getElementById('ch12-hw-submit');
#     var reset = document.getElementById('ch12-hw-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(grader);
#       submit.disabled = true;
#       result.textContent = 'Submitting homework.';
#
#       saveAttempt({
#         homework_id: homeworkId,
#         answers: collectAnswers(),
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           applyFeedback(grader, payload.feedback || {});
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(grader);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initHomeworkGrader);
#   } else {
#     initHomeworkGrader();
#   }
# })();
# </script>
