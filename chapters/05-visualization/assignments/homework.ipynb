# %% [markdown]
# # Homework
#
# - Use these questions after class to check your understanding of the chapter concepts and coding skills.
# - Sign in from the account menu before you start working on the homework.
# - Complete all true/false and coding questions before you submit the homework.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
# - Multiple submissions are allowed. The highest score is kept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **1. Chart Choice**
#
# **True or False:** A manager comparing revenue across regions would usually start with a comparison chart such as a bar chart.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 1 answer">
#   <label><input type="radio" name="ch05-hw-q1" value="true"> True</label>
#   <label><input type="radio" name="ch05-hw-q1" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Bar charts support comparisons across categories.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **2. Line Charts**
#
# **True or False:** A line chart is usually appropriate when the business question focuses on change over time.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 2 answer">
#   <label><input type="radio" name="ch05-hw-q2" value="true"> True</label>
#   <label><input type="radio" name="ch05-hw-q2" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Line charts emphasize trends across ordered time points.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **3. Scatterplots**
#
# **True or False:** A scatterplot is mainly used to show the parts of a whole, so it is the default choice for market share percentages.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 3 answer">
#   <label><input type="radio" name="ch05-hw-q3" value="true"> True</label>
#   <label><input type="radio" name="ch05-hw-q3" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# Scatterplots show relationships between two quantitative variables.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **4. Outliers**
#
# **True or False:** A chart can reveal an unusual sales value that should be investigated before a report is finalized.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 4 answer">
#   <label><input type="radio" name="ch05-hw-q4" value="true"> True</label>
#   <label><input type="radio" name="ch05-hw-q4" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Visualizations help analysts notice outliers and patterns.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **5. Labels**
#
# **True or False:** Removing axis labels usually makes a chart easier for a business audience to interpret.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 5 answer">
#   <label><input type="radio" name="ch05-hw-q5" value="true"> True</label>
#   <label><input type="radio" name="ch05-hw-q5" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# Clear labels usually make charts easier to interpret.

# %%
### 6. Chart Recommendation Count
# Count how many questions should use each chart type.
# Print exactly:
# Bar charts: 2
# Line charts: 1
chart_choices = ["bar", "line", "bar", "scatter"]

### Your code starts here.



### Your code ends here.

# %%
### Solution
chart_choices = ["bar", "line", "bar", "scatter"]

bar_charts = chart_choices.count("bar")
line_charts = chart_choices.count("line")

print("Bar charts:", bar_charts)
print("Line charts:", line_charts)
# Out:
# Bar charts: 2
# Line charts: 1

# %%
### 7. Axis Range
# Calculate the range needed for the y-axis values.
# Print exactly:
# Minimum sales: 80
# Maximum sales: 140
sales = [95, 120, 80, 140]

### Your code starts here.



### Your code ends here.

# %%
### Solution
sales = [95, 120, 80, 140]

print("Minimum sales:", min(sales))
print("Maximum sales:", max(sales))
# Out:
# Minimum sales: 80
# Maximum sales: 140

# %%
### 8. Scatter Pairs
# Pair ad spending and revenue values for a scatterplot.
# Print exactly:
# First pair: [10, 80]
# Pair count: 3
ad_spend = [10, 15, 20]
revenue = [80, 110, 150]

### Your code starts here.



### Your code ends here.

# %%
### Solution
ad_spend = [10, 15, 20]
revenue = [80, 110, 150]

pairs = []
index = 0
for value in ad_spend:
    pairs.append([value, revenue[index]])
    index = index + 1

print("First pair:", pairs[0])
print("Pair count:", len(pairs))
# Out:
# First pair: [10, 80]
# Pair count: 3

# %%
### 9. Emphasis Color
# Choose a highlight color for the target region and gray for the others.
# Print exactly:
# Colors: ['gray', 'red', 'gray']
regions = ["East", "West", "South"]
target_region = "West"

### Your code starts here.



### Your code ends here.

# %%
### Solution
regions = ["East", "West", "South"]
target_region = "West"

colors = []
for region in regions:
    if region == target_region:
        colors.append("red")
    else:
        colors.append("gray")

print("Colors:", colors)
# Out:
# Colors: ['gray', 'red', 'gray']

# %%
### 10. Misleading Scale Flag
# Flag the chart if the y-axis does not start at zero for a bar chart.
# Print exactly:
# Scale warning: True
chart_type = "bar"
y_axis_start = 75

### Your code starts here.



### Your code ends here.

# %%
### Solution
chart_type = "bar"
y_axis_start = 75

scale_warning = chart_type == "bar" and y_axis_start != 0
print("Scale warning:", scale_warning)
# Out:
# Scale warning: True

# %% [markdown]
# <style>
# .ch05-hw-grader { max-width: 900px; margin-top: 1rem; }
# .ch05-hw-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch05-hw-feedback-list[hidden] { display: none; }
# .ch05-hw-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch05-hw-feedback-row strong { margin-right: 0.35rem; }
# .ch05-hw-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch05-hw-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch05-hw-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch05-hw-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch05-hw-actions button.secondary { background: white; color: #176de8; }
# .ch05-hw-actions.is-locked { opacity: 0.55; }
# .ch05-hw-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch05-hw-result { font-weight: 700; }
# </style>
#
# <div class='ch05-hw-grader' id='ch05-hw-grader'>
#   <div class='ch05-hw-feedback-list' aria-live='polite' hidden>
#     <div class='ch05-hw-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch05-hw-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch05-hw-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch05-hw-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch05-hw-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#     <div class='ch05-hw-feedback-row' data-question='q6'><strong>Question 6</strong><span></span></div>
#     <div class='ch05-hw-feedback-row' data-question='q7'><strong>Question 7</strong><span></span></div>
#     <div class='ch05-hw-feedback-row' data-question='q8'><strong>Question 8</strong><span></span></div>
#     <div class='ch05-hw-feedback-row' data-question='q9'><strong>Question 9</strong><span></span></div>
#     <div class='ch05-hw-feedback-row' data-question='q10'><strong>Question 10</strong><span></span></div>
#   </div>
#   <div class='ch05-hw-actions'>
#     <button type='button' id='ch05-hw-submit' disabled>Submit</button>
#     <button type='button' class='secondary' id='ch05-hw-reset'>Clear Results</button>
#     <span class='ch05-hw-result' id='ch05-hw-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var homeworkId = 'ch05-homework';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var cm = cell.querySelector('.CodeMirror');
#     if (cm && cm.CodeMirror && typeof cm.CodeMirror.getValue === 'function') return cm.CodeMirror.getValue();
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent && cmContent.cmView && cmContent.cmView.view) return cmContent.cmView.view.state.doc.toString();
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.prototype.slice.call(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 6)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function collectAnswers() {
#     var answers = {};
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var checked = document.querySelector('input[name="ch05-hw-' + question + '"]:checked');
#       answers[question] = checked ? checked.value : '';
#     });
#     return answers;
#   }
#
#   function applyFeedback(grader, feedback) {
#     var list = grader.querySelector('.ch05-hw-feedback-list');
#     list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9', 'q10'].forEach(function (question) {
#       var row = grader.querySelector('[data-question=' + question + ']');
#       var message = row.querySelector('span');
#       var item = feedback[question];
#       row.className = 'ch05-hw-feedback-row';
#       if (!item) return;
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(grader) {
#     var list = grader.querySelector('.ch05-hw-feedback-list');
#     list.hidden = true;
#     grader.querySelectorAll('.ch05-hw-feedback-row').forEach(function (row) {
#       row.className = 'ch05-hw-feedback-row';
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/homework-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var payload = text ? JSON.parse(text) : null;
#         if (!payload || !response.ok || !payload.ok) {
#           throw new Error((payload && (payload.message || payload.error)) || 'Submission API is unavailable.');
#         }
#         return payload;
#       });
#     });
#   }
#
#   function initHomeworkGrader() {
#     var grader = document.getElementById('ch05-hw-grader');
#     if (!grader || grader.dataset.ready === 'true') return;
#     grader.dataset.ready = 'true';
#
#     var identity = getParams();
#     var actions = grader.querySelector('.ch05-hw-actions');
#     var result = document.getElementById('ch05-hw-result');
#     var submit = document.getElementById('ch05-hw-submit');
#     var reset = document.getElementById('ch05-hw-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(grader);
#       submit.disabled = true;
#       result.textContent = 'Submitting homework.';
#
#       saveAttempt({
#         homework_id: homeworkId,
#         answers: collectAnswers(),
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           applyFeedback(grader, payload.feedback || {});
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(grader);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initHomeworkGrader);
#   } else {
#     initHomeworkGrader();
#   }
# })();
# </script>
