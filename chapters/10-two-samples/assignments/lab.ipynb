# %% [markdown]
# # Lab
#
# **Due:** Tuesday, November 3, 2026, 11:59 PM CT.
# **Answers unlock:** after the lab due date.
#
# This lab will extend the section exercises from Chapter 10.
#
# > Lab questions will be added here.
#
# <div data-lab-answers-release-at="2026-11-03T23:59-06:00"></div>
