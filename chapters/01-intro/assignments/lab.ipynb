# %% [markdown]
# # Lab
#
# This lab gives you practice with technical ideas from Sections 1.1 and 1.2: data science workflows, data roles, programming constructs, expressions, number systems, and character encoding.

# %%
### Question 1: CRISP-DM phases
# A retail manager wants to predict which customers are likely to stop buying.
# Store the first three CRISP-DM phases in variables named phase_1, phase_2, and phase_3.
# Store the last three phases in variables named phase_4, phase_5, and phase_6.
# Then print the first phase and the last phase.
### Your code starts here.



### Your code ends here.

# %%
### Solution
phase_1 = "Business Understanding"
phase_2 = "Data Understanding"
phase_3 = "Data Preparation"
phase_4 = "Modeling"
phase_5 = "Evaluation"
phase_6 = "Deployment"

print("First phase:", phase_1)
print("Last phase:", phase_6)

# %%
### Question 2: Data science tool categories
# Create four variables named data_management_tool, data_manipulation_tool,
# data_analysis_tool, and data_visualization_tool.
# Give each variable one tool example from Section 1.1.
# Then print the visualization tool.
### Your code starts here.



### Your code ends here.

# %%
### Solution
data_management_tool = "SQL database"
data_manipulation_tool = "pandas"
data_analysis_tool = "scikit-learn"
data_visualization_tool = "Matplotlib"

print("Visualization tool:", data_visualization_tool)

# %%
### Question 3: Decimal to binary conversion
# Convert the decimal number 13 to binary using base-2 place values.
# Store each binary digit in a variable named bit_3, bit_2, bit_1, and bit_0.
# Store the full binary answer in a variable named manual_binary.
# Then print manual_binary.
# Check your answer by printing bin(13).
decimal_number = 13
### Your code starts here.



### Your code ends here.

# %%
### Solution
decimal_number = 13
bit_3 = 1  # 8s place
bit_2 = 1  # 4s place
bit_1 = 0  # 2s place
bit_0 = 1  # 1s place

manual_binary = "0b1101"

print("Manual conversion:", manual_binary)
print("Python check:", bin(decimal_number))

# %%
### Question 4: Expressions and statements
# The values below describe one customer order.
# Write assignment statements that calculate subtotal, tax, and total.
# Then print all three values rounded to 2 decimal places.
# Use round(value, 2) to round a number to 2 decimal places.
unit_price = 18.75
quantity = 4
tax_rate = 0.0825
### Your code starts here.



### Your code ends here.

# %%
### Solution
unit_price = 18.75
quantity = 4
tax_rate = 0.0825

subtotal = unit_price * quantity
tax = subtotal * tax_rate
total = subtotal + tax

print("Subtotal:", round(subtotal, 2))
print("Tax:", round(tax, 2))
print("Total:", round(total, 2))

# %%
### Question 5: Number systems and character encoding
# A simple inventory system uses product code "C" and item number 64.
# Save the decimal code for "C" in c_decimal using ord().
# Save the binary representation of c_decimal in c_binary using bin().
# Save the hexadecimal representation of item_number in item_hex using hex().
# Print c_decimal, c_binary, and item_hex.
item_number = 64
### Your code starts here.



### Your code ends here.

# %%
### Solution
item_number = 64
c_decimal = ord("C")
c_binary = bin(c_decimal)
item_hex = hex(item_number)

print("C decimal:", c_decimal)
print("C binary:", c_binary)
print("Item hex:", item_hex)

# %% [markdown]
# ## Submit Lab Answers
#
# <style>
# .ch01-lab-grader { max-width: 900px; margin-top: 1rem; }
# .ch01-lab-grader fieldset { border: 1px solid #d8dee4; border-radius: 6px; padding: 1rem; margin: 1rem 0; background: #fff; }
# .ch01-lab-grader legend { font-weight: 700; padding: 0 0.35rem; }
# .ch01-lab-grid { display: grid; grid-template-columns: repeat(auto-fit, minmax(220px, 1fr)); gap: 0.8rem; }
# .ch01-lab-grader label { display: grid; gap: 0.3rem; font-weight: 600; }
# .ch01-lab-grader input { border: 1px solid #d0d7de; border-radius: 6px; padding: 0.5rem; font: inherit; }
# .ch01-lab-identity-note { margin-top: 0.4rem; color: #57606a; font-size: 0.9rem; }
# .ch01-lab-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0; flex-wrap: wrap; }
# .ch01-lab-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch01-lab-actions button.secondary { background: white; color: #176de8; }
# .ch01-lab-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch01-lab-result { font-weight: 700; }
# .ch01-lab-feedback { margin-top: 0.65rem; font-weight: 600; }
# .ch01-lab-feedback.correct { color: #1a7f37; }
# .ch01-lab-feedback.incorrect { color: #cf222e; }
# </style>
#
# <div class='ch01-lab-grader' id='ch01-lab-grader'>
#   <fieldset>
#     <legend>Identity</legend>
#     <label>SIS Login ID <input id='ch01-lab-student-identifier' type='text' autocomplete='username' placeholder='Example: csat5h'></label>
#     <div class='ch01-lab-identity-note' id='ch01-lab-identity-note'></div>
#   </fieldset>
#   <fieldset data-question='q1'>
#     <legend>Question 1</legend>
#     <div class='ch01-lab-grid'>
#       <label>phase_1 <input data-answer='phase_1' type='text'></label>
#       <label>phase_6 <input data-answer='phase_6' type='text'></label>
#     </div>
#     <div class='ch01-lab-feedback' aria-live='polite'></div>
#   </fieldset>
#   <fieldset data-question='q2'>
#     <legend>Question 2</legend>
#     <label>data_visualization_tool <input data-answer='data_visualization_tool' type='text'></label>
#     <div class='ch01-lab-feedback' aria-live='polite'></div>
#   </fieldset>
#   <fieldset data-question='q3'>
#     <legend>Question 3</legend>
#     <label>manual_binary <input data-answer='manual_binary' type='text' placeholder='0b1101'></label>
#     <div class='ch01-lab-feedback' aria-live='polite'></div>
#   </fieldset>
#   <fieldset data-question='q4'>
#     <legend>Question 4</legend>
#     <div class='ch01-lab-grid'>
#       <label>subtotal <input data-answer='subtotal' type='text'></label>
#       <label>tax <input data-answer='tax' type='text'></label>
#       <label>total <input data-answer='total' type='text'></label>
#     </div>
#     <div class='ch01-lab-feedback' aria-live='polite'></div>
#   </fieldset>
#   <fieldset data-question='q5'>
#     <legend>Question 5</legend>
#     <div class='ch01-lab-grid'>
#       <label>c_decimal <input data-answer='c_decimal' type='text'></label>
#       <label>c_binary <input data-answer='c_binary' type='text'></label>
#       <label>item_hex <input data-answer='item_hex' type='text'></label>
#     </div>
#     <div class='ch01-lab-feedback' aria-live='polite'></div>
#   </fieldset>
#   <div class='ch01-lab-actions'>
#     <button type='button' id='ch01-lab-submit'>Submit Lab</button>
#     <button type='button' class='secondary' id='ch01-lab-reset'>Reset</button>
#     <span class='ch01-lab-result' id='ch01-lab-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var labId = 'ch01-lab';
#   var answerKeys = ['phase_1', 'phase_6', 'data_visualization_tool', 'manual_binary', 'subtotal', 'tax', 'total', 'c_decimal', 'c_binary', 'item_hex'];
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || '',
#       student_identifier: params.get('student_identifier') || params.get('student_id') || params.get('email') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, identifierInput, identityNote) {
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || identity.student_identifier || '';
#         identifierInput.value = identity.student_identifier || identity.canvas_user_id || '';
#         identifierInput.readOnly = true;
#         identityNote.textContent = payload.identity.display_name ? 'Signed in from Canvas as ' + payload.identity.display_name + '.' : 'Signed in from Canvas.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function collectAnswers(grader) {
#     var answers = {};
#     answerKeys.forEach(function (key) {
#       var input = grader.querySelector('[data-answer=' + key + ']');
#       answers[key] = input ? input.value : '';
#     });
#     return answers;
#   }
#
#   function applyFeedback(grader, feedback) {
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var fieldset = grader.querySelector('[data-question=' + question + ']');
#       var message = fieldset.querySelector('.ch01-lab-feedback');
#       var item = feedback[question];
#       message.className = 'ch01-lab-feedback';
#       if (!item) return;
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       message.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function initLabGrader() {
#     var grader = document.getElementById('ch01-lab-grader');
#     if (!grader || grader.dataset.ready === 'true') return;
#     grader.dataset.ready = 'true';
#
#     var identity = getParams();
#     var identifierInput = document.getElementById('ch01-lab-student-identifier');
#     var identityNote = document.getElementById('ch01-lab-identity-note');
#     var result = document.getElementById('ch01-lab-result');
#     var submit = document.getElementById('ch01-lab-submit');
#     var reset = document.getElementById('ch01-lab-reset');
#
#     identifierInput.value = identity.student_identifier || identity.canvas_user_id || '';
#     loadSessionIdentity(identity, identifierInput, identityNote);
#
#     submit.addEventListener('click', function () {
#       submit.disabled = true;
#       result.textContent = 'Submitting...';
#
#       fetch('/api/v1/lab-attempts.php', {
#         method: 'POST',
#         headers: { 'Content-Type': 'application/json' },
#         credentials: 'same-origin',
#         body: JSON.stringify({
#           lab_id: labId,
#           answers: collectAnswers(grader),
#           student_identifier: identifierInput.value,
#           canvas_course_id: identity.canvas_course_id,
#           canvas_assignment_id: identity.canvas_assignment_id,
#           canvas_user_id: identity.canvas_user_id
#         })
#       })
#         .then(function (response) {
#           return response.text().then(function (text) {
#             var payload = text ? JSON.parse(text) : null;
#             if (!payload || !response.ok || !payload.ok) {
#               throw new Error((payload && (payload.message || payload.error)) || 'Submission failed.');
#             }
#             return payload;
#           });
#         })
#         .then(function (payload) {
#           applyFeedback(grader, payload.feedback || {});
#           result.textContent = 'Score: ' + payload.score + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       grader.querySelectorAll('input[data-answer]').forEach(function (input) { input.value = ''; });
#       grader.querySelectorAll('.ch01-lab-feedback').forEach(function (feedback) { feedback.className = 'ch01-lab-feedback'; feedback.textContent = ''; });
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initLabGrader);
#   } else {
#     initLabGrader();
#   }
# })();
# </script>
