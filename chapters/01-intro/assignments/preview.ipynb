# %% [markdown]
# # Preview Questions
#
# Use these questions before class to activate what you already know about data, decisions, and programming.

# %%
### Preview: Data in a Business Decision
# Think of one decision a business makes regularly, such as pricing,
# staffing, inventory, advertising, or customer service.
#
# 1. Write the decision as a question.
# 2. List two pieces of data that could help answer it.
# 3. Explain what could go wrong if the business made the decision without data.
### Your response starts here.



### Your response ends here.

# %%
### Sample Response
# Decision question: How many employees should a coffee shop schedule on Friday morning?
# Useful data: past Friday sales by hour and average customer wait times.
# Risk without data: the shop might understaff a busy period, creating long lines
# and lost sales, or overstaff a slow period and raise labor costs unnecessarily.
