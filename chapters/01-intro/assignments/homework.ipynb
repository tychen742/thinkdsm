# %% [markdown]
# # Homework
#
# - Use these questions after class to check your understanding of the chapter concepts and coding skills.
# - Sign in from the account menu before you start working on the homework.
# - Complete all true/false and coding questions before you submit the homework.
# - Multiple submissions are allowed. The highest score is kept.
#
# <style>
# .tf-options { display: flex; gap: 1.25rem; flex-wrap: wrap; margin: 0.4rem 0 0.15rem; }
# .tf-options label { display: inline-flex; align-items: center; gap: 0.35rem; cursor: pointer; font-weight: 600; }
# .tf-options input { margin: 0; }
# .cell:has(.tf-options) { margin-bottom: 0.1rem; }
# .cell:has(.tf-options) + .cell { margin-top: 0; margin-bottom: 1.65rem; }
# .cell:has(.tf-options) + .cell details { margin-top: 0; }
# </style>

# %% [markdown]
# ::::{div} assignment-question-card
#
# **1. Data Science in a Retail Decision**
#
# **True or False:** A retail team combines sales records, Python summaries, statistics, merchandising knowledge, and a manager-facing recommendation to decide which products to reorder. Calling this work data science is appropriate.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 1 answer">
#   <label><input type="radio" name="ch01-hw-q1" value="true"> True</label>
#   <label><input type="radio" name="ch01-hw-q1" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# The work combines data, computing, statistics, domain expertise, and communication for a decision.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **2. Data Without Context**
#
# **True or False:** A marketing analyst has click data but does not know the campaign goal, product margins, or customer segment. The analyst can still decide the best campaign from the data alone.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 2 answer">
#   <label><input type="radio" name="ch01-hw-q2" value="true"> True</label>
#   <label><input type="radio" name="ch01-hw-q2" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# The data needs domain context before it can support a useful decision.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **3. Descriptive Questions**
#
# **True or False:** A store manager asks, "How many returns did each product category have last month?" This is mainly a descriptive data science question.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 3 answer">
#   <label><input type="radio" name="ch01-hw-q3" value="true"> True</label>
#   <label><input type="radio" name="ch01-hw-q3" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# The question summarizes what already happened.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **4. Predictive and Prescriptive Questions**
#
# **True or False:** An operations director asks, "Which shipments are most likely to arrive late next week?" This is mainly a prescriptive question.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 4 answer">
#   <label><input type="radio" name="ch01-hw-q4" value="true"> True</label>
#   <label><input type="radio" name="ch01-hw-q4" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# The question estimates a future outcome, so it is predictive. A prescriptive question would recommend an action.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **5. Formal Language Rules**
#
# **True or False:** A finance script has the right formula but is missing a closing quote in one `print()` statement. Because the business idea is correct, Python syntax rules will not affect whether the program runs.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 5 answer">
#   <label><input type="radio" name="ch01-hw-q5" value="true"> True</label>
#   <label><input type="radio" name="ch01-hw-q5" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# Python is a formal language; syntax errors can stop a program before the business logic runs.

# %%
### 6. Classify Management Questions
# A customer success team is reviewing subscription cancellations.
# Store the correct label for each question: descriptive, predictive, or prescriptive.
# Then print each label with the question name.
#
# question_a: How many customers canceled last month?
# question_b: Which customers are most likely to cancel next month?
# question_c: Which retention offer should we send first?

question_a = ""
question_b = ""
question_c = ""

### Your code starts here.



### Your code ends here.

# %%
### Solution
question_a = "descriptive"
question_b = "predictive"
question_c = "prescriptive"

print("Question A:", question_a)
print("Question B:", question_b)
print("Question C:", question_c)

# %%
### 7. Write a Stakeholder Status Line
# The lab asked you to print technical values. Here, turn values into a concise status line.
# Use an f-string and the variables below to print exactly:
# North store has 7 late shipments out of 80.

store = "North"
late_shipments = 7
total_shipments = 80

### Your code starts here.



### Your code ends here.

# %%
### Solution
store = "North"
late_shipments = 7
total_shipments = 80

print(f"{store} store has {late_shipments} late shipments out of {total_shipments}.")

# %%
### 8. Fix a Syntax Error
# The lab asked you to write correct statements. Here, practice recognizing broken syntax.
# The two lines below have syntax problems:
# print("DSM homework"
# print("Syntax fixed.")
# Write corrected code that prints exactly:
# DSM homework
# Syntax fixed.

### Your code starts here.



### Your code ends here.

# %%
### Solution
print("DSM homework")
print("Syntax fixed.")

# %%
### 9. Build an Inventory Code
# The lab printed separate number-system and character-code values.
# Here, combine those pieces into one inventory code.
# Use ord() and hex() with the variables below to print exactly:
# Inventory code: R-82-0x2d

category = "R"
item_id = 45

### Your code starts here.



### Your code ends here.

# %%
### Solution
category = "R"
item_id = 45
category_code = ord(category)
item_hex = hex(item_id)

print(f"Inventory code: {category}-{category_code}-{item_hex}")

# %%
### 10. Calculate Audit Metrics
# The lab calculated an order total. Here, calculate simple management metrics from case counts.
# Use the variables below to calculate open_cases and closure_rate.
# Print exactly:
# Open cases: 17
# Closure rate: 0.67

starting_cases = 20
new_cases = 7
closed_cases = 10
assigned_cases = 15

### Your code starts here.



### Your code ends here.

# %%
### Solution
starting_cases = 20
new_cases = 7
closed_cases = 10
assigned_cases = 15

open_cases = starting_cases + new_cases - closed_cases
closure_rate = closed_cases / assigned_cases

print("Open cases:", open_cases)
print("Closure rate:", round(closure_rate, 2))

# %% [markdown]
# <style>
# .ch01-hw-grader { max-width: 900px; margin-top: 1rem; }
# .ch01-hw-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch01-hw-feedback-list[hidden] { display: none; }
# .ch01-hw-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch01-hw-feedback-row strong { margin-right: 0.35rem; }
# .ch01-hw-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch01-hw-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch01-hw-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch01-hw-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch01-hw-actions button.secondary { background: white; color: #176de8; }
# .ch01-hw-actions.is-locked { opacity: 0.55; }
# .ch01-hw-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch01-hw-result { font-weight: 700; }
# </style>
#
# <div class='ch01-hw-grader' id='ch01-hw-grader'>
#   <div class='ch01-hw-feedback-list' aria-live='polite' hidden>
#     <div class='ch01-hw-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch01-hw-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch01-hw-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch01-hw-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch01-hw-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#     <div class='ch01-hw-feedback-row' data-question='q6'><strong>Question 6</strong><span></span></div>
#     <div class='ch01-hw-feedback-row' data-question='q7'><strong>Question 7</strong><span></span></div>
#     <div class='ch01-hw-feedback-row' data-question='q8'><strong>Question 8</strong><span></span></div>
#     <div class='ch01-hw-feedback-row' data-question='q9'><strong>Question 9</strong><span></span></div>
#     <div class='ch01-hw-feedback-row' data-question='q10'><strong>Question 10</strong><span></span></div>
#   </div>
#   <div class='ch01-hw-actions'>
#     <button type='button' id='ch01-hw-submit' disabled>Submit</button>
#     <button type='button' class='secondary' id='ch01-hw-reset'>Clear Results</button>
#     <span class='ch01-hw-result' id='ch01-hw-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var homeworkId = 'ch01-homework';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var cm = cell.querySelector('.CodeMirror');
#     if (cm && cm.CodeMirror && typeof cm.CodeMirror.getValue === 'function') return cm.CodeMirror.getValue();
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent && cmContent.cmView && cmContent.cmView.view) return cmContent.cmView.view.state.doc.toString();
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.prototype.slice.call(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 6)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function collectAnswers() {
#     var answers = {};
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var checked = document.querySelector('input[name="ch01-hw-' + question + '"]:checked');
#       answers[question] = checked ? checked.value : '';
#     });
#     return answers;
#   }
#
#   function applyFeedback(grader, feedback) {
#     var list = grader.querySelector('.ch01-hw-feedback-list');
#     list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9', 'q10'].forEach(function (question) {
#       var row = grader.querySelector('[data-question=' + question + ']');
#       var message = row.querySelector('span');
#       var item = feedback[question];
#       row.className = 'ch01-hw-feedback-row';
#       if (!item) return;
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(grader) {
#     var list = grader.querySelector('.ch01-hw-feedback-list');
#     list.hidden = true;
#     grader.querySelectorAll('.ch01-hw-feedback-row').forEach(function (row) {
#       row.className = 'ch01-hw-feedback-row';
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/homework-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var payload = text ? JSON.parse(text) : null;
#         if (!payload || !response.ok || !payload.ok) {
#           throw new Error((payload && (payload.message || payload.error)) || 'Submission API is unavailable.');
#         }
#         return payload;
#       });
#     });
#   }
#
#   function initHomeworkGrader() {
#     var grader = document.getElementById('ch01-hw-grader');
#     if (!grader || grader.dataset.ready === 'true') return;
#     grader.dataset.ready = 'true';
#
#     var identity = getParams();
#     var actions = grader.querySelector('.ch01-hw-actions');
#     var result = document.getElementById('ch01-hw-result');
#     var submit = document.getElementById('ch01-hw-submit');
#     var reset = document.getElementById('ch01-hw-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(grader);
#       submit.disabled = true;
#       result.textContent = 'Submitting homework.';
#
#       saveAttempt({
#         homework_id: homeworkId,
#         answers: collectAnswers(),
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           applyFeedback(grader, payload.feedback || {});
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(grader);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initHomeworkGrader);
#   } else {
#     initHomeworkGrader();
#   }
# })();
# </script>
