# %% [markdown]
# # Homework
#
# This homework asks you to connect Chapter 1 vocabulary to a realistic management situation.

# %%
### Homework: Classifying Data Science Work
# A retail manager wants to reduce product returns. For each task below,
# label it as mainly descriptive, predictive, or prescriptive.
#
# A. Count the number of returns by product category last month.
# B. Estimate which products are most likely to be returned next month.
# C. Recommend which product pages should be revised first to reduce returns.
#
# Then write one sentence explaining why data alone is not enough for this problem.
### Your response starts here.



### Your response ends here.

# %%
### Solution
# A. Descriptive: it summarizes what already happened.
# B. Predictive: it estimates what may happen in the future.
# C. Prescriptive: it recommends an action.
#
# Data alone is not enough because the manager still needs business context,
# such as product margins, customer expectations, and the cost of changing pages.
