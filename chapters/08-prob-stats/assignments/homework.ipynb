# %% [markdown]
# # Homework
#
# **Due:** To be announced.
#
# Use this homework after class to reinforce and extend the ideas from Chapter 8.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
#
# > Homework questions will be added here.
