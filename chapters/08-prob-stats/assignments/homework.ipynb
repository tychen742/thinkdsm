# %% [markdown]
# # Homework
#
# - Use these questions after class to check your understanding of the chapter concepts and coding skills.
# - Sign in from the account menu before you start working on the homework.
# - Complete all true/false and coding questions before you submit the homework.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
# - Multiple submissions are allowed. The highest score is kept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **1. Probability Model**
#
# A probability model can describe uncertain outcomes such as whether a shipment is delayed.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 1 answer">
#   <label><input type="radio" name="ch08-hw-q1" value="true"> True</label>
#   <label><input type="radio" name="ch08-hw-q1" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Probability models represent uncertainty.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **2. Mean and Median**
#
# For a skewed wait-time distribution, comparing mean and median can reveal how extreme values affect the summary.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 2 answer">
#   <label><input type="radio" name="ch08-hw-q2" value="true"> True</label>
#   <label><input type="radio" name="ch08-hw-q2" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Mean and median respond differently to skew and outliers.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **3. Sample Variation**
#
# Two random samples from the same customer population can have different sample proportions.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 3 answer">
#   <label><input type="radio" name="ch08-hw-q3" value="true"> True</label>
#   <label><input type="radio" name="ch08-hw-q3" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Sample statistics vary from sample to sample.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **4. Law of Large Numbers**
#
# The law of large numbers says that a sample of size two will always match the population exactly.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 4 answer">
#   <label><input type="radio" name="ch08-hw-q4" value="true"> True</label>
#   <label><input type="radio" name="ch08-hw-q4" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# Large samples tend to stabilize; tiny samples need not match exactly.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **5. Standard Error**
#
# Standard error is the same thing as the original data value for one customer.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 5 answer">
#   <label><input type="radio" name="ch08-hw-q5" value="true"> True</label>
#   <label><input type="radio" name="ch08-hw-q5" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# Standard error describes variability in a statistic across samples.

# %%
### 6. Complement Probability
# Calculate the probability that an order is not delayed.
# Print exactly:
# On-time probability: 0.85
delay_probability = 0.15

### Your code starts here.



### Your code ends here.

# %%
### Solution
delay_probability = 0.15
on_time_probability = 1 - delay_probability
print("On-time probability:", on_time_probability)
# Out:
# On-time probability: 0.85

# %%
### 7. Range of Values
# Calculate the range of customer wait times.
# Print exactly:
# Wait range: 9
wait_times = [3, 5, 8, 12]

### Your code starts here.



### Your code ends here.

# %%
### Solution
wait_times = [3, 5, 8, 12]
wait_range = max(wait_times) - min(wait_times)
print("Wait range:", wait_range)
# Out:
# Wait range: 9

# %%
### 8. Count Above Mean
# Count values above the mean.
# Print exactly:
# Mean sales: 30.0
# Above mean: 2
sales = [20, 30, 40, 30]

### Your code starts here.



### Your code ends here.

# %%
### Solution
sales = [20, 30, 40, 30]
mean_sales = sum(sales) / len(sales)
above_mean = 0
for sale in sales:
    if sale > mean_sales:
        above_mean = above_mean + 1
print("Mean sales:", mean_sales)
print("Above mean:", above_mean)
# Out:
# Mean sales: 30.0
# Above mean: 1

# %%
### 9. Empirical Probability
# Calculate empirical probability from event flags.
# Print exactly:
# Empirical probability: 0.5
flags = [1, 0, 1, 0]

### Your code starts here.



### Your code ends here.

# %%
### Solution
flags = [1, 0, 1, 0]
empirical_probability = sum(flags) / len(flags)
print("Empirical probability:", empirical_probability)
# Out:
# Empirical probability: 0.5

# %%
### 10. Standard Error Direction
# Decide whether the standard error should be smaller for the larger sample.
# Print exactly:
# Larger sample has smaller SE: True
small_sample_size = 25
large_sample_size = 100

### Your code starts here.



### Your code ends here.

# %%
### Solution
small_sample_size = 25
large_sample_size = 100
larger_sample_has_smaller_se = large_sample_size > small_sample_size
print("Larger sample has smaller SE:", larger_sample_has_smaller_se)
# Out:
# Larger sample has smaller SE: True

# %% [markdown]
# <style>
# .ch08-hw-grader { max-width: 900px; margin-top: 1rem; }
# .ch08-hw-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch08-hw-feedback-list[hidden] { display: none; }
# .ch08-hw-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch08-hw-feedback-row strong { margin-right: 0.35rem; }
# .ch08-hw-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch08-hw-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch08-hw-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch08-hw-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch08-hw-actions button.secondary { background: white; color: #176de8; }
# .ch08-hw-actions.is-locked { opacity: 0.55; }
# .ch08-hw-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch08-hw-result { font-weight: 700; }
# </style>
#
# <div class='ch08-hw-grader' id='ch08-hw-grader'>
#   <div class='ch08-hw-feedback-list' aria-live='polite' hidden>
#     <div class='ch08-hw-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch08-hw-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch08-hw-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch08-hw-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch08-hw-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#     <div class='ch08-hw-feedback-row' data-question='q6'><strong>Question 6</strong><span></span></div>
#     <div class='ch08-hw-feedback-row' data-question='q7'><strong>Question 7</strong><span></span></div>
#     <div class='ch08-hw-feedback-row' data-question='q8'><strong>Question 8</strong><span></span></div>
#     <div class='ch08-hw-feedback-row' data-question='q9'><strong>Question 9</strong><span></span></div>
#     <div class='ch08-hw-feedback-row' data-question='q10'><strong>Question 10</strong><span></span></div>
#   </div>
#   <div class='ch08-hw-actions'>
#     <button type='button' id='ch08-hw-submit' disabled>Submit</button>
#     <button type='button' class='secondary' id='ch08-hw-reset'>Clear Results</button>
#     <span class='ch08-hw-result' id='ch08-hw-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var homeworkId = 'ch08-homework';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var cm = cell.querySelector('.CodeMirror');
#     if (cm && cm.CodeMirror && typeof cm.CodeMirror.getValue === 'function') return cm.CodeMirror.getValue();
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent && cmContent.cmView && cmContent.cmView.view) return cmContent.cmView.view.state.doc.toString();
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.prototype.slice.call(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 6)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function collectAnswers() {
#     var answers = {};
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var checked = document.querySelector('input[name="ch08-hw-' + question + '"]:checked');
#       answers[question] = checked ? checked.value : '';
#     });
#     return answers;
#   }
#
#   function applyFeedback(grader, feedback) {
#     var list = grader.querySelector('.ch08-hw-feedback-list');
#     list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9', 'q10'].forEach(function (question) {
#       var row = grader.querySelector('[data-question=' + question + ']');
#       var message = row.querySelector('span');
#       var item = feedback[question];
#       row.className = 'ch08-hw-feedback-row';
#       if (!item) return;
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(grader) {
#     var list = grader.querySelector('.ch08-hw-feedback-list');
#     list.hidden = true;
#     grader.querySelectorAll('.ch08-hw-feedback-row').forEach(function (row) {
#       row.className = 'ch08-hw-feedback-row';
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/homework-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var payload = text ? JSON.parse(text) : null;
#         if (!payload || !response.ok || !payload.ok) {
#           throw new Error((payload && (payload.message || payload.error)) || 'Submission API is unavailable.');
#         }
#         return payload;
#       });
#     });
#   }
#
#   function initHomeworkGrader() {
#     var grader = document.getElementById('ch08-hw-grader');
#     if (!grader || grader.dataset.ready === 'true') return;
#     grader.dataset.ready = 'true';
#
#     var identity = getParams();
#     var actions = grader.querySelector('.ch08-hw-actions');
#     var result = document.getElementById('ch08-hw-result');
#     var submit = document.getElementById('ch08-hw-submit');
#     var reset = document.getElementById('ch08-hw-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(grader);
#       submit.disabled = true;
#       result.textContent = 'Submitting homework.';
#
#       saveAttempt({
#         homework_id: homeworkId,
#         answers: collectAnswers(),
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           applyFeedback(grader, payload.feedback || {});
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(grader);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initHomeworkGrader);
#   } else {
#     initHomeworkGrader();
#   }
# })();
# </script>
