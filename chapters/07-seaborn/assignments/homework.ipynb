# %% [markdown]
# # Homework
#
# - Use these questions after class to check your understanding of the chapter concepts and coding skills.
# - Sign in from the account menu before you start working on the homework.
# - Complete all true/false and coding questions before you submit the homework.
# - Launch Live Code (the rocket) to write and run code in the coding cells.
# - Multiple submissions are allowed. The highest score is kept.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **Question 1: Tidy Data**
#
# A tidy dataset with one observation per row works well with Seaborn semantic mappings.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 1 answer">
#   <label><input type="radio" name="ch07-hw-q1" value="true"> True</label>
#   <label><input type="radio" name="ch07-hw-q1" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Seaborn is designed around tidy DataFrame inputs.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **Question 2: Hue Mapping**
#
# Using hue can help compare groups such as regions or customer segments in the same plot.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 2 answer">
#   <label><input type="radio" name="ch07-hw-q2" value="true"> True</label>
#   <label><input type="radio" name="ch07-hw-q2" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Hue maps a variable to color.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **Question 3: FacetGrid**
#
# Faceting combines all groups into one axis and prevents separate panels.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 3 answer">
#   <label><input type="radio" name="ch07-hw-q3" value="true"> True</label>
#   <label><input type="radio" name="ch07-hw-q3" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# Faceting creates separate panels for groups.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **Question 4: Categorical Plots**
#
# A categorical plot can help compare satisfaction scores across service plans.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 4 answer">
#   <label><input type="radio" name="ch07-hw-q4" value="true"> True</label>
#   <label><input type="radio" name="ch07-hw-q4" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# True
# Categorical plots compare distributions or summaries by group.

# %% [markdown]
# ::::{div} assignment-question-card
#
# **Question 5: Themes**
#
# Changing a Seaborn theme changes the raw data values being analyzed.
#
# <div class="tf-options" role="radiogroup" aria-label="Question 5 answer">
#   <label><input type="radio" name="ch07-hw-q5" value="true"> True</label>
#   <label><input type="radio" name="ch07-hw-q5" value="false"> False</label>
# </div>
#
# ::::

# %%
### Solution
# False
# Themes affect visual style, not the data.

# %%
### 6. Long Data Rows
# Convert two store records into long-format rows.
# Print exactly:
# Long rows: 4
stores = ["A", "B"]
metrics = ["sales", "profit"]

### Your code starts here.



### Your code ends here.

# %%
### Solution
stores = ["A", "B"]
metrics = ["sales", "profit"]
long_rows = []
for store in stores:
    for metric in metrics:
        long_rows.append([store, metric])
print("Long rows:", len(long_rows))
# Out:
# Long rows: 4

# %%
### 7. Relational Variables
# Store the x and y variables for a relational plot.
# Print exactly:
# X: discount
# Y: sales
variables = {"x": "discount", "y": "sales"}

### Your code starts here.



### Your code ends here.

# %%
### Solution
variables = {"x": "discount", "y": "sales"}
print("X:", variables["x"])
print("Y:", variables["y"])
# Out:
# X: discount
# Y: sales

# %%
### 8. Distribution Center
# Calculate the average value for a distribution plot annotation.
# Print exactly:
# Average rating: 4.0
ratings = [3, 4, 5]

### Your code starts here.



### Your code ends here.

# %%
### Solution
ratings = [3, 4, 5]
average_rating = sum(ratings) / len(ratings)
print("Average rating:", average_rating)
# Out:
# Average rating: 4.0

# %%
### 9. Facet Count
# Count unique product categories for faceting.
# Print exactly:
# Facet count: 3
categories = ["A", "B", "A", "C"]

### Your code starts here.



### Your code ends here.

# %%
### Solution
categories = ["A", "B", "A", "C"]
facet_count = len(set(categories))
print("Facet count:", facet_count)
# Out:
# Facet count: 3

# %%
### 10. Heatmap Cell Count
# Calculate how many cells appear in a 3 by 4 heatmap.
# Print exactly:
# Heatmap cells: 12
rows = 3
columns = 4

### Your code starts here.



### Your code ends here.

# %%
### Solution
rows = 3
columns = 4
heatmap_cells = rows * columns
print("Heatmap cells:", heatmap_cells)
# Out:
# Heatmap cells: 12

# %% [markdown]
# <style>
# .ch07-hw-grader { max-width: 900px; margin-top: 1rem; }
# .ch07-hw-feedback-list { display: grid; gap: 0.45rem; margin: 0 0 1rem; }
# .ch07-hw-feedback-list[hidden] { display: none; }
# .ch07-hw-feedback-row { border: 1px solid #d8dee4; border-radius: 6px; padding: 0.55rem 0.65rem; }
# .ch07-hw-feedback-row strong { margin-right: 0.35rem; }
# .ch07-hw-feedback-row.correct { border-color: #aceebb; background: #dafbe1; color: #116329; }
# .ch07-hw-feedback-row.incorrect { border-color: #ffcecb; background: #ffebe9; color: #cf222e; }
# .ch07-hw-actions { display: flex; gap: 0.75rem; align-items: center; margin: 1rem 0 0; flex-wrap: wrap; }
# .ch07-hw-actions button { border: 1px solid #176de8; border-radius: 6px; background: #176de8; color: white; padding: 0.55rem 0.9rem; cursor: pointer; font-weight: 600; }
# .ch07-hw-actions button.secondary { background: white; color: #176de8; }
# .ch07-hw-actions.is-locked { opacity: 0.55; }
# .ch07-hw-actions button:disabled { cursor: not-allowed; opacity: 0.65; }
# .ch07-hw-result { font-weight: 700; }
# </style>
#
# <div class='ch07-hw-grader' id='ch07-hw-grader'>
#   <div class='ch07-hw-feedback-list' aria-live='polite' hidden>
#     <div class='ch07-hw-feedback-row' data-question='q1'><strong>Question 1</strong><span></span></div>
#     <div class='ch07-hw-feedback-row' data-question='q2'><strong>Question 2</strong><span></span></div>
#     <div class='ch07-hw-feedback-row' data-question='q3'><strong>Question 3</strong><span></span></div>
#     <div class='ch07-hw-feedback-row' data-question='q4'><strong>Question 4</strong><span></span></div>
#     <div class='ch07-hw-feedback-row' data-question='q5'><strong>Question 5</strong><span></span></div>
#     <div class='ch07-hw-feedback-row' data-question='q6'><strong>Question 6</strong><span></span></div>
#     <div class='ch07-hw-feedback-row' data-question='q7'><strong>Question 7</strong><span></span></div>
#     <div class='ch07-hw-feedback-row' data-question='q8'><strong>Question 8</strong><span></span></div>
#     <div class='ch07-hw-feedback-row' data-question='q9'><strong>Question 9</strong><span></span></div>
#     <div class='ch07-hw-feedback-row' data-question='q10'><strong>Question 10</strong><span></span></div>
#   </div>
#   <div class='ch07-hw-actions'>
#     <button type='button' id='ch07-hw-submit' disabled>Submit</button>
#     <button type='button' class='secondary' id='ch07-hw-reset'>Clear Results</button>
#     <span class='ch07-hw-result' id='ch07-hw-result' aria-live='polite'></span>
#   </div>
# </div>
#
# <script>
# (function () {
#   var homeworkId = 'ch07-homework';
#
#   function getParams() {
#     var params = new URLSearchParams(window.location.search);
#     return {
#       canvas_course_id: params.get('canvas_course_id') || params.get('course_id') || '',
#       canvas_assignment_id: params.get('canvas_assignment_id') || params.get('assignment_id') || '',
#       canvas_user_id: params.get('canvas_user_id') || params.get('user_id') || ''
#     };
#   }
#
#   function loadSessionIdentity(identity, actions, submit, result) {
#     submit.disabled = true;
#     actions.classList.add('is-locked');
#     result.textContent = 'Sign in from the account menu to submit this assignment.';
#
#     return fetch('/api/v1/session.php', { credentials: 'same-origin' })
#       .then(function (response) { return response.ok ? response.json() : null; })
#       .then(function (payload) {
#         if (!payload || !payload.authenticated || !payload.identity) return identity;
#         identity.canvas_user_id = payload.identity.canvas_user_id || identity.canvas_user_id || '';
#         identity.student_identifier = payload.identity.student_identifier || '';
#         submit.disabled = false;
#         actions.classList.remove('is-locked');
#         result.textContent = payload.identity.display_name ? 'Signed in as ' + payload.identity.display_name + '.' : 'Signed in.';
#         return identity;
#       })
#       .catch(function () { return identity; });
#   }
#
#   function codeFromCell(cell) {
#     var cm = cell.querySelector('.CodeMirror');
#     if (cm && cm.CodeMirror && typeof cm.CodeMirror.getValue === 'function') return cm.CodeMirror.getValue();
#     var cmContent = cell.querySelector('.cm-content');
#     if (cmContent && cmContent.cmView && cmContent.cmView.view) return cmContent.cmView.view.state.doc.toString();
#     var textarea = cell.querySelector('textarea');
#     if (textarea) return textarea.value;
#     var pre = cell.querySelector('.cell_input pre');
#     return pre ? pre.textContent : '';
#   }
#
#   function collectCodeCells() {
#     var cells = Array.prototype.slice.call(document.querySelectorAll('div.cell.tag_thebe-interactive')).slice(0, 5);
#     var code = {};
#     cells.forEach(function (cell, index) {
#       code['q' + (index + 6)] = codeFromCell(cell);
#     });
#     return code;
#   }
#
#   function collectAnswers() {
#     var answers = {};
#     ['q1', 'q2', 'q3', 'q4', 'q5'].forEach(function (question) {
#       var checked = document.querySelector('input[name="ch07-hw-' + question + '"]:checked');
#       answers[question] = checked ? checked.value : '';
#     });
#     return answers;
#   }
#
#   function applyFeedback(grader, feedback) {
#     var list = grader.querySelector('.ch07-hw-feedback-list');
#     list.hidden = false;
#     ['q1', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9', 'q10'].forEach(function (question) {
#       var row = grader.querySelector('[data-question=' + question + ']');
#       var message = row.querySelector('span');
#       var item = feedback[question];
#       row.className = 'ch07-hw-feedback-row';
#       if (!item) return;
#       message.textContent = item.message + ' (' + item.score + ' / ' + item.max_score + ')';
#       row.classList.add(item.correct ? 'correct' : 'incorrect');
#     });
#   }
#
#   function clearFeedback(grader) {
#     var list = grader.querySelector('.ch07-hw-feedback-list');
#     list.hidden = true;
#     grader.querySelectorAll('.ch07-hw-feedback-row').forEach(function (row) {
#       row.className = 'ch07-hw-feedback-row';
#       var message = row.querySelector('span');
#       if (message) message.textContent = '';
#     });
#   }
#
#   function saveAttempt(payload) {
#     return fetch('/api/v1/homework-attempts.php', {
#       method: 'POST',
#       headers: { 'Content-Type': 'application/json' },
#       credentials: 'same-origin',
#       body: JSON.stringify(payload)
#     }).then(function (response) {
#       return response.text().then(function (text) {
#         var payload = text ? JSON.parse(text) : null;
#         if (!payload || !response.ok || !payload.ok) {
#           throw new Error((payload && (payload.message || payload.error)) || 'Submission API is unavailable.');
#         }
#         return payload;
#       });
#     });
#   }
#
#   function initHomeworkGrader() {
#     var grader = document.getElementById('ch07-hw-grader');
#     if (!grader || grader.dataset.ready === 'true') return;
#     grader.dataset.ready = 'true';
#
#     var identity = getParams();
#     var actions = grader.querySelector('.ch07-hw-actions');
#     var result = document.getElementById('ch07-hw-result');
#     var submit = document.getElementById('ch07-hw-submit');
#     var reset = document.getElementById('ch07-hw-reset');
#
#     loadSessionIdentity(identity, actions, submit, result);
#
#     submit.addEventListener('click', function () {
#       clearFeedback(grader);
#       submit.disabled = true;
#       result.textContent = 'Submitting homework.';
#
#       saveAttempt({
#         homework_id: homeworkId,
#         answers: collectAnswers(),
#         code: collectCodeCells(),
#         canvas_course_id: identity.canvas_course_id,
#         canvas_assignment_id: identity.canvas_assignment_id,
#         canvas_user_id: identity.canvas_user_id
#       })
#         .then(function (payload) {
#           var best = (payload.best_score === null || typeof payload.best_score === 'undefined') ? payload.score : payload.best_score;
#           var attempt = (payload.attempt_count === null || typeof payload.attempt_count === 'undefined') ? '' : ' Attempt ' + payload.attempt_count + '.';
#           applyFeedback(grader, payload.feedback || {});
#           result.textContent = 'Submission saved.' + attempt + ' Score: ' + payload.score + ' / ' + payload.max_score + '. Best score: ' + best + ' / ' + payload.max_score + '. Canvas sync: ' + payload.canvas_sync_status + '.';
#         })
#         .catch(function (error) {
#           result.textContent = 'Could not save this attempt: ' + error.message;
#         })
#         .finally(function () {
#           submit.disabled = false;
#         });
#     });
#
#     reset.addEventListener('click', function () {
#       clearFeedback(grader);
#       result.textContent = '';
#     });
#   }
#
#   if (document.readyState === 'loading') {
#     document.addEventListener('DOMContentLoaded', initHomeworkGrader);
#   } else {
#     initHomeworkGrader();
#   }
# })();
# </script>
