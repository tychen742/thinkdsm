# %% [markdown]
# # Files

# %% [markdown]
# ## Opening local files

# %%
### open a file in the same directory as this notebook
file = open(words.txt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 ### open a file in the same directory as this notebook
# ----> 2 file = open(words.txt)
#
# NameError: name 'words' is not defined

# %% [markdown]
# ### file path

# %% [markdown]
# In your

# %% [markdown]
# ## Loading Online Data
